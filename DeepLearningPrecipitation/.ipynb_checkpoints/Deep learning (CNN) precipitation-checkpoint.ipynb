# %% [markdown]
# # Data treatment and Neural Network Training using IPMA data
# João Oliveira and Edgar Mendes

# %%
#-----------------------Imports

import os
import requests
import json
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import io
from io import BytesIO
from PIL import Image, ImageDraw
import pytz
import numpy as np

#-----------------------Constantes

DADOS_ULTIMAS_3_HORAS = "https://api.ipma.pt/open-data/observation/meteorology/stations/obs-surface.geojson" #por exemplo se forem 9PM tem os dados entre 5PM e 7PM de hora a hora para todas as estações
DADOS_IDS_ESTACOES = "https://api.ipma.pt/open-data/observation/meteorology/stations/stations.json"
local_tz = pytz.timezone('Europe/Lisbon') #Define o fuso horário local

#-------Recorte para cada distrito

boxVianaDoCastelo = (570, 428, 770, 628)
boxLeiria = (574, 902, 774, 1102)
boxAveiro = (603, 687, 803, 887)
boxBeja =  (735, 1546, 935, 1746)
boxBraga =  (645, 463, 845, 663)
boxBraganca = (953, 401, 1153, 601)
boxCasteloBranco = (817, 886, 1017, 1086)
boxPortalegre = (829, 1012, 1029, 1212)
boxPorto = (611, 562, 811, 762)
boxSantarem = (597, 1026, 797, 1226)
boxCoimbra = (645, 792, 845, 992)
boxEvora = (740, 1183, 940, 1383)
boxFaro = (736, 1546, 936, 1746)
boxGuarda = (859, 712, 1059, 912)
boxLisboa = (513, 1149, 713, 1349)
boxSetubal = (559, 1193, 759, 1393)
boxVilaReal = (770, 527, 970, 727)
boxViseu = (740, 682, 940, 882)

#-------IDs das estações

idVianaDoCastelo = 1240610
idLeiria = 1210718
idAveiro = 1210702
idBeja = 1200562
idBraga = 6212124
idBraganca = 1200575
idCasteloBranco = 1200570
idPortalegre = 1200571
idPorto = 1240903
idSantarem = 1210734
idCoimbra = 1210707
idEvora = 1200558
idFaro = 1200554
idGuarda = 1210683
idLisboa = 7240919
idSetubal = 1210770
idVilaReal = 1240566
idViseu = 1240675

ids = np.array([1240610, 1210718, 1210702, 1200562, 6212124, 1200575, 1200570, 1200571, 
                1240903, 1210734, 1210707, 1200558, 1200554, 1210683, 7240919, 1210770, 
                1240566, 1240675])

station_box_dict = {idVianaDoCastelo: boxVianaDoCastelo,
                    idLeiria: boxLeiria,
                    idAveiro: boxAveiro,
                    idBeja: boxBeja,
                    idBraga: boxBraga,
                    idBraganca: boxBraganca,
                    idCasteloBranco: boxCasteloBranco,
                    idPortalegre: boxPortalegre,
                    idPorto: boxPorto,
                    idSantarem: boxSantarem,
                    idCoimbra: boxCoimbra,
                    idEvora: boxEvora,
                    idFaro: boxFaro,
                    idGuarda: boxGuarda,
                    idLisboa: boxLisboa,
                    idSetubal: boxSetubal,
                    idVilaReal: boxVilaReal,
                    idViseu: boxViseu}


#-----------------------Funções

def get_data(url):
    response = requests.get(f"{url}")
    if response.status_code == 200:
        print("Sucessfully fetched the data!") 
        return response.json() #https://www.educative.io/answers/how-to-make-api-calls-in-python
    else:
        print(f"Hello there, there's a {response.status_code} error with your request.")
        
def normalize_precipitation_value(precipitation_value):
    return int(round((precipitation_value/240)*100,0)) #o valor normalizado ta a ser arredondado pq as pastas sao de valores inteiros. https://www.ipma.pt/pt/oclima/extremos.clima/ Vou usar o valor máximo aqui como referencia

def get_images_and_data_from_ipma():
    data = get_data(DADOS_ULTIMAS_3_HORAS)
    # Faz a requisição à apiEstacoes e à apiMeteo para obter as informações meteorológicas 
    final_result = {}
    for feature in data['features']:
        if feature['properties']['idEstacao']  in ids:
            station_data = feature['properties']
            id_estacao = station_data['idEstacao']
            # Converte a hora da estação para o fuso horário local
            date_time_utc = datetime.fromisoformat(station_data['time'])
            date_time = datetime.fromisoformat(station_data['time']).replace(tzinfo=pytz.utc).astimezone(local_tz)
            date_str, hour_str = date_time.strftime('%Y-%m-%d %H:%M').split()
            precipitation = station_data['precAcumulada']

            if date_str not in final_result:
                final_result[date_str] = {hour_str: precipitation}
            else:
                final_result[date_str][hour_str] = normalize_precipitation_value(max(0, precipitation))

            url_image = f"https://www.ipma.pt/resources.www/transf/radar/por/pcr-{date_time_utc.strftime('%Y-%m-%d')}T{date_time_utc.strftime('%H%M')}.png"
            response = requests.get(url_image)
            image_data = io.BytesIO(response.content)
            image = Image.open(image_data)
            print(f"{url_image} ({hour_str}h)")
            
            
            # remover os pixeis pretos 
            image = remove_black_pixels(image)

            # Corte da imagem
            # verifica se a pasta id_estacao existe e cria se não existir
            if not os.path.exists(f"dataset/images/{id_estacao}"):
                os.makedirs(f"dataset/images/{id_estacao}")

            # verifica se a pasta date_str existe e cria se não existir
            if not os.path.exists(f"dataset/images/{id_estacao}/{date_str}"):
                os.makedirs(f"dataset/images/{id_estacao}/{date_str}")

            region = image.crop(station_box_dict[id_estacao])
            region.save(f"dataset/images/{id_estacao}/{date_str}/{date_time.strftime('%Y-%m-%dT%H%M')}.png")
            region.close()

            # Verifica se o arquivo JSON para esta estação já existe, se não, cria o arquivo
            filename = f"dataset/precipitation/{id_estacao}.json"
            if not os.path.isfile(filename):
                with open(filename, 'w') as file:
                    json.dump({}, file)

            # Carrega o conteúdo do arquivo JSON para a variável "precipitation_data"
            with open(filename, 'r') as file:
                precipitation_data = json.load(file)

            # Adiciona as informações meteorológicas ao arquivo JSON
            for date in final_result:
                if date not in precipitation_data:
                    precipitation_data[date] = final_result[date]
                else:
                    precipitation_data[date].update(final_result[date])

            # Escreve o conteúdo atualizado no arquivo JSON
            with open(filename, 'w') as file:
                json.dump(precipitation_data, file, indent=4)

    print("Dados atualizados com sucesso!")

    
def dict_to_array2D(input_dict):
    # Create an empty list to hold the values
    output_array = np.empty(0)
    # Loop over each key-value pair in the dictionary
    for date_dict in input_dict.values():
        for value in date_dict.values():
            # Append the value to the output array
            output_array = np.append(output_array,value)
    # Reshape to 2D array
    output_array = np.reshape(output_array, (-1, 1))
    # Return the output array
    return output_array

def remove_black_pixels(image):
    # Convert the image to RGBA mode (if it's not already in RGBA mode)
    image = image.convert("RGBA")
    # Get the pixel data as a list of tuples
    pixels = list(image.getdata())
    # Replace every black pixel with transparent
    new_pixels = []
    for pixel in pixels:
        if pixel[0] == 0 and pixel[1] == 0 and pixel[2] == 0:
            new_pixels.append((0, 0, 0, 0))
        else:
            new_pixels.append(pixel)

    # Create a new image with the same size and mode as the original image
    new_image = Image.new(image.mode, image.size)
    # Update the new image with the new pixel data
    new_image.putdata(new_pixels)
    # Return the new image
    return new_image

# %%
#--------Criação das pastas de 0 a 100

for i in range(101):
    os.mkdir(str(i)) #---Cria as pastas do 0 ao 100
print("Pastas criadas!")
# Out:
# Pastas criadas!

# %% [markdown]
# #  API Precipition Information
# Observação Meteorológica de Estações, últimas 3 horas (formato GeoJSON) com as imagens (png)

# %%
get_images_and_data_from_ipma()
#<class 'PIL.PngImagePlugin.PngImageFile'> | Image: <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x2331 at 0x1DADDEBEF40>
# Out:
# Sucessfully fetched the data!
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1200.png (13:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1300.png (14:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-05-03T1400.png (15:00h)
# Dados atualizados com sucesso!

# %% [markdown]
# # Model Training

# %%
#-----------------------Imports

import numpy as np
import io

from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras as keras

from keras import layers
from keras import callbacks
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPooling2D
from keras.utils.vis_utils import plot_model

import pydot



#-----------------------Constantes

N_CHANNELS = 4
N_NEURONIOS = 32
FILTER_SIZE = 3
MAX_POOL_SIZE = (3,3)
N_CLASSES = 100
N_EPOCHS = 200
N_STRIDES = 2
DROPOUT_VALUE = 0.5
IMAGE_WIDTH, IMAGE_HEIGHT = 200,200

# %%
images_array = np.empty((0, IMAGE_WIDTH, IMAGE_HEIGHT, 4))
data_array = np.empty(0)
# Open the JSON file
with open('dataset/precipitation/1240610.json') as f:
    # Load the JSON data
    data = json.load(f)

data_array = dict_to_array2D(data)

#-----------------------------------------

images_folder_path = 'dataset/images/1240610/'

# Get a list of all the files in the current folder
file_list = os.listdir(images_folder_path)

# Filter the list to only include folders files
days_folders_list = [file for file in file_list if os.path.isdir(os.path.join(images_folder_path, file))]

for day_folder in days_folders_list:
    current_path = images_folder_path + day_folder
    #Get a list of all files in the folder 
    files_list = os.listdir(current_path)
    # Filter the list to only include images files
    image_list = [file for file in files_list if file.endswith('.png')]
    for i in range(len(image_list)):
        image_path = os.path.join(current_path, image_list[i])
        image = Image.open(image_path)
        img_np = np.array(image)
        images_array = np.append(images_array, [img_np], axis=0)
        
train_images, val_images, train_values, val_values = train_test_split(images_array, data_array, test_size=0.2, random_state=42)

train_images = tf.keras.utils.normalize(train_images, axis=1)
val_images = tf.keras.utils.normalize(val_images, axis=1)

# %%
#Ver quantos valores há

def flatten_array(input_array):
    output_array = np.reshape(input_array, (-1,))
    return output_array

def count_values(arr):
    counts = {}
    for num in arr:
        if num in counts:
            counts[num] += 1
        else:
            counts[num] = 1
    return counts

counts = count_values(flatten_array(data_array))
print(counts)
# Out:
# {0.0: 57, 1.0: 2, 5.0: 1}

# %%
model = tf.keras.models.Sequential()
model.add(layers.Conv2D(N_NEURONIOS, MAX_POOL_SIZE, activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, N_CHANNELS)))
model.add(tf.keras.layers.Conv2D(N_NEURONIOS, FILTER_SIZE, strides=N_STRIDES, padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=MAX_POOL_SIZE))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(N_NEURONIOS*2, FILTER_SIZE, padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.MaxPooling2D(pool_size=MAX_POOL_SIZE))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Conv2D(N_NEURONIOS*4, FILTER_SIZE, padding='same', activation='relu'))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.MaxPooling2D(pool_size=MAX_POOL_SIZE))
# model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(N_NEURONIOS*8, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(DROPOUT_VALUE))
model.add(tf.keras.layers.Dense(N_CLASSES, activation='softmax'))

#model.summary()
#plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history = model.fit(train_images, train_values, epochs= N_EPOCHS, validation_data=(val_images, val_values))
# Out:
# Epoch 1/200
# 2/2 [==============================] - 5s 768ms/step - loss: 5.6387 - accuracy: 0.0417 - val_loss: 4.6987 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 2/2 [==============================] - 1s 400ms/step - loss: 4.6551 - accuracy: 0.1458 - val_loss: 4.6640 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 2/2 [==============================] - 1s 403ms/step - loss: 4.8159 - accuracy: 0.1667 - val_loss: 4.5971 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 2/2 [==============================] - 1s 407ms/step - loss: 4.7449 - accuracy: 0.2917 - val_loss: 4.5514 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 2/2 [==============================] - 1s 385ms/step - loss: 4.4730 - accuracy: 0.2292 - val_loss: 4.4807 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 2/2 [==============================] - 1s 385ms/step - loss: 4.7142 - accuracy: 0.2708 - val_loss: 4.4028 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 2/2 [==============================] - 1s 373ms/step - loss: 4.3063 - accuracy: 0.3333 - val_loss: 4.3142 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 2/2 [==============================] - 1s 384ms/step - loss: 4.1424 - accuracy: 0.3750 - val_loss: 4.2609 - val_accuracy: 0.0000e+00
# Epoch 9/200
# 2/2 [==============================] - 1s 397ms/step - loss: 3.7468 - accuracy: 0.4167 - val_loss: 4.2125 - val_accuracy: 0.0000e+00
# Epoch 10/200
# 2/2 [==============================] - 1s 375ms/step - loss: 4.2943 - accuracy: 0.3333 - val_loss: 4.1372 - val_accuracy: 0.0000e+00
# Epoch 11/200
# 2/2 [==============================] - 1s 374ms/step - loss: 3.8811 - accuracy: 0.4167 - val_loss: 4.0529 - val_accuracy: 0.0000e+00
# Epoch 12/200
# 2/2 [==============================] - 1s 392ms/step - loss: 3.4738 - accuracy: 0.5833 - val_loss: 3.9436 - val_accuracy: 0.0000e+00
# Epoch 13/200
# 2/2 [==============================] - 1s 403ms/step - loss: 3.6629 - accuracy: 0.5417 - val_loss: 3.8274 - val_accuracy: 0.4167
# Epoch 14/200
# 2/2 [==============================] - 1s 381ms/step - loss: 3.3189 - accuracy: 0.5417 - val_loss: 3.7183 - val_accuracy: 0.9167
# Epoch 15/200
# 2/2 [==============================] - 4s 2s/step - loss: 3.4584 - accuracy: 0.5625 - val_loss: 3.6076 - val_accuracy: 1.0000
# Epoch 16/200
# 2/2 [==============================] - 2s 453ms/step - loss: 3.0203 - accuracy: 0.6250 - val_loss: 3.5036 - val_accuracy: 1.0000
# Epoch 17/200
# 2/2 [==============================] - 1s 458ms/step - loss: 3.0308 - accuracy: 0.5625 - val_loss: 3.4014 - val_accuracy: 1.0000
# Epoch 18/200
# 2/2 [==============================] - 1s 440ms/step - loss: 2.9878 - accuracy: 0.5000 - val_loss: 3.2828 - val_accuracy: 1.0000
# Epoch 19/200
# 2/2 [==============================] - 1s 464ms/step - loss: 2.2419 - accuracy: 0.5625 - val_loss: 3.1339 - val_accuracy: 1.0000
# Epoch 20/200
# 2/2 [==============================] - 1s 455ms/step - loss: 2.6099 - accuracy: 0.6042 - val_loss: 3.0045 - val_accuracy: 1.0000
# Epoch 21/200
# 2/2 [==============================] - 1s 433ms/step - loss: 2.6595 - accuracy: 0.6250 - val_loss: 2.8998 - val_accuracy: 1.0000
# Epoch 22/200
# 2/2 [==============================] - 1s 441ms/step - loss: 2.4428 - accuracy: 0.7083 - val_loss: 2.8124 - val_accuracy: 1.0000
# Epoch 23/200
# 2/2 [==============================] - 1s 422ms/step - loss: 2.0941 - accuracy: 0.7292 - val_loss: 2.6856 - val_accuracy: 1.0000
# Epoch 24/200
# 2/2 [==============================] - 1s 493ms/step - loss: 1.9324 - accuracy: 0.7292 - val_loss: 2.5737 - val_accuracy: 1.0000
# Epoch 25/200
# 2/2 [==============================] - 1s 449ms/step - loss: 2.0050 - accuracy: 0.7083 - val_loss: 2.4656 - val_accuracy: 1.0000
# Epoch 26/200
# 2/2 [==============================] - 1s 462ms/step - loss: 1.9964 - accuracy: 0.7292 - val_loss: 2.3886 - val_accuracy: 1.0000
# Epoch 27/200
# 2/2 [==============================] - 1s 452ms/step - loss: 2.2053 - accuracy: 0.7292 - val_loss: 2.3192 - val_accuracy: 1.0000
# Epoch 28/200
# 2/2 [==============================] - 1s 429ms/step - loss: 1.5245 - accuracy: 0.8542 - val_loss: 2.2826 - val_accuracy: 1.0000
# Epoch 29/200
# 2/2 [==============================] - 1s 464ms/step - loss: 1.8267 - accuracy: 0.7500 - val_loss: 2.2206 - val_accuracy: 1.0000
# Epoch 30/200
# 2/2 [==============================] - 1s 390ms/step - loss: 1.3885 - accuracy: 0.8958 - val_loss: 2.1425 - val_accuracy: 1.0000
# Epoch 31/200
# 2/2 [==============================] - 1s 412ms/step - loss: 1.1600 - accuracy: 0.8958 - val_loss: 2.0422 - val_accuracy: 1.0000
# Epoch 32/200
# 2/2 [==============================] - 1s 392ms/step - loss: 1.2274 - accuracy: 0.9375 - val_loss: 1.9159 - val_accuracy: 1.0000
# Epoch 33/200
# 2/2 [==============================] - 1s 379ms/step - loss: 1.8261 - accuracy: 0.7083 - val_loss: 1.8054 - val_accuracy: 1.0000
# Epoch 34/200
# 2/2 [==============================] - 1s 387ms/step - loss: 0.7597 - accuracy: 0.9792 - val_loss: 1.6585 - val_accuracy: 1.0000
# Epoch 35/200
# 2/2 [==============================] - 1s 377ms/step - loss: 1.7106 - accuracy: 0.7292 - val_loss: 1.5912 - val_accuracy: 1.0000
# Epoch 36/200
# 2/2 [==============================] - 1s 399ms/step - loss: 1.4173 - accuracy: 0.8125 - val_loss: 1.5570 - val_accuracy: 1.0000
# Epoch 37/200
# 2/2 [==============================] - 1s 406ms/step - loss: 1.5673 - accuracy: 0.7917 - val_loss: 1.5333 - val_accuracy: 1.0000
# Epoch 38/200
# 2/2 [==============================] - 1s 393ms/step - loss: 0.7867 - accuracy: 0.9375 - val_loss: 1.4648 - val_accuracy: 1.0000
# Epoch 39/200
# 2/2 [==============================] - 1s 385ms/step - loss: 0.4942 - accuracy: 0.9583 - val_loss: 1.4155 - val_accuracy: 1.0000
# Epoch 40/200
# 2/2 [==============================] - 1s 382ms/step - loss: 1.2555 - accuracy: 0.8750 - val_loss: 1.3427 - val_accuracy: 1.0000
# Epoch 41/200
# 2/2 [==============================] - 1s 375ms/step - loss: 2.5424 - accuracy: 0.6458 - val_loss: 1.2713 - val_accuracy: 1.0000
# Epoch 42/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.9254 - accuracy: 0.9375 - val_loss: 1.1787 - val_accuracy: 1.0000
# Epoch 43/200
# 2/2 [==============================] - 1s 392ms/step - loss: 0.8174 - accuracy: 0.9792 - val_loss: 1.0987 - val_accuracy: 1.0000
# Epoch 44/200
# 2/2 [==============================] - 1s 375ms/step - loss: 1.2682 - accuracy: 0.7708 - val_loss: 1.0390 - val_accuracy: 1.0000
# Epoch 45/200
# 2/2 [==============================] - 1s 385ms/step - loss: 0.5049 - accuracy: 0.9375 - val_loss: 1.0076 - val_accuracy: 1.0000
# Epoch 46/200
# 2/2 [==============================] - 1s 373ms/step - loss: 0.6198 - accuracy: 0.9583 - val_loss: 1.0545 - val_accuracy: 1.0000
# Epoch 47/200
# 2/2 [==============================] - 1s 384ms/step - loss: 1.2551 - accuracy: 0.7917 - val_loss: 1.1136 - val_accuracy: 1.0000
# Epoch 48/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.6110 - accuracy: 0.8958 - val_loss: 1.1996 - val_accuracy: 1.0000
# Epoch 49/200
# 2/2 [==============================] - 1s 383ms/step - loss: 0.4115 - accuracy: 0.9792 - val_loss: 1.3369 - val_accuracy: 1.0000
# Epoch 50/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.5505 - accuracy: 0.9792 - val_loss: 1.4318 - val_accuracy: 1.0000
# Epoch 51/200
# 2/2 [==============================] - 1s 370ms/step - loss: 0.5107 - accuracy: 1.0000 - val_loss: 1.4127 - val_accuracy: 1.0000
# Epoch 52/200
# 2/2 [==============================] - 1s 379ms/step - loss: 0.4130 - accuracy: 1.0000 - val_loss: 1.2290 - val_accuracy: 1.0000
# Epoch 53/200
# 2/2 [==============================] - 1s 384ms/step - loss: 0.4242 - accuracy: 0.9583 - val_loss: 1.0629 - val_accuracy: 1.0000
# Epoch 54/200
# 2/2 [==============================] - 1s 388ms/step - loss: 0.3225 - accuracy: 1.0000 - val_loss: 0.9063 - val_accuracy: 1.0000
# Epoch 55/200
# 2/2 [==============================] - 1s 393ms/step - loss: 0.2655 - accuracy: 1.0000 - val_loss: 0.7804 - val_accuracy: 1.0000
# Epoch 56/200
# 2/2 [==============================] - 1s 371ms/step - loss: 0.3256 - accuracy: 0.9792 - val_loss: 0.6697 - val_accuracy: 1.0000
# Epoch 57/200
# 2/2 [==============================] - 1s 377ms/step - loss: 0.2210 - accuracy: 0.9792 - val_loss: 0.5766 - val_accuracy: 1.0000
# Epoch 58/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.3014 - accuracy: 0.9792 - val_loss: 0.5341 - val_accuracy: 1.0000
# Epoch 59/200
# 2/2 [==============================] - 1s 377ms/step - loss: 0.3221 - accuracy: 0.9792 - val_loss: 0.4956 - val_accuracy: 1.0000
# Epoch 60/200
# 2/2 [==============================] - 1s 373ms/step - loss: 0.3188 - accuracy: 0.9792 - val_loss: 0.4725 - val_accuracy: 1.0000
# Epoch 61/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.2293 - accuracy: 1.0000 - val_loss: 0.4425 - val_accuracy: 1.0000
# Epoch 62/200
# 2/2 [==============================] - 1s 379ms/step - loss: 1.0705 - accuracy: 0.8542 - val_loss: 0.4371 - val_accuracy: 1.0000
# Epoch 63/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.2410 - accuracy: 1.0000 - val_loss: 0.4458 - val_accuracy: 1.0000
# Epoch 64/200
# 2/2 [==============================] - 1s 379ms/step - loss: 0.8445 - accuracy: 0.8542 - val_loss: 0.4191 - val_accuracy: 1.0000
# Epoch 65/200
# 2/2 [==============================] - 1s 383ms/step - loss: 0.1307 - accuracy: 1.0000 - val_loss: 0.3727 - val_accuracy: 1.0000
# Epoch 66/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.1244 - accuracy: 1.0000 - val_loss: 0.3511 - val_accuracy: 1.0000
# Epoch 67/200
# 2/2 [==============================] - 1s 381ms/step - loss: 0.0926 - accuracy: 1.0000 - val_loss: 0.3429 - val_accuracy: 1.0000
# Epoch 68/200
# 2/2 [==============================] - 1s 381ms/step - loss: 0.1130 - accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 1.0000
# Epoch 69/200
# 2/2 [==============================] - 1s 379ms/step - loss: 1.8882 - accuracy: 0.7500 - val_loss: 0.3243 - val_accuracy: 1.0000
# Epoch 70/200
# 2/2 [==============================] - 1s 371ms/step - loss: 0.9547 - accuracy: 0.8542 - val_loss: 0.3295 - val_accuracy: 1.0000
# Epoch 71/200
# 2/2 [==============================] - 4s 2s/step - loss: 0.2178 - accuracy: 0.9792 - val_loss: 0.3221 - val_accuracy: 1.0000
# Epoch 72/200
# 2/2 [==============================] - 2s 411ms/step - loss: 0.1249 - accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 1.0000
# Epoch 73/200
# 2/2 [==============================] - 1s 409ms/step - loss: 0.1293 - accuracy: 1.0000 - val_loss: 0.3253 - val_accuracy: 1.0000
# Epoch 74/200
# 2/2 [==============================] - 1s 410ms/step - loss: 0.8305 - accuracy: 0.9167 - val_loss: 0.3453 - val_accuracy: 1.0000
# Epoch 75/200
# 2/2 [==============================] - 1s 408ms/step - loss: 0.7776 - accuracy: 0.8958 - val_loss: 0.3481 - val_accuracy: 1.0000
# Epoch 76/200
# 2/2 [==============================] - 1s 409ms/step - loss: 0.1613 - accuracy: 0.9792 - val_loss: 0.3308 - val_accuracy: 1.0000
# Epoch 77/200
# 2/2 [==============================] - 1s 399ms/step - loss: 0.3688 - accuracy: 1.0000 - val_loss: 0.2906 - val_accuracy: 1.0000
# Epoch 78/200
# 2/2 [==============================] - 1s 400ms/step - loss: 0.1084 - accuracy: 1.0000 - val_loss: 0.2594 - val_accuracy: 1.0000
# Epoch 79/200
# 2/2 [==============================] - 1s 414ms/step - loss: 0.0950 - accuracy: 1.0000 - val_loss: 0.2393 - val_accuracy: 1.0000
# Epoch 80/200
# 2/2 [==============================] - 1s 399ms/step - loss: 0.1100 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 1.0000
# Epoch 81/200
# 2/2 [==============================] - 1s 432ms/step - loss: 0.1381 - accuracy: 1.0000 - val_loss: 0.2360 - val_accuracy: 1.0000
# Epoch 82/200
# 2/2 [==============================] - 1s 421ms/step - loss: 0.0901 - accuracy: 1.0000 - val_loss: 0.2438 - val_accuracy: 1.0000
# Epoch 83/200
# 2/2 [==============================] - 1s 418ms/step - loss: 0.1208 - accuracy: 1.0000 - val_loss: 0.2410 - val_accuracy: 1.0000
# Epoch 84/200
# 2/2 [==============================] - 1s 391ms/step - loss: 0.1667 - accuracy: 0.9792 - val_loss: 0.2390 - val_accuracy: 1.0000
# Epoch 85/200
# 2/2 [==============================] - 1s 386ms/step - loss: 0.6225 - accuracy: 0.9167 - val_loss: 0.2617 - val_accuracy: 1.0000
# Epoch 86/200
# 2/2 [==============================] - 1s 391ms/step - loss: 0.1111 - accuracy: 0.9792 - val_loss: 0.3072 - val_accuracy: 1.0000
# Epoch 87/200
# 2/2 [==============================] - 1s 392ms/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 0.3516 - val_accuracy: 1.0000
# Epoch 88/200
# 2/2 [==============================] - 1s 395ms/step - loss: 0.5082 - accuracy: 0.9792 - val_loss: 0.3889 - val_accuracy: 1.0000
# Epoch 89/200
# 2/2 [==============================] - 1s 379ms/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.3949 - val_accuracy: 1.0000
# Epoch 90/200
# 2/2 [==============================] - 1s 380ms/step - loss: 1.2921 - accuracy: 0.8125 - val_loss: 0.3679 - val_accuracy: 1.0000
# Epoch 91/200
# 2/2 [==============================] - 1s 381ms/step - loss: 0.3509 - accuracy: 0.9375 - val_loss: 0.3677 - val_accuracy: 1.0000
# Epoch 92/200
# 2/2 [==============================] - 1s 380ms/step - loss: 0.4883 - accuracy: 0.9375 - val_loss: 0.3718 - val_accuracy: 1.0000
# Epoch 93/200
# 2/2 [==============================] - 1s 377ms/step - loss: 0.6834 - accuracy: 0.9167 - val_loss: 0.3574 - val_accuracy: 1.0000
# Epoch 94/200
# 2/2 [==============================] - 1s 373ms/step - loss: 0.1298 - accuracy: 1.0000 - val_loss: 0.3133 - val_accuracy: 1.0000
# Epoch 95/200
# 2/2 [==============================] - 1s 384ms/step - loss: 0.1995 - accuracy: 0.9792 - val_loss: 0.2751 - val_accuracy: 1.0000
# Epoch 96/200
# 2/2 [==============================] - 1s 390ms/step - loss: 0.2120 - accuracy: 0.9792 - val_loss: 0.2338 - val_accuracy: 1.0000
# Epoch 97/200
# 2/2 [==============================] - 1s 376ms/step - loss: 0.4691 - accuracy: 0.9375 - val_loss: 0.2058 - val_accuracy: 1.0000
# Epoch 98/200
# 2/2 [==============================] - 1s 379ms/step - loss: 0.2520 - accuracy: 0.9792 - val_loss: 0.1742 - val_accuracy: 1.0000
# Epoch 99/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 1.0000
# Epoch 100/200
# 2/2 [==============================] - 1s 376ms/step - loss: 0.0605 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 1.0000
# Epoch 101/200
# 2/2 [==============================] - 1s 372ms/step - loss: 0.8502 - accuracy: 0.9167 - val_loss: 0.0978 - val_accuracy: 1.0000
# Epoch 102/200
# 2/2 [==============================] - 1s 364ms/step - loss: 0.0619 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 1.0000
# Epoch 103/200
# 2/2 [==============================] - 1s 376ms/step - loss: 0.2705 - accuracy: 0.9375 - val_loss: 0.0895 - val_accuracy: 1.0000
# Epoch 104/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.4031 - accuracy: 0.9375 - val_loss: 0.0852 - val_accuracy: 1.0000
# Epoch 105/200
# 2/2 [==============================] - 1s 383ms/step - loss: 0.3422 - accuracy: 0.8958 - val_loss: 0.0865 - val_accuracy: 1.0000
# Epoch 106/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.4376 - accuracy: 0.9583 - val_loss: 0.0861 - val_accuracy: 1.0000
# Epoch 107/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 108/200
# 2/2 [==============================] - 1s 383ms/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 109/200
# 2/2 [==============================] - 1s 386ms/step - loss: 0.2317 - accuracy: 0.9792 - val_loss: 0.0734 - val_accuracy: 1.0000
# Epoch 110/200
# 2/2 [==============================] - 1s 393ms/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 111/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.5671 - accuracy: 0.9375 - val_loss: 0.0620 - val_accuracy: 1.0000
# Epoch 112/200
# 2/2 [==============================] - 1s 371ms/step - loss: 0.4434 - accuracy: 0.9375 - val_loss: 0.0569 - val_accuracy: 1.0000
# Epoch 113/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.0397 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 1.0000
# Epoch 114/200
# 2/2 [==============================] - 1s 379ms/step - loss: 0.2957 - accuracy: 0.9792 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 115/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 116/200
# 2/2 [==============================] - 1s 377ms/step - loss: 0.2788 - accuracy: 0.9792 - val_loss: 0.0492 - val_accuracy: 1.0000
# Epoch 117/200
# 2/2 [==============================] - 1s 376ms/step - loss: 0.0890 - accuracy: 0.9792 - val_loss: 0.0498 - val_accuracy: 1.0000
# Epoch 118/200
# 2/2 [==============================] - 1s 380ms/step - loss: 0.1719 - accuracy: 0.9792 - val_loss: 0.0527 - val_accuracy: 1.0000
# Epoch 119/200
# 2/2 [==============================] - 1s 368ms/step - loss: 0.0920 - accuracy: 0.9792 - val_loss: 0.0564 - val_accuracy: 1.0000
# Epoch 120/200
# 2/2 [==============================] - 1s 394ms/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 121/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 1.0000
# Epoch 122/200
# 2/2 [==============================] - 1s 385ms/step - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 123/200
# 2/2 [==============================] - 1s 370ms/step - loss: 0.1271 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 1.0000
# Epoch 124/200
# 2/2 [==============================] - 1s 371ms/step - loss: 0.0629 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 1.0000
# Epoch 125/200
# 2/2 [==============================] - 1s 376ms/step - loss: 0.4322 - accuracy: 0.9583 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 126/200
# 2/2 [==============================] - 1s 385ms/step - loss: 0.2764 - accuracy: 0.9792 - val_loss: 0.0659 - val_accuracy: 1.0000
# Epoch 127/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.1057 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 1.0000
# Epoch 128/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 1.0000
# Epoch 129/200
# 2/2 [==============================] - 1s 399ms/step - loss: 0.0678 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 1.0000
# Epoch 130/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.1076 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 1.0000
# Epoch 131/200
# 2/2 [==============================] - 1s 380ms/step - loss: 0.0356 - accuracy: 1.0000 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 132/200
# 2/2 [==============================] - 1s 372ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 1.0000
# Epoch 133/200
# 2/2 [==============================] - 1s 377ms/step - loss: 0.4219 - accuracy: 0.9792 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 134/200
# 2/2 [==============================] - 1s 370ms/step - loss: 0.0801 - accuracy: 0.9792 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 135/200
# 2/2 [==============================] - 1s 398ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0694 - val_accuracy: 1.0000
# Epoch 136/200
# 2/2 [==============================] - 1s 384ms/step - loss: 0.1387 - accuracy: 1.0000 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 137/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.3048 - accuracy: 0.9792 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 138/200
# 2/2 [==============================] - 1s 371ms/step - loss: 0.2588 - accuracy: 1.0000 - val_loss: 0.0675 - val_accuracy: 1.0000
# Epoch 139/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.2544 - accuracy: 0.9792 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 140/200
# 2/2 [==============================] - 1s 383ms/step - loss: 0.0615 - accuracy: 0.9792 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 141/200
# 2/2 [==============================] - 2s 2s/step - loss: 0.2937 - accuracy: 0.9792 - val_loss: 0.0444 - val_accuracy: 1.0000
# Epoch 142/200
# 2/2 [==============================] - 4s 2s/step - loss: 0.2723 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 143/200
# 2/2 [==============================] - 1s 383ms/step - loss: 0.1014 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 144/200
# 2/2 [==============================] - 1s 387ms/step - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 145/200
# 2/2 [==============================] - 1s 387ms/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 146/200
# 2/2 [==============================] - 2s 2s/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 147/200
# 2/2 [==============================] - 4s 1s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 148/200
# 2/2 [==============================] - 1s 394ms/step - loss: 0.2831 - accuracy: 0.9792 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 149/200
# 2/2 [==============================] - 1s 394ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 150/200
# 2/2 [==============================] - 1s 394ms/step - loss: 0.1233 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 151/200
# 2/2 [==============================] - 1s 379ms/step - loss: 0.1008 - accuracy: 0.9792 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 152/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.1264 - accuracy: 0.9792 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 153/200
# 2/2 [==============================] - 1s 385ms/step - loss: 0.2559 - accuracy: 0.9583 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 154/200
# 2/2 [==============================] - 1s 400ms/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 155/200
# 2/2 [==============================] - 1s 390ms/step - loss: 0.2103 - accuracy: 0.9792 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 156/200
# 2/2 [==============================] - 1s 380ms/step - loss: 0.1794 - accuracy: 0.9792 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 157/200
# 2/2 [==============================] - 1s 401ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 158/200
# 2/2 [==============================] - 1s 413ms/step - loss: 0.1575 - accuracy: 0.9792 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 159/200
# 2/2 [==============================] - 1s 418ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 160/200
# 2/2 [==============================] - 1s 386ms/step - loss: 0.2582 - accuracy: 0.9583 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 161/200
# 2/2 [==============================] - 1s 381ms/step - loss: 0.0597 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 162/200
# 2/2 [==============================] - 1s 390ms/step - loss: 0.4034 - accuracy: 0.9375 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 163/200
# 2/2 [==============================] - 1s 398ms/step - loss: 0.2091 - accuracy: 0.9792 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 164/200
# 2/2 [==============================] - 1s 394ms/step - loss: 0.0414 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 165/200
# 2/2 [==============================] - 1s 396ms/step - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 166/200
# 2/2 [==============================] - 1s 394ms/step - loss: 0.1462 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 167/200
# 2/2 [==============================] - 1s 387ms/step - loss: 0.2301 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 168/200
# 2/2 [==============================] - 1s 402ms/step - loss: 0.2698 - accuracy: 0.9583 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 169/200
# 2/2 [==============================] - 1s 394ms/step - loss: 0.1988 - accuracy: 0.9792 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 170/200
# 2/2 [==============================] - 1s 396ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 171/200
# 2/2 [==============================] - 1s 389ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 172/200
# 2/2 [==============================] - 1s 384ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 173/200
# 2/2 [==============================] - 1s 397ms/step - loss: 0.2985 - accuracy: 0.9583 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 174/200
# 2/2 [==============================] - 1s 404ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 175/200
# 2/2 [==============================] - 1s 408ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 176/200
# 2/2 [==============================] - 1s 423ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 177/200
# 2/2 [==============================] - 1s 402ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 178/200
# 2/2 [==============================] - 1s 414ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 179/200
# 2/2 [==============================] - 1s 399ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 180/200
# 2/2 [==============================] - 1s 421ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 181/200
# 2/2 [==============================] - 1s 392ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 182/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 183/200
# 2/2 [==============================] - 1s 395ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 184/200
# 2/2 [==============================] - 1s 395ms/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 185/200
# 2/2 [==============================] - 1s 390ms/step - loss: 0.2285 - accuracy: 0.9792 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 186/200
# 2/2 [==============================] - 1s 400ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 187/200
# 2/2 [==============================] - 1s 400ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 188/200
# 2/2 [==============================] - 1s 392ms/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 189/200
# 2/2 [==============================] - 1s 405ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 190/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 191/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.2964 - accuracy: 0.9792 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 192/200
# 2/2 [==============================] - 1s 396ms/step - loss: 0.1049 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 193/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 194/200
# 2/2 [==============================] - 1s 399ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 195/200
# 2/2 [==============================] - 1s 381ms/step - loss: 0.0291 - accuracy: 0.9792 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 196/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 1s 373ms/step - loss: 0.0699 - accuracy: 0.9792 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 198/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.2855 - accuracy: 0.9792 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 199/200
# 2/2 [==============================] - 1s 373ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 200/200
# 2/2 [==============================] - 4s 2s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
