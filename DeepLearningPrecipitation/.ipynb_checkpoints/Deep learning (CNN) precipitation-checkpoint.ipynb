# %% [markdown]
# # Data treatment and Neural Network Training using IPMA data
# João Oliveira and Edgar Mendes

# %%
#-----------------------Imports

import os
import requests
import json
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import io
from io import BytesIO
from PIL import Image, ImageDraw
import pytz

#-----------------------Constantes

DADOS_ULTIMAS_3_HORAS = "https://api.ipma.pt/open-data/observation/meteorology/stations/obs-surface.geojson" #por exemplo se forem 9PM tem os dados entre 5PM e 7PM de hora a hora para todas as estações
DADOS_IDS_ESTACOES = "https://api.ipma.pt/open-data/observation/meteorology/stations/stations.json"
local_tz = pytz.timezone('Europe/Lisbon') #Define o fuso horário local

#-----------------------Funções

def get_data(url):
    response = requests.get(f"{url}")
    if response.status_code == 200:
        print("Sucessfully fetched the data!") 
        return response.json() #https://www.educative.io/answers/how-to-make-api-calls-in-python
    else:
        print(f"Hello there, there's a {response.status_code} error with your request.")
        
def normalize_precipitation_value(precipitation_value):
    return int(round((precipitation_value/240)*100,0)) #o valor normalizado ta a ser arredondado pq as pastas sao de valores inteiros. https://www.ipma.pt/pt/oclima/extremos.clima/ Vou usar o valor máximo aqui como referencia

def get_images_and_data_from_ipma():
    data = get_data(DADOS_ULTIMAS_3_HORAS)
    # Faz a requisição à apiEstacoes e à apiMeteo para obter as informações meteorológicas 
    box = (570, 428, 770, 628) # esses valores foram escolhidos por testes. coordenadas da região de Viana do Castelo (x1, y1, x2, y2) (1500x2331)

    final_result = {}
    for feature in data['features']:
        station_data = feature['properties']
        id_estacao = station_data['idEstacao']
        # Converte a hora da estação para o fuso horário local
        date_time_utc = datetime.fromisoformat(station_data['time'])
        date_time = datetime.fromisoformat(station_data['time']).replace(tzinfo=pytz.utc).astimezone(local_tz)
        date_str, hour_str = date_time.strftime('%Y-%m-%d %H:%M').split()
        precipitation = station_data['precAcumulada']

        if date_str not in final_result:
            final_result[date_str] = {hour_str: precipitation}
        else:
            final_result[date_str][hour_str] = normalize_precipitation_value(max(0, precipitation))

        url_image = f"https://www.ipma.pt/resources.www/transf/radar/por/pcr-{date_time_utc.strftime('%Y-%m-%d')}T{date_time_utc.strftime('%H%M')}.png"
        response = requests.get(url_image)
        image_data = io.BytesIO(response.content)
        image = Image.open(image_data)
        print(f"{url_image} ({hour_str}h)")

        # Corte da imagem
        # verifica se a pasta id_estacao existe e cria se não existir
        if not os.path.exists(f"dataset/images/{id_estacao}"):
            os.makedirs(f"dataset/images/{id_estacao}")

        # verifica se a pasta date_str existe e cria se não existir
        if not os.path.exists(f"dataset/images/{id_estacao}/{date_str}"):
            os.makedirs(f"dataset/images/{id_estacao}/{date_str}")

        # Corta a imagem na região definida pelas coordenadas se for de viana do castelo
        if int(id_estacao) == 1240610:
            region = image.crop(box)
            region.save(f"dataset/images/{id_estacao}/{date_str}/{date_time.strftime('%Y-%m-%dT%H%M')}.png")
            region.close()
        else:
            # Salva a imagem cortada como um arquivo PNG
            image.save(f"dataset/images/{id_estacao}/{date_str}/{date_time.strftime('%Y-%m-%dT%H%M')}.png")
        image.close()
        # Verifica se o arquivo JSON para esta estação já existe, se não, cria o arquivo
        filename = f"dataset/precipitation/{id_estacao}.json"
        if not os.path.isfile(filename):
            with open(filename, 'w') as file:
                json.dump({}, file)

        # Carrega o conteúdo do arquivo JSON para a variável "precipitation_data"
        with open(filename, 'r') as file:
            precipitation_data = json.load(file)

        # Adiciona as informações meteorológicas ao arquivo JSON
        for date in final_result:
            if date not in precipitation_data:
                precipitation_data[date] = final_result[date]
            else:
                precipitation_data[date].update(final_result[date])

        # Escreve o conteúdo atualizado no arquivo JSON
        with open(filename, 'w') as file:
            json.dump(precipitation_data, file, indent=4)

    print("Dados atualizados com sucesso!")
    
def dict_to_array2D(input_dict):
    # Create an empty list to hold the values
    output_array = np.empty(0)
    # Loop over each key-value pair in the dictionary
    for date_dict in input_dict.values():
        for value in date_dict.values():
            # Append the value to the output array
            output_array = np.append(output_array,value)
    # Reshape to 2D array
    output_array = np.reshape(output_array, (-1, 1))
    # Return the output array
    return output_array

# %%
#--------Criação das pastas de 0 a 100

for i in range(101):
    os.mkdir(str(i)) #---Cria as pastas do 0 ao 100
print("Pastas criadas!")
# Out:
# Pastas criadas!

# %% [markdown]
# #  API Precipition Information
# Observação Meteorológica de Estações, últimas 3 horas (formato GeoJSON) com as imagens (png)

# %%
#--------Código auxiliar para o corte das regiões para a análise 

# Coordenadas da imagem (aproximação)
lat1, long1 = 43.95, -12.453377201650959
lat2, long2 = 34, -4.348615353313684

# Carrega a imagem
img = Image.open("dataset/teste.png")
dist = 200

# Coordenadas do ponto de corte (coordenadas da estação)
lat_corte, long_corte = 41.695, -8.82916 
    
#lat_corte, long_corte = 37.16925866835189, -7.40364787889199

# Calcula as coordenadas do canto superior esquerdo do corte ()
x = int(img.width * (long_corte - long1) / (long2 - long1) - (dist/2))
y = int(img.height * (lat_corte - lat1) / (lat2 - lat1) - (dist/2))
print(f'(x1, y1, x2, y2) => ({x}, {y}, {x + dist}, {y + dist})') # Mostra onde a imagem foi cortada (x1, y1, x2, y2)

# Desenha um ponto vermelho no centro da imagem
draw = ImageDraw.Draw(img)
draw.ellipse((x+(dist/2), y+(dist/2), x+((dist/2)+2), y+((dist/2)+2)), fill='red')

# Faz o corte de (dist x dist) pixels
corte = img.crop((x, y, x+dist, y+dist))

# Mostra a imagem cortada
plt.imshow(corte)
plt.show()
# Out:
# (x1, y1, x2, y2) => (570, 428, 770, 628)

# %%
get_images_and_data_from_ipma()
#<class 'PIL.PngImagePlugin.PngImageFile'> | Image: <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x2331 at 0x1DADDEBEF40>
# Out:
# Sucessfully fetched the data!
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1700.png (18:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1800.png (19:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# https://www.ipma.pt/resources.www/transf/radar/por/pcr-2023-04-17T1900.png (20:00h)
# Dados atualizados com sucesso!

# %% [markdown]
# # Model Training

# %%
#-----------------------Imports

import numpy as np
import io

from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras as keras

from keras import layers
from keras import callbacks
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPooling2D


#-----------------------Constantes

N_CHANNELS = 4
N_NEURONIOS = 32
FILTER_SIZE = 3
MAX_POOL_SIZE = (3,3)
N_CLASSES = 100
N_EPOCHS = 200
N_STRIDES = 2
DROPOUT_VALUE = 0.5
IMAGE_WIDTH, IMAGE_HEIGHT = 200,200

# %%
images_array = np.empty((0, image_width, image_height, 4))
data_array = np.empty(0)
# Open the JSON file
with open('dataset/precipitation/1240610.json') as f:
    # Load the JSON data
    data = json.load(f)

data_array = dict_to_array2D(data)

#-----------------------------------------

images_folder_path = 'dataset/images/1240610/'

# Get a list of all the files in the current folder
file_list = os.listdir(images_folder_path)

# Filter the list to only include folders files
days_folders_list = [file for file in file_list if os.path.isdir(os.path.join(images_folder_path, file))]

for day_folder in days_folders_list:
    current_path = images_folder_path + day_folder
    #Get a list of all files in the folder 
    files_list = os.listdir(current_path)
    # Filter the list to only include images files
    image_list = [file for file in files_list if file.endswith('.png')]
    for i in range(len(image_list)):
        image_path = os.path.join(current_path, image_list[i])
        image = Image.open(image_path)
        img_np = np.array(image)
        images_array = np.append(images_array, [img_np], axis=0)

# %%
train_images, val_images, train_values, val_values = train_test_split(images_array, data_array, test_size=0.2, random_state=42)

# %%
train_images = tf.keras.utils.normalize(train_images, axis=1)
val_images = tf.keras.utils.normalize(val_images, axis=1)

# %%
model = tf.keras.models.Sequential()
model.add(layers.Conv2D(N_NEURONIOS, MAX_POOL_SIZE, activation='relu', input_shape=(IMAGE_WIDTH, image_height, N_CHANNELS)))
model.add(tf.keras.layers.Conv2D(N_NEURONIOS, FILTER_SIZE, strides=N_STRIDES, padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=MAX_POOL_SIZE))
model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Conv2D(N_NEURONIOS*2, FILTER_SIZE, padding='same', activation='relu'))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.MaxPooling2D(pool_size=MAX_POOL_SIZE))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Conv2D(N_NEURONIOS*4, FILTER_SIZE, padding='same', activation='relu'))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.MaxPooling2D(pool_size=MAX_POOL_SIZE))
# model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(N_NEURONIOS*8, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(DROPOUT_VALUE))
model.add(tf.keras.layers.Dense(N_CLASSES, activation='softmax'))

model.summary()

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(train_images, train_values, epochs= N_EPOCHS, validation_data=(val_images, val_values))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 198, 198, 32)      1184
#
#  conv2d_9 (Conv2D)           (None, 99, 99, 32)        9248
#
#  batch_normalization_13 (Bat  (None, 99, 99, 32)       128
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 33, 33, 32)       0
#  2D)
#
#  batch_normalization_14 (Bat  (None, 33, 33, 32)       128
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 34848)             0
#
#  dense_5 (Dense)             (None, 256)               8921344
#
#  batch_normalization_15 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 8,958,756
# Trainable params: 8,958,116
# Non-trainable params: 640
# _________________________________________________________________
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 6.5677 - accuracy: 0.0000e+00 - val_loss: 4.5864 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 1/1 [==============================] - 0s 342ms/step - loss: 5.8623 - accuracy: 0.0000e+00 - val_loss: 4.5262 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 1/1 [==============================] - 0s 336ms/step - loss: 6.0705 - accuracy: 0.0000e+00 - val_loss: 4.4820 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 1/1 [==============================] - 0s 357ms/step - loss: 5.3260 - accuracy: 0.0000e+00 - val_loss: 4.4207 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 1/1 [==============================] - 0s 400ms/step - loss: 5.7516 - accuracy: 0.0000e+00 - val_loss: 4.3798 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 1/1 [==============================] - 0s 354ms/step - loss: 5.5446 - accuracy: 0.0000e+00 - val_loss: 4.3475 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 1/1 [==============================] - 0s 379ms/step - loss: 5.3952 - accuracy: 0.0455 - val_loss: 4.3198 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 1/1 [==============================] - 0s 363ms/step - loss: 4.8745 - accuracy: 0.0455 - val_loss: 4.2978 - val_accuracy: 0.0000e+00
# Epoch 9/200
# 1/1 [==============================] - 0s 387ms/step - loss: 4.8554 - accuracy: 0.0000e+00 - val_loss: 4.2819 - val_accuracy: 0.0000e+00
# Epoch 10/200
# 1/1 [==============================] - 0s 382ms/step - loss: 4.9621 - accuracy: 0.0000e+00 - val_loss: 4.2698 - val_accuracy: 0.0000e+00
# Epoch 11/200
# 1/1 [==============================] - 0s 380ms/step - loss: 5.1627 - accuracy: 0.0000e+00 - val_loss: 4.2600 - val_accuracy: 0.0000e+00
# Epoch 12/200
# 1/1 [==============================] - 0s 371ms/step - loss: 5.2502 - accuracy: 0.0000e+00 - val_loss: 4.2517 - val_accuracy: 0.0000e+00
# Epoch 13/200
# 1/1 [==============================] - 0s 405ms/step - loss: 4.6984 - accuracy: 0.0455 - val_loss: 4.2417 - val_accuracy: 0.0000e+00
# Epoch 14/200
# 1/1 [==============================] - 0s 375ms/step - loss: 4.9638 - accuracy: 0.0455 - val_loss: 4.2340 - val_accuracy: 0.0000e+00
# Epoch 15/200
# 1/1 [==============================] - 0s 366ms/step - loss: 5.2034 - accuracy: 0.0909 - val_loss: 4.2214 - val_accuracy: 0.0000e+00
# Epoch 16/200
# 1/1 [==============================] - 0s 399ms/step - loss: 4.9931 - accuracy: 0.0909 - val_loss: 4.1987 - val_accuracy: 0.0000e+00
# Epoch 17/200
# 1/1 [==============================] - 0s 398ms/step - loss: 5.1417 - accuracy: 0.1364 - val_loss: 4.1773 - val_accuracy: 0.0000e+00
# Epoch 18/200
# 1/1 [==============================] - 0s 361ms/step - loss: 5.3378 - accuracy: 0.0909 - val_loss: 4.1557 - val_accuracy: 0.0000e+00
# Epoch 19/200
# 1/1 [==============================] - 0s 401ms/step - loss: 5.3582 - accuracy: 0.0455 - val_loss: 4.1322 - val_accuracy: 0.0000e+00
# Epoch 20/200
# 1/1 [==============================] - 0s 370ms/step - loss: 5.1695 - accuracy: 0.1818 - val_loss: 4.1083 - val_accuracy: 0.0000e+00
# Epoch 21/200
# 1/1 [==============================] - 0s 383ms/step - loss: 4.6884 - accuracy: 0.2273 - val_loss: 4.0808 - val_accuracy: 0.0000e+00
# Epoch 22/200
# 1/1 [==============================] - 0s 390ms/step - loss: 4.8316 - accuracy: 0.2727 - val_loss: 4.0530 - val_accuracy: 0.0000e+00
# Epoch 23/200
# 1/1 [==============================] - 0s 382ms/step - loss: 5.2978 - accuracy: 0.1818 - val_loss: 4.0237 - val_accuracy: 0.0000e+00
# Epoch 24/200
# 1/1 [==============================] - 0s 366ms/step - loss: 4.8019 - accuracy: 0.3182 - val_loss: 3.9927 - val_accuracy: 0.0000e+00
# Epoch 25/200
# 1/1 [==============================] - 0s 379ms/step - loss: 4.7511 - accuracy: 0.2727 - val_loss: 3.9632 - val_accuracy: 0.0000e+00
# Epoch 26/200
# 1/1 [==============================] - 0s 390ms/step - loss: 4.7557 - accuracy: 0.3182 - val_loss: 3.9319 - val_accuracy: 0.0000e+00
# Epoch 27/200
# 1/1 [==============================] - 0s 385ms/step - loss: 5.2117 - accuracy: 0.1818 - val_loss: 3.8986 - val_accuracy: 0.0000e+00
# Epoch 28/200
# 1/1 [==============================] - 0s 375ms/step - loss: 4.3018 - accuracy: 0.3182 - val_loss: 3.8671 - val_accuracy: 0.0000e+00
# Epoch 29/200
# 1/1 [==============================] - 0s 378ms/step - loss: 4.7253 - accuracy: 0.2273 - val_loss: 3.8384 - val_accuracy: 0.0000e+00
# Epoch 30/200
# 1/1 [==============================] - 0s 352ms/step - loss: 4.8395 - accuracy: 0.2273 - val_loss: 3.8087 - val_accuracy: 0.0000e+00
# Epoch 31/200
# 1/1 [==============================] - 0s 369ms/step - loss: 5.0594 - accuracy: 0.2727 - val_loss: 3.7787 - val_accuracy: 0.0000e+00
# Epoch 32/200
# 1/1 [==============================] - 0s 364ms/step - loss: 5.3281 - accuracy: 0.2273 - val_loss: 3.7488 - val_accuracy: 0.0000e+00
# Epoch 33/200
# 1/1 [==============================] - 0s 353ms/step - loss: 4.7758 - accuracy: 0.4091 - val_loss: 3.7200 - val_accuracy: 0.0000e+00
# Epoch 34/200
# 1/1 [==============================] - 0s 368ms/step - loss: 4.1070 - accuracy: 0.3182 - val_loss: 3.6934 - val_accuracy: 0.0000e+00
# Epoch 35/200
# 1/1 [==============================] - 0s 362ms/step - loss: 4.4855 - accuracy: 0.2273 - val_loss: 3.6671 - val_accuracy: 0.0000e+00
# Epoch 36/200
# 1/1 [==============================] - 0s 382ms/step - loss: 4.7260 - accuracy: 0.3182 - val_loss: 3.6410 - val_accuracy: 0.0000e+00
# Epoch 37/200
# 1/1 [==============================] - 0s 376ms/step - loss: 4.4062 - accuracy: 0.3636 - val_loss: 3.6189 - val_accuracy: 0.0000e+00
# Epoch 38/200
# 1/1 [==============================] - 0s 379ms/step - loss: 4.0633 - accuracy: 0.3182 - val_loss: 3.5970 - val_accuracy: 0.0000e+00
# Epoch 39/200
# 1/1 [==============================] - 0s 381ms/step - loss: 4.4695 - accuracy: 0.4545 - val_loss: 3.5738 - val_accuracy: 0.0000e+00
# Epoch 40/200
# 1/1 [==============================] - 0s 367ms/step - loss: 4.3323 - accuracy: 0.3182 - val_loss: 3.5482 - val_accuracy: 0.0000e+00
# Epoch 41/200
# 1/1 [==============================] - 0s 365ms/step - loss: 4.3620 - accuracy: 0.4091 - val_loss: 3.5224 - val_accuracy: 0.0000e+00
# Epoch 42/200
# 1/1 [==============================] - 0s 370ms/step - loss: 5.2355 - accuracy: 0.5000 - val_loss: 3.4389 - val_accuracy: 0.0000e+00
# Epoch 43/200
# 1/1 [==============================] - 0s 355ms/step - loss: 4.3199 - accuracy: 0.4091 - val_loss: 3.3630 - val_accuracy: 0.0000e+00
# Epoch 44/200
# 1/1 [==============================] - 0s 366ms/step - loss: 4.6505 - accuracy: 0.4091 - val_loss: 3.3057 - val_accuracy: 0.0000e+00
# Epoch 45/200
# 1/1 [==============================] - 0s 374ms/step - loss: 4.4716 - accuracy: 0.4091 - val_loss: 3.2627 - val_accuracy: 0.0000e+00
# Epoch 46/200
# 1/1 [==============================] - 0s 371ms/step - loss: 3.8368 - accuracy: 0.5455 - val_loss: 3.2325 - val_accuracy: 0.0000e+00
# Epoch 47/200
# 1/1 [==============================] - 0s 385ms/step - loss: 4.6666 - accuracy: 0.4545 - val_loss: 3.2077 - val_accuracy: 0.0000e+00
# Epoch 48/200
# 1/1 [==============================] - 0s 397ms/step - loss: 4.3676 - accuracy: 0.6364 - val_loss: 3.1856 - val_accuracy: 0.0000e+00
# Epoch 49/200
# 1/1 [==============================] - 0s 376ms/step - loss: 4.0860 - accuracy: 0.6818 - val_loss: 3.1644 - val_accuracy: 0.0000e+00
# Epoch 50/200
# 1/1 [==============================] - 0s 369ms/step - loss: 4.2405 - accuracy: 0.5909 - val_loss: 3.1416 - val_accuracy: 0.0000e+00
# Epoch 51/200
# 1/1 [==============================] - 0s 346ms/step - loss: 4.1200 - accuracy: 0.6364 - val_loss: 3.1149 - val_accuracy: 0.0000e+00
# Epoch 52/200
# 1/1 [==============================] - 0s 409ms/step - loss: 3.7792 - accuracy: 0.7273 - val_loss: 3.0901 - val_accuracy: 0.0000e+00
# Epoch 53/200
# 1/1 [==============================] - 0s 346ms/step - loss: 4.2098 - accuracy: 0.6818 - val_loss: 3.0643 - val_accuracy: 0.0000e+00
# Epoch 54/200
# 1/1 [==============================] - 0s 362ms/step - loss: 4.2028 - accuracy: 0.5909 - val_loss: 3.0434 - val_accuracy: 0.0000e+00
# Epoch 55/200
# 1/1 [==============================] - 0s 387ms/step - loss: 4.7113 - accuracy: 0.5000 - val_loss: 3.0206 - val_accuracy: 0.0000e+00
# Epoch 56/200
# 1/1 [==============================] - 0s 355ms/step - loss: 4.5161 - accuracy: 0.5455 - val_loss: 2.9939 - val_accuracy: 0.0000e+00
# Epoch 57/200
# 1/1 [==============================] - 0s 350ms/step - loss: 3.7589 - accuracy: 0.6364 - val_loss: 2.9685 - val_accuracy: 0.0000e+00
# Epoch 58/200
# 1/1 [==============================] - 0s 349ms/step - loss: 3.4055 - accuracy: 0.6818 - val_loss: 2.9404 - val_accuracy: 0.0000e+00
# Epoch 59/200
# 1/1 [==============================] - 0s 364ms/step - loss: 4.2455 - accuracy: 0.5909 - val_loss: 2.9070 - val_accuracy: 0.0000e+00
# Epoch 60/200
# 1/1 [==============================] - 0s 379ms/step - loss: 3.6459 - accuracy: 0.6364 - val_loss: 2.8730 - val_accuracy: 0.0000e+00
# Epoch 61/200
# 1/1 [==============================] - 0s 393ms/step - loss: 3.9373 - accuracy: 0.6364 - val_loss: 2.8417 - val_accuracy: 0.0000e+00
# Epoch 62/200
# 1/1 [==============================] - 0s 349ms/step - loss: 4.0093 - accuracy: 0.6818 - val_loss: 2.8102 - val_accuracy: 0.6667
# Epoch 63/200
# 1/1 [==============================] - 0s 354ms/step - loss: 3.5209 - accuracy: 0.7273 - val_loss: 2.7800 - val_accuracy: 0.8333
# Epoch 64/200
# 1/1 [==============================] - 0s 380ms/step - loss: 4.1935 - accuracy: 0.6818 - val_loss: 2.7440 - val_accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 350ms/step - loss: 4.0424 - accuracy: 0.5909 - val_loss: 2.7100 - val_accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 342ms/step - loss: 3.6290 - accuracy: 0.6818 - val_loss: 2.6766 - val_accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 345ms/step - loss: 3.4671 - accuracy: 0.6364 - val_loss: 2.6374 - val_accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 347ms/step - loss: 3.9299 - accuracy: 0.7273 - val_loss: 2.5987 - val_accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 394ms/step - loss: 3.3517 - accuracy: 0.7273 - val_loss: 2.5595 - val_accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 377ms/step - loss: 3.3957 - accuracy: 0.6818 - val_loss: 2.5170 - val_accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 355ms/step - loss: 3.3714 - accuracy: 0.7727 - val_loss: 2.4736 - val_accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 359ms/step - loss: 3.6260 - accuracy: 0.7273 - val_loss: 2.4315 - val_accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 334ms/step - loss: 3.6693 - accuracy: 0.7727 - val_loss: 2.3888 - val_accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 337ms/step - loss: 3.3647 - accuracy: 0.7273 - val_loss: 2.3436 - val_accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 353ms/step - loss: 3.2007 - accuracy: 0.7273 - val_loss: 2.3014 - val_accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 347ms/step - loss: 3.8763 - accuracy: 0.6818 - val_loss: 2.2590 - val_accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 372ms/step - loss: 3.1255 - accuracy: 0.6818 - val_loss: 2.2182 - val_accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 349ms/step - loss: 3.3205 - accuracy: 0.6818 - val_loss: 2.1780 - val_accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 343ms/step - loss: 3.7095 - accuracy: 0.6818 - val_loss: 2.1363 - val_accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 352ms/step - loss: 3.6311 - accuracy: 0.6364 - val_loss: 2.0944 - val_accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 346ms/step - loss: 3.2643 - accuracy: 0.7273 - val_loss: 2.0544 - val_accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 343ms/step - loss: 3.0500 - accuracy: 0.7273 - val_loss: 2.0138 - val_accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 376ms/step - loss: 2.8594 - accuracy: 0.8636 - val_loss: 1.9697 - val_accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 362ms/step - loss: 2.7738 - accuracy: 0.8182 - val_loss: 1.9265 - val_accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 359ms/step - loss: 3.0524 - accuracy: 0.7727 - val_loss: 1.8824 - val_accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 359ms/step - loss: 3.3304 - accuracy: 0.7273 - val_loss: 1.8377 - val_accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 371ms/step - loss: 2.9119 - accuracy: 0.7727 - val_loss: 1.7940 - val_accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 347ms/step - loss: 3.0778 - accuracy: 0.7273 - val_loss: 1.7499 - val_accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 370ms/step - loss: 2.5485 - accuracy: 0.8636 - val_loss: 1.7035 - val_accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 347ms/step - loss: 2.3703 - accuracy: 0.8182 - val_loss: 1.6576 - val_accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 369ms/step - loss: 2.4405 - accuracy: 0.8182 - val_loss: 1.6135 - val_accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 349ms/step - loss: 3.0276 - accuracy: 0.7727 - val_loss: 1.5660 - val_accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 359ms/step - loss: 2.7238 - accuracy: 0.8182 - val_loss: 1.5191 - val_accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 350ms/step - loss: 2.6224 - accuracy: 0.8182 - val_loss: 1.4699 - val_accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 357ms/step - loss: 2.8188 - accuracy: 0.7273 - val_loss: 1.4187 - val_accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 347ms/step - loss: 2.3104 - accuracy: 0.8182 - val_loss: 1.3687 - val_accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 354ms/step - loss: 2.9413 - accuracy: 0.6818 - val_loss: 1.3174 - val_accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 347ms/step - loss: 2.1561 - accuracy: 0.7727 - val_loss: 1.2672 - val_accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 342ms/step - loss: 2.0258 - accuracy: 0.8182 - val_loss: 1.2178 - val_accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 365ms/step - loss: 2.3420 - accuracy: 0.7727 - val_loss: 1.1638 - val_accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 340ms/step - loss: 2.1666 - accuracy: 0.8182 - val_loss: 1.1131 - val_accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 349ms/step - loss: 2.1190 - accuracy: 0.8636 - val_loss: 1.0621 - val_accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 353ms/step - loss: 2.1707 - accuracy: 0.8636 - val_loss: 1.0091 - val_accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 351ms/step - loss: 2.0107 - accuracy: 0.9091 - val_loss: 0.9572 - val_accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 355ms/step - loss: 2.1768 - accuracy: 0.8182 - val_loss: 0.9101 - val_accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 352ms/step - loss: 1.8031 - accuracy: 0.8636 - val_loss: 0.8649 - val_accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 354ms/step - loss: 2.6588 - accuracy: 0.7273 - val_loss: 0.8228 - val_accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 351ms/step - loss: 2.0735 - accuracy: 0.9091 - val_loss: 0.7824 - val_accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 352ms/step - loss: 1.9495 - accuracy: 0.8182 - val_loss: 0.7460 - val_accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 342ms/step - loss: 1.7668 - accuracy: 0.9091 - val_loss: 0.7100 - val_accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 353ms/step - loss: 1.9823 - accuracy: 0.8182 - val_loss: 0.6757 - val_accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 355ms/step - loss: 1.7060 - accuracy: 0.9091 - val_loss: 0.6400 - val_accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 354ms/step - loss: 1.8005 - accuracy: 0.9091 - val_loss: 0.6046 - val_accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 352ms/step - loss: 1.3949 - accuracy: 0.9091 - val_loss: 0.5687 - val_accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 350ms/step - loss: 1.9524 - accuracy: 0.8636 - val_loss: 0.5373 - val_accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 351ms/step - loss: 1.5557 - accuracy: 0.9091 - val_loss: 0.5085 - val_accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 347ms/step - loss: 2.0664 - accuracy: 0.8636 - val_loss: 0.4826 - val_accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 359ms/step - loss: 1.4346 - accuracy: 0.9091 - val_loss: 0.4576 - val_accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 350ms/step - loss: 1.4814 - accuracy: 0.9091 - val_loss: 0.4320 - val_accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 372ms/step - loss: 1.4658 - accuracy: 0.9091 - val_loss: 0.4035 - val_accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 351ms/step - loss: 1.4054 - accuracy: 0.9545 - val_loss: 0.3735 - val_accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 361ms/step - loss: 1.6235 - accuracy: 0.8182 - val_loss: 0.3449 - val_accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 346ms/step - loss: 1.5316 - accuracy: 0.8636 - val_loss: 0.3174 - val_accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 344ms/step - loss: 1.3573 - accuracy: 0.9545 - val_loss: 0.2910 - val_accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 348ms/step - loss: 1.1416 - accuracy: 0.9091 - val_loss: 0.2682 - val_accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 347ms/step - loss: 1.5847 - accuracy: 0.8636 - val_loss: 0.2482 - val_accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 342ms/step - loss: 1.3805 - accuracy: 0.9091 - val_loss: 0.2294 - val_accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 357ms/step - loss: 1.0643 - accuracy: 0.8636 - val_loss: 0.2112 - val_accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 348ms/step - loss: 1.4128 - accuracy: 0.8636 - val_loss: 0.1946 - val_accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 340ms/step - loss: 1.1973 - accuracy: 0.8182 - val_loss: 0.1704 - val_accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 339ms/step - loss: 1.2164 - accuracy: 0.8636 - val_loss: 0.1587 - val_accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 340ms/step - loss: 1.4708 - accuracy: 0.8636 - val_loss: 0.1479 - val_accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 347ms/step - loss: 1.2141 - accuracy: 0.9545 - val_loss: 0.1369 - val_accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 352ms/step - loss: 0.9347 - accuracy: 0.9545 - val_loss: 0.1261 - val_accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 348ms/step - loss: 0.9149 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 340ms/step - loss: 0.9163 - accuracy: 0.9091 - val_loss: 0.1078 - val_accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 370ms/step - loss: 1.2598 - accuracy: 0.9091 - val_loss: 0.0996 - val_accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 373ms/step - loss: 0.8512 - accuracy: 0.9545 - val_loss: 0.0920 - val_accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 372ms/step - loss: 1.1805 - accuracy: 0.8182 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 374ms/step - loss: 0.9467 - accuracy: 0.9545 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 348ms/step - loss: 0.6413 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 353ms/step - loss: 0.6885 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 363ms/step - loss: 0.6524 - accuracy: 0.9545 - val_loss: 0.0598 - val_accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 335ms/step - loss: 0.7526 - accuracy: 0.9545 - val_loss: 0.0543 - val_accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 336ms/step - loss: 0.8456 - accuracy: 0.9545 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 340ms/step - loss: 0.5337 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 347ms/step - loss: 0.6742 - accuracy: 0.9545 - val_loss: 0.0401 - val_accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 349ms/step - loss: 0.8463 - accuracy: 0.9545 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 347ms/step - loss: 0.8336 - accuracy: 0.9545 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 339ms/step - loss: 1.0488 - accuracy: 0.8636 - val_loss: 0.0303 - val_accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 349ms/step - loss: 0.7517 - accuracy: 0.9545 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 347ms/step - loss: 0.4463 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 364ms/step - loss: 0.6530 - accuracy: 0.9545 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 355ms/step - loss: 0.4491 - accuracy: 0.9545 - val_loss: 0.0224 - val_accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 383ms/step - loss: 0.5595 - accuracy: 0.9545 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 373ms/step - loss: 0.5209 - accuracy: 0.9545 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4553 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 353ms/step - loss: 0.8745 - accuracy: 0.9091 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 363ms/step - loss: 0.8108 - accuracy: 0.9091 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 367ms/step - loss: 0.5891 - accuracy: 0.9545 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 344ms/step - loss: 0.6653 - accuracy: 0.9545 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 339ms/step - loss: 0.6092 - accuracy: 0.9545 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 369ms/step - loss: 0.5961 - accuracy: 0.9545 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 369ms/step - loss: 0.5276 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 359ms/step - loss: 0.3238 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 357ms/step - loss: 0.3766 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 370ms/step - loss: 0.3309 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 371ms/step - loss: 0.4682 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 382ms/step - loss: 0.2911 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 363ms/step - loss: 0.3522 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 377ms/step - loss: 0.5294 - accuracy: 0.9545 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 370ms/step - loss: 0.2599 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 386ms/step - loss: 0.3127 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 345ms/step - loss: 0.2672 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 350ms/step - loss: 0.2406 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 366ms/step - loss: 0.4385 - accuracy: 0.9545 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 357ms/step - loss: 0.3305 - accuracy: 0.9545 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 352ms/step - loss: 0.2935 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 365ms/step - loss: 0.4674 - accuracy: 0.9545 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 363ms/step - loss: 0.2322 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 366ms/step - loss: 0.1790 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 362ms/step - loss: 0.2296 - accuracy: 0.9545 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 376ms/step - loss: 0.2341 - accuracy: 0.9545 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 394ms/step - loss: 0.3275 - accuracy: 0.9545 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 344ms/step - loss: 0.2562 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 377ms/step - loss: 0.2414 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 379ms/step - loss: 0.3283 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 372ms/step - loss: 0.2261 - accuracy: 0.9545 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 371ms/step - loss: 0.3175 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 370ms/step - loss: 0.2265 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 362ms/step - loss: 0.4586 - accuracy: 0.9545 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 377ms/step - loss: 0.1904 - accuracy: 0.9545 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 356ms/step - loss: 0.1622 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 380ms/step - loss: 0.1308 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 394ms/step - loss: 0.1275 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0952 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 367ms/step - loss: 0.1220 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 373ms/step - loss: 0.1697 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 371ms/step - loss: 0.2509 - accuracy: 0.9545 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 371ms/step - loss: 0.1253 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
