# %%
import os
import requests
import json
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import io
from io import BytesIO
from PIL import Image, ImageDraw
import pytz
import numpy as np
from ipywidgets import IntProgress
from IPython.display import display
import time
import pydot
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import ipyplot 
import shutil

totalDeImagens = 0

ids = np.array([1240610, 1210718, 1210702, 1200562, 6212124, 1200575, 1200570, 1200571, 
                1240903, 1210734, 1210707, 1200558, 1200554, 1210683, 7240919, 1210770, 
                1240566, 1240675])

data_array = np.empty(0)

def dict_to_array1D(input_dict):
    # Create an empty list to hold the values
    output_array = np.empty(0)
    # Loop over each key-value pair in the dictionary
    for date_dict in input_dict.values():
        for value in date_dict.values():
            # Append the value to the output array
            output_array = np.append(output_array,value)
    # Return the output array
    return output_array

def list_dataset_folders():
    folders = []
    folder_path = os.getcwd()
    for name in os.listdir(folder_path):
        if os.path.isdir(os.path.join(folder_path, name)):
            if name.endswith("dataset"):
                # and name != "dataset"
                #folder_name = name.replace("dataset", "")
                folders.append(name)
    return folders

specific_datasets = list_dataset_folders()

for dataset in specific_datasets:
    for stationFolder in ids:
        images_folder_path = dataset+'/images/'+str(stationFolder)+'/'
        # Get a list of all the files in the current folder
        file_list = os.listdir(images_folder_path)
        # Filter the list to only include folders files
        days_folders_list = [file for file in file_list if os.path.isdir(os.path.join(images_folder_path, file))]
        for day_folder in days_folders_list:
            current_path = images_folder_path + day_folder
            #Get a list of all files in the folder 
            files_list = os.listdir(current_path)
            # Filter the list to only include images files
            image_list = [file for file in files_list if file.endswith('.png')]
            totalDeImagens+=len(image_list)
            
for dataset in specific_datasets:
    for stationJson in ids:
        currentDir = dataset+'/precipitation/'+str(stationJson)+'.json'
        with open(currentDir) as f:
            # Load the JSON data
            data = json.load(f)
        f.close()
        current_data_array = np.empty(0)
        current_data_array = dict_to_array1D(data)
        data_array = np.concatenate((data_array, current_data_array))

# %%
print(f"Total De Dados: {len(data_array)} \nTotal De Imagens: {totalDeImagens}")
# Out:
# Total De Dados: 14813
# Total De Imagens: 14813

# %%
from ipywidgets import IntProgress
from IPython.display import display
import time

progress_bar_length = 4000
f = IntProgress(min=0, max=progress_bar_length) # instantiate the bar
display(f) # display the bar

for i in range(4001):
    print("")
    f.value+=1
# Out:
# IntProgress(value=0, max=4000)

# %%
import os
from PIL import Image

def list_folders_without_dataset():
    folders = []
    folder_path = os.getcwd()
    for name in os.listdir(folder_path):
        if os.path.isdir(os.path.join(folder_path, name)):
            if name.endswith("dataset"):
                # and name != "dataset"
                #folder_name = name.replace("dataset", "")
                folders.append(name)
    return folders

all_datasets=list_folders_without_dataset()

images = []

for unique_dataset in all_datasets:
    image_path=unique_dataset+'/images/1200554/2023-05-08/2023-05-08T0000.png'
    image = Image.open(image_path)
    images.append(image)

# %%
import ipyplot 



labels = all_datasets
ipyplot.plot_images(images,labels=labels,img_width=200)
image.close()
# Out:
# C:\Users\joao\AppData\Roaming\Python\Python39\site-packages\ipyplot\_utils.py:95: FutureWarning: The input object of type 'PngImageFile' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'PngImageFile', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   return np.asarray(seq, dtype=type(seq[0]))
#     <style>
#         #ipyplot-html-viewer-toggle-7vNJB2EAHsqAetH8NuALHS {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7vNJB2EAHsqAetH8NuALHS {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7vNJB2EAHsqAetH8NuALHS {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7vNJB2EAHsqAetH8NuALHS:checked ~ #ipyplot-html-viewer-textarea-7vNJB2EAHsqAetH8NuALHS {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7vNJB2EAHsqAetH8NuALHS:checked + #ipyplot-html-viewer-label-7vNJB2EAHsqAetH8NuALHS:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-7vNJB2EAHsqAetH8NuALHS">
#         <label id="ipyplot-html-viewer-label-7vNJB2EAHsqAetH8NuALHS" for="ipyplot-html-viewer-toggle-7vNJB2EAHsqAetH8NuALHS">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-7vNJB2EAHsqAetH8NuALHS" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-iYNYAj3sxPxeWTwpvv7mqu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-iYNYAj3sxPxeWTwpvv7mqu">
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-GGT58bZR9yq2kqChPs9zSt" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">135_rotated_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-GGT58bZR9yq2kqChPs9zSt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-9V32LECmtQ5aqgzMsVJjXi" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">135_rotated_horizontal_and_vertical_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-9V32LECmtQ5aqgzMsVJjXi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-fubUyAyWHuC82rChmEUz3y" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">135_rotated_horizontal_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-fubUyAyWHuC82rChmEUz3y">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-n3Bc4Y4gL6BHDXY6G2YziM" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">135_rotated_vertical_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-n3Bc4Y4gL6BHDXY6G2YziM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-6ryuHDr3Yawe4BTfBPgjHM" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">45_rotated_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-6ryuHDr3Yawe4BTfBPgjHM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-HXNXho9VC6ZMcBpCzFdAsE" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">45_rotated_horizontal_and_vertical_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-HXNXho9VC6ZMcBpCzFdAsE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-AbVrYkv7c74FeyAttSMJMm" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">45_rotated_horizontal_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-AbVrYkv7c74FeyAttSMJMm">
#                 <s
#         <style>
#         #ipyplot-imgs-container-div-iYNYAj3sxPxeWTwpvv7mqu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-iYNYAj3sxPxeWTwpvv7mqu">
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-GGT58bZR9yq2kqChPs9zSt" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">135_rotated_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-GGT58bZR9yq2kqChPs9zSt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-9V32LECmtQ5aqgzMsVJjXi" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">135_rotated_horizontal_and_vertical_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-9V32LECmtQ5aqgzMsVJjXi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-fubUyAyWHuC82rChmEUz3y" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">135_rotated_horizontal_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-fubUyAyWHuC82rChmEUz3y">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-n3Bc4Y4gL6BHDXY6G2YziM" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">135_rotated_vertical_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-n3Bc4Y4gL6BHDXY6G2YziM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-6ryuHDr3Yawe4BTfBPgjHM" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">45_rotated_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-6ryuHDr3Yawe4BTfBPgjHM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-HXNXho9VC6ZMcBpCzFdAsE" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">45_rotated_horizontal_and_vertical_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-HXNXho9VC6ZMcBpCzFdAsE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-AbVrYkv7c74FeyAttSMJMm" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">45_rotated_horizontal_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-AbVrYkv7c74FeyAttSMJMm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-9yRr7qstagyNYwGR3HBk62" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">45_rotated_vertical_flip_dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-9yRr7qstagyNYwGR3HBk62">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-bxdiL2YYJzWo6wPF7pvqo4" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dataset</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-bxdiL2YYJzWo6wPF7pvqo4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iYNYAj3sxPxeWTwpvv7mqu">
#         <div id="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu-oPJ3nu4VNNLfdP3iq8Nm3A" class="ipyplot-content-div-iYNYAj3sxPxeWTwpvv7mqu">
#             <h4 style="font-size: 12px; word-w
