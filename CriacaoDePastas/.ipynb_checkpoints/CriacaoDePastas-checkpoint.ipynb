# %%
import os

for i in range(101):
    os.mkdir(str(i)) #---Cria as pastas do 0 ao 100
print("Pastas criadas!")
# Out:
# Pastas criadas!

# %%
import requests
import json

DADOS_ULTIMAS_3_HORAS = "https://api.ipma.pt/open-data/observation/meteorology/stations/obs-surface.geojson" #por exemplo se forem 9PM tem os dados entre 5PM e 7PM de hora a hora para todas as estações
DADOS_ULTIMAS_24_HORAS = "https://api.ipma.pt/open-data/observation/meteorology/stations/observations.json" #tem os dados das ultimas 24 horas para algumas estações

class make_api_call:
    def get_data(self, api):
        response = requests.get(f"{api}")
        if response.status_code == 200:
            print("sucessfully fetched the data")
            return response.json()
        else:
            print(f"Hello there, there's a {response.status_code} error with your request")
            
#---Define a função que vai transformar o valor da precipatação para um valor de 0 a 100
#---https://www.ipma.pt/pt/oclima/extremos.clima/ Vou usar o valor máximo aqui como referencia

def normalize_precipitation_value(precipitation_value):
  return int(round((precipitation_value/240)*100,0)) #o valor normalizado ta a ser arredondado pq as pastas sao de valores inteiros

# %%
api_call_instance = make_api_call()
full_json_array = api_call_instance.get_data(DADOS_ULTIMAS_3_HORAS)
# Out:
# sucessfully fetched the data
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -31.1301,
#                     39.4582
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "W",
#                 "humidade": 61.0,
#                 "idDireccVento": 7,
#                 "idEstacao": 1200501,
#                 "intensidadeVento": 6.0,
#                 "intensidadeVentoKM": 21.6,
#                 "localEstacao": "Flores (Aeroporto)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1030.2,
#                 "radiacao": 1295.4,
#                 "temperatura": 18.4,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -31.1136,
#                     39.6739
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "W",
#                 "humidade": 71.0,
#                 "idDireccVento": 7,
#                 "idEstacao": 1200502,
#                 "intensidadeVento": 7.0,
#                 "intensidadeVentoKM": 25.2,
#                 "localEstacao": "Corvo (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1030.3,
#                 "radiacao": -99.0,
#                 "temperatura": 17.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -28.4414,
#                     38.5522
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NW",
#                 "humidade": 67.0,
#                 "idDireccVento": 8,
#                 "idEstacao": 1200504,
#                 "intensidadeVento": 3.4,
#                 "intensidadeVentoKM": 12.2,
#                 "localEstacao": "Pico (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1031.1,
#                 "radiacao": 1458.7,
#                 "temperatura": 17.4,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -28.6322,
#                     38.5408
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NW",
#                 "humidade": 74.0,
#                 "idDireccVento": 8,
#                 "idEstacao": 1200506,
#                 "intensidadeVento": 7.6,
#                 "intensidadeVentoKM": 27.4,
#                 "localEstacao": "Horta (Obs. Pr\u00edncipe Alberto M\u00f3naco)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1031.4,
#                 "radiacao": 1090.8,
#                 "temperatura": 17.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -28.0285,
#                     39.0904
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NW",
#                 "humidade": 74.0,
#                 "idDireccVento": 8,
#                 "idEstacao": 1200507,
#                 "intensidadeVento": 4.9,
#                 "intensidadeVentoKM": 17.6,
#                 "localEstacao": "Graciosa (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1031.1,
#                 "radiacao": 1740.3,
#                 "temperatura": 16.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -28.17,
#                     38.66
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "W",
#                 "humidade": 72.0,
#                 "idDireccVento": 7,
#                 "idEstacao": 1200510,
#                 "intensidadeVento": 3.6,
#                 "intensidadeVentoKM": 13.0,
#                 "localEstacao": "S\u00e3o Jorge",
#                 "precAcumulada": 0.0,
#                 "pressao": 1031.1,
#                 "radiacao": 3330.5,
#                 "temperatura": 16.9,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -27.2166,
#                     38.6659
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "W",
#                 "humidade": 71.0,
#                 "idDireccVento": 7,
#                 "idEstacao": 1200511,
#                 "intensidadeVento": 5.2,
#                 "intensidadeVentoKM": 18.7,
#                 "localEstacao": "Angra do Hero\u00edsmo",
#                 "precAcumulada": 0.0,
#                 "pressao": 1030.8,
#                 "radiacao": -99.0,
#                 "temperatura": 17.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -25.6953,
#                     37.7441
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 70.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1200512,
#                 "intensidadeVento": 5.5,
#                 "intensidadeVentoKM": 19.8,
#                 "localEstacao": "Ponta Delgada (Aeroporto)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1030.7,
#                 "radiacao": -99.0,
#                 "temperatura": 16.7,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -25.1679,
#                     36.9672
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "N",
#                 "humidade": 64.0,
#                 "idDireccVento": 1,
#                 "idEstacao": 1200515,
#                 "intensidadeVento": 6.0,
#                 "intensidadeVentoKM": 21.6,
#                 "localEstacao": "Santa Maria (Aeroporto)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1030.5,
#                 "radiacao": 2785.2,
#                 "temperatura": 17.6,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -16.7761,
#                     32.6969
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "N",
#                 "humidade": 77.0,
#                 "idDireccVento": 1,
#                 "idEstacao": 1200521,
#                 "intensidadeVento": 8.4,
#                 "intensidadeVentoKM": 30.2,
#                 "localEstacao": "Santa Catarina (Aeroporto)",
#                 "precAcumulada": 0.6,
#                 "pressao": 1018.7,
#                 "radiacao": 2997.9,
#                 "temperatura": 17.6,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -16.888,
#                     32.6479
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "SE",
#                 "humidade": 60.0,
#                 "idDireccVento": 4,
#                 "idEstacao": 1200522,
#                 "intensidadeVento": 2.6,
#                 "intensidadeVentoKM": 9.4,
#                 "localEstacao": "Funchal",
#                 "precAcumulada": 0.0,
#                 "pressao": 1018.3,
#                 "radiacao": 1656.3,
#                 "temperatura": 20.1,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -16.3487,
#                     33.074
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "N",
#                 "humidade": 67.0,
#                 "idDireccVento": 9,
#                 "idEstacao": 1200524,
#                 "intensidadeVento": 9.7,
#                 "intensidadeVentoKM": 34.9,
#                 "localEstacao": "Porto Santo (Aeroporto)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1018.2,
#                 "radiacao": 3134.4,
#                 "temperatura": 19.6,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -9.4074,
#                     39.38
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "N",
#                 "humidade": 73.0,
#                 "idDireccVento": 1,
#                 "idEstacao": 1200531,
#                 "intensidadeVento": 6.6,
#                 "intensidadeVentoKM": 23.8,
#                 "localEstacao": "Cabo Carvoeiro",
#                 "precAcumulada": 0.0,
#                 "pressao": 1013.4,
#                 "radiacao": -99.0,
#                 "temperatura": 17.1,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.9491,
#                     37.0128
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "W",
#                 "humidade": 49.0,
#                 "idDireccVento": 7,
#                 "idEstacao": 1200533,
#                 "intensidadeVento": 2.2,
#                 "intensidadeVentoKM": 7.9,
#                 "localEstacao": "Sagres",
#                 "precAcumulada": -99.0,
#                 "pressao": 1011.5,
#                 "radiacao": -99.0,
#                 "temperatura": 19.6,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -9.1497,
#                     38.7191
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "N",
#                 "humidade": 25.0,
#                 "idDireccVento": 1,
#                 "idEstacao": 1200535,
#                 "intensidadeVento": 3.7,
#                 "intensidadeVentoKM": 13.3,
#                 "localEstacao": "Lisboa (Geof\u00edsico)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1012.0,
#                 "radiacao": 3035.3,
#                 "temperatura": 23.9,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.8383,
#                     37.9545
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NW",
#                 "humidade": 52.0,
#                 "idDireccVento": 8,
#                 "idEstacao": 1200541,
#                 "intensidadeVento": 3.5,
#                 "intensidadeVentoKM": 12.6,
#                 "localEstacao": "Sines",
#                 "precAcumulada": 0.0,
#                 "pressao": 1011.4,
#                 "radiacao": 2516.8,
#                 "temperatura": 20.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.6813,
#                     41.2335
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 25.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1200545,
#                 "intensidadeVento": 4.9,
#                 "intensidadeVentoKM": 17.6,
#                 "localEstacao": "Pedras Rubras",
#                 "precAcumulada": 0.0,
#                 "pressao": 1015.1,
#                 "radiacao": 2758.0,
#                 "temperatura": 22.1,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.4667,
#                     40.1501
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 24.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1200548,
#                 "intensidadeVento": 2.9,
#                 "intensidadeVentoKM": 10.4,
#                 "localEstacao": "Coimbra (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1013.3,
#                 "radiacao": 2922.7,
#                 "temperatura": 21.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.8046,
#                     41.6489
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NW",
#                 "humidade": 54.0,
#                 "idDireccVento": 8,
#                 "idEstacao": 1200551,
#                 "intensidadeVento": 4.1,
#                 "intensidadeVentoKM": 14.8,
#                 "localEstacao": "Viana Castelo, Chaf\u00e9",
#                 "precAcumulada": 0.0,
#                 "pressao": 1015.2,
#                 "radiacao": 3080.8,
#                 "temperatura": 19.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.972,
#                     37.0166
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 54.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1200554,
#                 "intensidadeVento": 8.9,
#                 "intensidadeVentoKM": 32.0,
#                 "localEstacao": "Faro (Aeroporto)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1011.6,
#                 "radiacao": 2908.9,
#                 "temperatura": 20.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.8834,
#                     38.5334
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "SE",
#                 "humidade": 29.0,
#                 "idDireccVento": 4,
#                 "idEstacao": 1200558,
#                 "intensidadeVento": 2.6,
#                 "intensidadeVentoKM": 9.4,
#                 "localEstacao": "\u00c9vora (C.Coordena\u00e7\u00e3o)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1011.0,
#                 "radiacao": 3066.5,
#                 "temperatura": 23.9,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.8875,
#                     40.7264
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 21.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1200559,
#                 "intensidadeVento": 5.9,
#                 "intensidadeVentoKM": 21.2,
#                 "localEstacao": "Viseu (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1014.0,
#                 "radiacao": -99.0,
#                 "temperatura": 17.6,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.8959,
#                     40.7149
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 23.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1200560,
#                 "intensidadeVento": 6.6,
#                 "intensidadeVentoKM": 23.8,
#                 "localEstacao": "Viseu (C.Coordena\u00e7\u00e3o)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1014.6,
#                 "radiacao": -99.0,
#                 "temperatura": 17.7,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.8673,
#                     38.0249
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "SE",
#                 "humidade": 35.0,
#                 "idDireccVento": 4,
#                 "idEstacao": 1200562,
#                 "intensidadeVento": 2.3,
#                 "intensidadeVentoKM": 8.3,
#                 "localEstacao": "Beja",
#                 "precAcumulada": 0.0,
#                 "pressao": 1010.6,
#                 "radiacao": 2624.5,
#                 "temperatura": 22.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.7171,
#                     41.2742
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 18.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1200567,
#                 "intensidadeVento": 2.0,
#                 "intensidadeVentoKM": 7.2,
#                 "localEstacao": "Vila Real",
#                 "precAcumulada": 0.0,
#                 "pressao": 1015.1,
#                 "radiacao": 2903.3,
#                 "temperatura": 19.5,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.5587,
#                     40.4114
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "SE",
#                 "humidade": 25.0,
#                 "idDireccVento": 4,
#                 "idEstacao": 1200568,
#                 "intensidadeVento": 4.4,
#                 "intensidadeVentoKM": 15.8,
#                 "localEstacao": "Penhas Douradas",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3308.5,
#                 "temperatura": 13.1,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.4668,
#                     39.8334
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 17.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1200570,
#                 "intensidadeVento": 4.2,
#                 "intensidadeVentoKM": 15.1,
#                 "localEstacao": "Castelo Branco",
#                 "precAcumulada": 0.0,
#                 "pressao": 1012.5,
#                 "radiacao": 2964.0,
#                 "temperatura": 22.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.42,
#                     39.2955
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 18.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1200571,
#                 "intensidadeVento": 3.3,
#                 "intensidadeVentoKM": 11.9,
#                 "localEstacao": "Portalegre",
#                 "precAcumulada": 0.0,
#                 "pressao": 1011.6,
#                 "radiacao": 2353.1,
#                 "temperatura": 20.6,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -6.7428,
#                     41.8039
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 12.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1200575,
#                 "intensidadeVento": 4.2,
#                 "intensidadeVentoKM": 15.1,
#                 "localEstacao": "Bragan\u00e7a",
#                 "precAcumulada": 0.0,
#                 "pressao": 1016.2,
#                 "radiacao": 3248.4,
#                 "temperatura": 18.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -6.708,
#                     41.8576
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 14.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1200576,
#                 "intensidadeVento": 6.4,
#                 "intensidadeVentoKM": 23.0,
#                 "localEstacao": "Bragan\u00e7a (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1016.3,
#                 "radiacao": -99.0,
#                 "temperatura": 17.9,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -9.1275,
#                     38.7662
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 28.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1200579,
#                 "intensidadeVento": 2.9,
#                 "intensidadeVentoKM": 10.4,
#                 "localEstacao": "Lisboa (G.Coutinho)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1011.9,
#                 "radiacao": 3084.2,
#                 "temperatura": 24.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -25.6623,
#                     37.7464
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 60.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210513,
#                 "intensidadeVento": 3.1,
#                 "intensidadeVentoKM": 11.2,
#                 "localEstacao": "Ponta Delgada (Obs. Afonso Chaves)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3332.7,
#                 "temperatura": 18.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.729,
#                     37.5471
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 46.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210577,
#                 "intensidadeVento": 3.1,
#                 "intensidadeVentoKM": 11.2,
#                 "localEstacao": "Odemira, S. Teot\u00f3nio",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2700.9,
#                 "temperatura": 22.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.6668,
#                     41.9667
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "---",
#                 "humidade": 42.0,
#                 "idDireccVento": 0,
#                 "idEstacao": 1210604,
#                 "intensidadeVento": 3.9,
#                 "intensidadeVentoKM": 14.0,
#                 "localEstacao": "V.N.Cerveira (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1015.5,
#                 "radiacao": 2972.5,
#                 "temperatura": 22.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.3833,
#                     42.0667
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 38.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210605,
#                 "intensidadeVento": 3.8,
#                 "intensidadeVentoKM": 13.7,
#                 "localEstacao": "Mon\u00e7\u00e3o, Valinha",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2972.5,
#                 "temperatura": 21.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.1833,
#                     42.0333
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "N",
#                 "humidade": 40.0,
#                 "idDireccVento": 1,
#                 "idEstacao": 1210606,
#                 "intensidadeVento": 4.6,
#                 "intensidadeVentoKM": 16.6,
#                 "localEstacao": "Lamas de Mouro, P.Ribeiro",
#                 "precAcumulada": 0.0,
#                 "pressao": 1015.2,
#                 "radiacao": 3040.6,
#                 "temperatura": 17.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.788,
#                     41.8228
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 14.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210611,
#                 "intensidadeVento": 3.7,
#                 "intensidadeVentoKM": 13.3,
#                 "localEstacao": "Montalegre",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 1925.0,
#                 "temperatura": 14.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.0034,
#                     41.8434
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 17.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210612,
#                 "intensidadeVento": 6.7,
#                 "intensidadeVentoKM": 24.1,
#                 "localEstacao": "Vinhais",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 16.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.5667,
#                     41.7501
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 25.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210615,
#                 "intensidadeVento": 2.2,
#                 "intensidadeVentoKM": 7.9,
#                 "localEstacao": "Ponte de Lima (Escola agr\u00edcola)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3045.7,
#                 "temperatura": 23.5,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.4654,
#                     41.7252
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 14.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210616,
#                 "intensidadeVento": 5.6,
#                 "intensidadeVentoKM": 20.2,
#                 "localEstacao": "Chaves (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1015.4,
#                 "radiacao": 2067.1,
#                 "temperatura": 20.6,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.0167,
#                     41.7167
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "---",
#                 "humidade": 15.0,
#                 "idDireccVento": 0,
#                 "idEstacao": 1210619,
#                 "intensidadeVento": -99.0,
#                 "intensidadeVentoKM": -99.0,
#                 "localEstacao": "Cabril",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 20.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.45,
#                     41.5668
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "N",
#                 "humidade": 22.0,
#                 "idDireccVento": 9,
#                 "idEstacao": 1210622,
#                 "intensidadeVento": 2.0,
#                 "intensidadeVentoKM": 7.2,
#                 "localEstacao": "Braga, Merelim",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2908.3,
#                 "temperatura": 23.1,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.9667,
#                     41.5333
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 15.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210630,
#                 "intensidadeVento": 4.2,
#                 "intensidadeVentoKM": 15.1,
#                 "localEstacao": "Cabeceiras de Basto",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2638.6,
#                 "temperatura": 21.7,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.1908,
#                     41.5148
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 16.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210632,
#                 "intensidadeVento": 4.6,
#                 "intensidadeVentoKM": 16.6,
#                 "localEstacao": "Mirandela",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 21.6,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -6.7833,
#                     41.5667
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 19.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210633,
#                 "intensidadeVento": 3.6,
#                 "intensidadeVentoKM": 13.0,
#                 "localEstacao": "Macedo de Cavaleiros, Bagueixe",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 19.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -6.2833,
#                     41.5167
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 23.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210635,
#                 "intensidadeVento": 6.6,
#                 "intensidadeVentoKM": 23.8,
#                 "localEstacao": "Miranda do Douro",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 17.4,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -6.7333,
#                     41.3333
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 24.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210637,
#                 "intensidadeVento": 9.5,
#                 "intensidadeVentoKM": 34.2,
#                 "localEstacao": "Mogadouro",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3293.2,
#                 "temperatura": 16.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.3801,
#                     41.2737
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 17.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210643,
#                 "intensidadeVento": 4.4,
#                 "intensidadeVentoKM": 15.8,
#                 "localEstacao": "Pa\u00e7os Ferreira",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 20.8,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.2833,
#                     41.2333
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 27.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210644,
#                 "intensidadeVento": 4.8,
#                 "intensidadeVentoKM": 17.3,
#                 "localEstacao": "Carraz\u00eada de Ansi\u00e3es",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2644.2,
#                 "temperatura": 16.7,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.6445,
#                     41.1844
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 19.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210649,
#                 "intensidadeVento": 2.8,
#                 "intensidadeVentoKM": 10.1,
#                 "localEstacao": "S. Gens",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 1561.0,
#                 "temperatura": 22.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.0167,
#                     41.1833
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 22.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210654,
#                 "intensidadeVento": 4.7,
#                 "intensidadeVentoKM": 16.9,
#                 "localEstacao": "Moncorvo",
#                 "precAcumulada": 0.0,
#                 "pressao": 1015.3,
#                 "radiacao": 2722.9,
#                 "temperatura": 19.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.549,
#                     41.1728
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "S",
#                 "humidade": 17.0,
#                 "idDireccVento": 5,
#                 "idEstacao": 1210655,
#                 "intensidadeVento": 4.7,
#                 "intensidadeVentoKM": 16.9,
#                 "localEstacao": "Pinh\u00e3o, Santa B\u00e1rbara",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 22.7,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.249,
#                     41.1459
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 28.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210657,
#                 "intensidadeVento": 4.1,
#                 "intensidadeVentoKM": 14.8,
#                 "localEstacao": "Luzim",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2784.4,
#                 "temperatura": 19.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.6,
#                     40.9833
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 26.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210663,
#                 "intensidadeVento": 4.3,
#                 "intensidadeVentoKM": 15.5,
#                 "localEstacao": "Moimenta da Beira",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2592.6,
#                 "temperatura": 18.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.3667,
#                     40.7833
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 33.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210666,
#                 "intensidadeVento": 5.8,
#                 "intensidadeVentoKM": 20.9,
#                 "localEstacao": "Trancoso, Bandarra",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3212.7,
#                 "temperatura": 14.7,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.25,
#                     40.9333
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "SE",
#                 "humidade": 19.0,
#                 "idDireccVento": 4,
#                 "idEstacao": 1210669,
#                 "intensidadeVento": 2.5,
#                 "intensidadeVentoKM": 9.0,
#                 "localEstacao": "Arouca",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2353.2,
#                 "temperatura": 21.4,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -6.8833,
#                     40.75
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 34.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210671,
#                 "intensidadeVento": 4.9,
#                 "intensidadeVentoKM": 17.6,
#                 "localEstacao": "Fig. de Castelo Rodrigo (Vila Torpim)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3060.0,
#                 "temperatura": 17.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.2667,
#                     40.5333
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 30.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210683,
#                 "intensidadeVento": 4.5,
#                 "intensidadeVentoKM": 16.2,
#                 "localEstacao": "Guarda",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3316.3,
#                 "temperatura": 14.2,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.85,
#                     40.5167
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 28.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 1210685,
#                 "intensidadeVento": 5.7,
#                 "intensidadeVentoKM": 20.5,
#                 "localEstacao": "Nelas",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 2676.1,
#                 "temperatura": 18.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.4823,
#                     40.2643
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 23.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210687,
#                 "intensidadeVento": 5.5,
#                 "intensidadeVentoKM": 19.8,
#                 "localEstacao": "Covilh\u00e3 (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3195.8,
#                 "temperatura": 19.5,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.3893,
#                     40.3543
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 23.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210690,
#                 "intensidadeVento": 3.6,
#                 "intensidadeVentoKM": 13.0,
#                 "localEstacao": "Aldeia Souto (Quinta Lageosa)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": 3237.8,
#                 "temperatura": 19.2,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.2441,
#                     40.1439
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "---",
#                 "humidade": 36.0,
#                 "idDireccVento": 0,
#                 "idEstacao": 1210697,
#                 "intensidadeVento": 4.0,
#                 "intensidadeVentoKM": 14.4,
#                 "localEstacao": "Lous\u00e3 (Aer\u00f3dromo)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 24.0,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.5536,
#                     40.1406
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 18.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 1210698,
#                 "intensidadeVento": 4.8,
#                 "intensidadeVentoKM": 17.3,
#                 "localEstacao": "Fund\u00e3o",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 19.3,
#                 "time": "2023-04-04T14:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.6596,
#                     40.6353
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NW",
#                 "humidade": 41.0,
#                 "idDireccVento": 8,
#                 "idEstacao": 1210702,
#                 "intensidadeVento": 4.5,
#                 "intensidadeVentoKM": 16.2,
#                 "localEstacao": "Aveiro (Universidade)",
# ...
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.6271,
#                     41.5294
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 14.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 6212125,
#                 "intensidadeVento": 1.2,
#                 "intensidadeVentoKM": 4.3,
#                 "localEstacao": "Barcelos (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1015.0,
#                 "radiacao": 2262.0,
#                 "temperatura": 24.6,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.7798,
#                     41.5265
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "---",
#                 "humidade": 65.0,
#                 "idDireccVento": 0,
#                 "idEstacao": 6212126,
#                 "intensidadeVento": -99.0,
#                 "intensidadeVentoKM": -99.0,
#                 "localEstacao": "Esposende (CIM)",
#                 "precAcumulada": -99.0,
#                 "pressao": 1014.6,
#                 "radiacao": -99.0,
#                 "temperatura": 18.0,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.9263,
#                     40.4672
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": -99.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213012,
#                 "intensidadeVento": 5.8,
#                 "intensidadeVentoKM": 20.9,
#                 "localEstacao": "Carregal do Sal(CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 21.2,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.8832,
#                     40.9809
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 24.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213013,
#                 "intensidadeVento": 5.2,
#                 "intensidadeVentoKM": 18.7,
#                 "localEstacao": "Castro Daire / M\u00e9zio (CIM)",
#                 "precAcumulada": -99.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 15.8,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.6084,
#                     40.611
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 23.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 6213014,
#                 "intensidadeVento": 5.8,
#                 "intensidadeVentoKM": 20.9,
#                 "localEstacao": "Mangualde / Ch\u00e3s de Tavares  (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 19.0,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.6966,
#                     40.6571
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 24.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 6213017,
#                 "intensidadeVento": 5.7,
#                 "intensidadeVentoKM": 20.5,
#                 "localEstacao": "Penalva do Castelo (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 20.1,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.7202,
#                     40.7607
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 19.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213020,
#                 "intensidadeVento": 6.3,
#                 "intensidadeVentoKM": 22.7,
#                 "localEstacao": "Sat\u00e3o (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 18.7,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.2083,
#                     40.5458
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 22.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 6213021,
#                 "intensidadeVento": 8.7,
#                 "intensidadeVentoKM": 31.3,
#                 "localEstacao": "Tondela, Caramulinho ",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 15.1,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.7272,
#                     40.8559
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 30.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213022,
#                 "intensidadeVento": 4.4,
#                 "intensidadeVentoKM": 15.8,
#                 "localEstacao": "Vila Nova do Paiva (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 17.2,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.0511,
#                     40.6441
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 22.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 6213023,
#                 "intensidadeVento": 5.1,
#                 "intensidadeVentoKM": 18.4,
#                 "localEstacao": "Vouzela (CIM)",
#                 "precAcumulada": -99.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 17.0,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.9744,
#                     40.2746
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 26.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213611,
#                 "intensidadeVento": 3.9,
#                 "intensidadeVentoKM": 14.0,
#                 "localEstacao": "Arganil / Aer\u00f3dromo (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 23.1,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.5776,
#                     40.3419
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 23.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213612,
#                 "intensidadeVento": 4.5,
#                 "intensidadeVentoKM": 16.2,
#                 "localEstacao": "Cantanhede / Fonte Dom Pedro (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 22.3,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.3749,
#                     40.3308
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 25.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213613,
#                 "intensidadeVento": 4.0,
#                 "intensidadeVentoKM": 14.4,
#                 "localEstacao": "Coimbra / Mata de S\u00e3o Pedro (CIM)",
#                 "precAcumulada": -99.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 21.4,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.4388,
#                     40.3733
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 22.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213615,
#                 "intensidadeVento": 3.0,
#                 "intensidadeVentoKM": 10.8,
#                 "localEstacao": "Mealhada / Quinta do Vale (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 23.0,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.2321,
#                     40.4262
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": -99.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213616,
#                 "intensidadeVento": 6.0,
#                 "intensidadeVentoKM": 21.6,
#                 "localEstacao": "Mort\u00e1gua / Aer\u00f3dromo (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": -99.0,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.1987,
#                     40.2809
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 22.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 6213617,
#                 "intensidadeVento": 4.5,
#                 "intensidadeVentoKM": 16.2,
#                 "localEstacao": "Penacova / Hombres (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 22.7,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.242,
#                     40.2114
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 23.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213619,
#                 "intensidadeVento": 3.9,
#                 "intensidadeVentoKM": 14.0,
#                 "localEstacao": "Vila Nova de Poiares (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 23.3,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -7.868,
#                     40.4133
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 21.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213620,
#                 "intensidadeVento": 7.8,
#                 "intensidadeVentoKM": 28.1,
#                 "localEstacao": "Oliveira do Hospital (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 21.7,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -8.5049,
#                     40.0293
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "NE",
#                 "humidade": 32.0,
#                 "idDireccVento": 2,
#                 "idEstacao": 6213621,
#                 "intensidadeVento": 5.8,
#                 "intensidadeVentoKM": 20.9,
#                 "localEstacao": "Soure (CIM)",
#                 "precAcumulada": 0.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": 18.3,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -9.1649,
#                     38.7239
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "E",
#                 "humidade": 27.0,
#                 "idDireccVento": 3,
#                 "idEstacao": 7240919,
#                 "intensidadeVento": 2.1,
#                 "intensidadeVentoKM": 7.6,
#                 "localEstacao": "Lisboa, Amoreiras (Lic. Franc\u00eas)",
#                 "precAcumulada": 0.0,
#                 "pressao": 1011.5,
#                 "radiacao": -99.0,
#                 "temperatura": 26.3,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -25.0917,
#                     36.9542
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "descDirVento": "---",
#                 "humidade": 68.0,
#                 "idDireccVento": 0,
#                 "idEstacao": 11217160,
#                 "intensidadeVento": -99.0,
#                 "intensidadeVentoKM": -99.0,
#                 "localEstacao": "Santa Maria / Praia Formosa (DRAAC)",
#                 "precAcumulada": -99.0,
#                 "pressao": -99.0,
#                 "radiacao": -99.0,
#                 "temperatura": -99.0,
#                 "time": "2023-04-04T16:00:00"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Extract specific attributes from each feature in the GeoJSON and store them in a list
selected_attributes = []

for feature in full_json_array['features']:
    # Extract only the 'name' and 'population' attributes from each feature
    idEstacao = feature['properties']['idEstacao']
    localEstacao = feature['properties']['localEstacao']
    precAcumulada = feature['properties']['precAcumulada']
    
    # Create a new dictionary with the selected attributes and append it to the list
    selected_attributes.append({'idEstacao': idEstacao, 'localEstacao': localEstacao, 'precAcumuladaNormalizada' : normalize_precipitation_value(max(0, precAcumulada))})

# Print the list of selected attributes
# print(json.dumps(selected_attributes, indent=2))
# Out:
# [
#   {
#     "idEstacao": 1200501,
#     "localEstacao": "Flores (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200502,
#     "localEstacao": "Corvo (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200504,
#     "localEstacao": "Pico (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200506,
#     "localEstacao": "Horta (Obs. Pr\u00edncipe Alberto M\u00f3naco)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200507,
#     "localEstacao": "Graciosa (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200510,
#     "localEstacao": "S\u00e3o Jorge",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200511,
#     "localEstacao": "Angra do Hero\u00edsmo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200512,
#     "localEstacao": "Ponta Delgada (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200515,
#     "localEstacao": "Santa Maria (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200521,
#     "localEstacao": "Santa Catarina (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200522,
#     "localEstacao": "Funchal",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200524,
#     "localEstacao": "Porto Santo (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200531,
#     "localEstacao": "Cabo Carvoeiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200533,
#     "localEstacao": "Sagres",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200535,
#     "localEstacao": "Lisboa (Geof\u00edsico)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200541,
#     "localEstacao": "Sines",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200545,
#     "localEstacao": "Pedras Rubras",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200548,
#     "localEstacao": "Coimbra (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200551,
#     "localEstacao": "Viana Castelo, Chaf\u00e9",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200554,
#     "localEstacao": "Faro (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200558,
#     "localEstacao": "\u00c9vora (C.Coordena\u00e7\u00e3o)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200559,
#     "localEstacao": "Viseu (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200560,
#     "localEstacao": "Viseu (C.Coordena\u00e7\u00e3o)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200562,
#     "localEstacao": "Beja",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200567,
#     "localEstacao": "Vila Real",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200568,
#     "localEstacao": "Penhas Douradas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200570,
#     "localEstacao": "Castelo Branco",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200571,
#     "localEstacao": "Portalegre",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200575,
#     "localEstacao": "Bragan\u00e7a",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200576,
#     "localEstacao": "Bragan\u00e7a (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200579,
#     "localEstacao": "Lisboa (G.Coutinho)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210513,
#     "localEstacao": "Ponta Delgada (Obs. Afonso Chaves)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210577,
#     "localEstacao": "Odemira, S. Teot\u00f3nio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210604,
#     "localEstacao": "V.N.Cerveira (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210605,
#     "localEstacao": "Mon\u00e7\u00e3o, Valinha",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210606,
#     "localEstacao": "Lamas de Mouro, P.Ribeiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210611,
#     "localEstacao": "Montalegre",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210612,
#     "localEstacao": "Vinhais",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210615,
#     "localEstacao": "Ponte de Lima (Escola agr\u00edcola)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210616,
#     "localEstacao": "Chaves (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210619,
#     "localEstacao": "Cabril",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210622,
#     "localEstacao": "Braga, Merelim",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210630,
#     "localEstacao": "Cabeceiras de Basto",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210632,
#     "localEstacao": "Mirandela",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210633,
#     "localEstacao": "Macedo de Cavaleiros, Bagueixe",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210635,
#     "localEstacao": "Miranda do Douro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210637,
#     "localEstacao": "Mogadouro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210643,
#     "localEstacao": "Pa\u00e7os Ferreira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210644,
#     "localEstacao": "Carraz\u00eada de Ansi\u00e3es",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210649,
#     "localEstacao": "S. Gens",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210654,
#     "localEstacao": "Moncorvo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210655,
#     "localEstacao": "Pinh\u00e3o, Santa B\u00e1rbara",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210657,
#     "localEstacao": "Luzim",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210663,
#     "localEstacao": "Moimenta da Beira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210666,
#     "localEstacao": "Trancoso, Bandarra",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210669,
#     "localEstacao": "Arouca",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210671,
#     "localEstacao": "Fig. de Castelo Rodrigo (Vila Torpim)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210683,
#     "localEstacao": "Guarda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210685,
#     "localEstacao": "Nelas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210687,
#     "localEstacao": "Covilh\u00e3 (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210690,
#     "localEstacao": "Aldeia Souto (Quinta Lageosa)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210697,
#     "localEstacao": "Lous\u00e3 (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210698,
#     "localEstacao": "Fund\u00e3o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210702,
#     "localEstacao": "Aveiro (Universidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210704,
#     "localEstacao": "Dunas de Mira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210705,
#     "localEstacao": "Anadia",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210707,
#     "localEstacao": "Coimbra, Bencanta",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210713,
#     "localEstacao": "Figueira da Foz, Vila Verde",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210716,
#     "localEstacao": "Ansi\u00e3o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210718,
#     "localEstacao": "Leiria (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210721,
#     "localEstacao": "S\u00e3o Pedro de Moel",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210724,
#     "localEstacao": "Tomar, Valdonas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210726,
#     "localEstacao": "Alcoba\u00e7a",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210729,
#     "localEstacao": "Rio Maior",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210734,
#     "localEstacao": "Santar\u00e9m, Fonte Boa",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210739,
#     "localEstacao": "Torres Vedras, Dois Portos",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210744,
#     "localEstacao": "Coruche (Est. de Regadio - I.N.I.A.)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210746,
#     "localEstacao": "Santa Cruz (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210750,
#     "localEstacao": "Cabo da Roca",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210762,
#     "localEstacao": "Lisboa, Tapada da Ajuda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210765,
#     "localEstacao": "Cabo Raso",
#     "precAcumuladaNormalizada": 1
#   },
#   {
#     "idEstacao": 1210766,
#     "localEstacao": "Barreiro, Lavradio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210767,
#     "localEstacao": "Peg\u00f5es",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210770,
#     "localEstacao": "Set\u00fabal (Est. de Fruticultura)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210773,
#     "localEstacao": "Almada, P.Rainha",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210776,
#     "localEstacao": "Alc\u00e1cer do Sal, Barrosinha",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210783,
#     "localEstacao": "Alvalade",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210788,
#     "localEstacao": "Zambujeira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210789,
#     "localEstacao": "Aljezur",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210790,
#     "localEstacao": "Fo\u00eda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210800,
#     "localEstacao": "Sabugal, Martim Rei",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210803,
#     "localEstacao": "Zebreira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210806,
#     "localEstacao": "Proen\u00e7a-a-Nova, P.Moitas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210812,
#     "localEstacao": "Alvega",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210824,
#     "localEstacao": "Avis, Benavila (Esc. Abreu Callado)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210826,
#     "localEstacao": "Mora",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210835,
#     "localEstacao": "Elvas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210837,
#     "localEstacao": "Estremoz",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210847,
#     "localEstacao": "Viana do Alentejo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210848,
#     "localEstacao": "Portel, Oriola",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210851,
#     "localEstacao": "Amareleja",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210863,
#     "localEstacao": "M\u00e9rtola, Vale Formoso",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210864,
#     "localEstacao": "Castro Verde, N.Corvo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210866,
#     "localEstacao": "Vila Real de S.Ant\u00f3nio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210867,
#     "localEstacao": "Castro Marim (RN Sapal)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210874,
#     "localEstacao": "Albufeira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210878,
#     "localEstacao": "Portim\u00e3o (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210881,
#     "localEstacao": "Olh\u00e3o, EPPO",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210883,
#     "localEstacao": "Tavira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210932,
#     "localEstacao": "S. Miguel, Nordeste",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210956,
#     "localEstacao": "Madeira, Porto Moniz",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210960,
#     "localEstacao": "Madeira, S. Jorge, Santana",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210965,
#     "localEstacao": "Madeira, Santana",
#     "precAcumuladaNormalizada": 1
#   },
#   {
#     "idEstacao": 1210967,
#     "localEstacao": "Madeira, S\u00e3o Vicente",
#     "precAcumuladaNormalizada": 3
#   },
#   {
#     "idEstacao": 1210970,
#     "localEstacao": "Madeira, Bica da Cana",
#     "precAcumuladaNormalizada": 3
#   },
#   {
#     "idEstacao": 1210972,
#     "localEstacao": "Pico Alto",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210973,
#     "localEstacao": "Madeira, Areeiro",
#     "precAcumuladaNormalizada": 2
#   },
#   {
#     "idEstacao": 1210974,
#     "localEstacao": "Madeira, Pico do Areeiro",
#     "precAcumuladaNormalizada": 2
#   },
#   {
#     "idEstacao": 1210975,
#     "localEstacao": "Madeira, Santo da Serra",
#     "precAcumuladaNormalizada": 1
#   },
#   {
#     "idEstacao": 1210976,
#     "localEstacao": "Monte ",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210977,
#     "localEstacao": "Madeira, Cancela, Funchal",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210978,
#     "localEstacao": "Madeira, Cani\u00e7al, S. Louren\u00e7o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210980,
#     "localEstacao": "Madeira, Lombo da Ter\u00e7a",
#     "precAcumuladaNormalizada": 2
#   },
#   {
#     "idEstacao": 1210984,
#     "localEstacao": "Madeira, Quinta Grande",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210986,
#     "localEstacao": "Madeira, Ponta do Sol",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210987,
#     "localEstacao": "Madeira, Prazeres",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210990,
#     "localEstacao": "Madeira, Calheta",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240546,
#     "localEstacao": "Serra do Pilar",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240566,
#     "localEstacao": "Vila Real (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240610,
#     "localEstacao": "Viana do Castelo (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240675,
#     "localEstacao": "Viseu (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240903,
#     "localEstacao": "Porto, Massarelos",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240971,
#     "localEstacao": "Funchal, Lido",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 5210758,
#     "localEstacao": "Alcochete / Campo Tiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212121,
#     "localEstacao": "Terras de Bouro/Barral (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212122,
#     "localEstacao": "Amares Caldelas (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212123,
#     "localEstacao": "Vila Verde (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212124,
#     "localEstacao": "Braga (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212125,
#     "localEstacao": "Barcelos (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212126,
#     "localEstacao": "Esposende (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213012,
#     "localEstacao": "Carregal do Sal(CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213013,
#     "localEstacao": "Castro Daire / M\u00e9zio (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213014,
#     "localEstacao": "Mangualde / Ch\u00e3s de Tavares  (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213017,
#     "localEstacao": "Penalva do Castelo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213020,
#     "localEstacao": "Sat\u00e3o (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213021,
#     "localEstacao": "Tondela, Caramulinho ",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213022,
#     "localEstacao": "Vila Nova do Paiva (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213023,
#     "localEstacao": "Vouzela (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213611,
#     "localEstacao": "Arganil / Aer\u00f3dromo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213612,
#     "localEstacao": "Cantanhede / Fonte Dom Pedro (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213613,
#     "localEstacao": "Coimbra / Mata de S\u00e3o Pedro (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213615,
#     "localEstacao": "Mealhada / Quinta do Vale (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213616,
#     "localEstacao": "Mort\u00e1gua / Aer\u00f3dromo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213617,
#     "localEstacao": "Penacova / Hombres (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213619,
#     "localEstacao": "Vila Nova de Poiares (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213620,
#     "localEstacao": "Oliveira do Hospital (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213621,
#     "localEstacao": "Soure (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6214523,
#     "localEstacao": "Ma\u00e7\u00e3o/Cardigos (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 7240919,
#     "localEstacao": "Lisboa, Amoreiras (Lic. Franc\u00eas)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217160,
#     "localEstacao": "Santa Maria / Praia Formosa (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217165,
#     "localEstacao": "Santa Maria / Maia (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217217,
#     "localEstacao": "S\u00e3o Miguel / Santana (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217225,
#     "localEstacao": "S\u00e3o Miguel / Sete Cidades (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217255,
#     "localEstacao": "S\u00e3o Miguel / Lagoa das Furnas (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217370,
#     "localEstacao": "Terceira / Ribeira das Nove (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217372,
#     "localEstacao": "Terceira / Serra do Cume (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217430,
#     "localEstacao": "Graciosa / Serra das Fontes (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217510,
#     "localEstacao": "S\u00e3o Jorge / Pico do Areeiro (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217625,
#     "localEstacao": "Pico / Cabe\u00e7o do Teicho (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217645,
#     "localEstacao": "Pico / Cabecinho (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200501,
#     "localEstacao": "Flores (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200502,
#     "localEstacao": "Corvo (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200504,
#     "localEstacao": "Pico (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200506,
#     "localEstacao": "Horta (Obs. Pr\u00edncipe Alberto M\u00f3naco)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200507,
#     "localEstacao": "Graciosa (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200510,
#     "localEstacao": "S\u00e3o Jorge",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200511,
#     "localEstacao": "Angra do Hero\u00edsmo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200512,
#     "localEstacao": "Ponta Delgada (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200515,
#     "localEstacao": "Santa Maria (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200521,
#     "localEstacao": "Santa Catarina (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200522,
#     "localEstacao": "Funchal",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200524,
#     "localEstacao": "Porto Santo (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200531,
#     "localEstacao": "Cabo Carvoeiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200533,
#     "localEstacao": "Sagres",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200535,
#     "localEstacao": "Lisboa (Geof\u00edsico)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200541,
#     "localEstacao": "Sines",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200545,
#     "localEstacao": "Pedras Rubras",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200548,
#     "localEstacao": "Coimbra (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200551,
#     "localEstacao": "Viana Castelo, Chaf\u00e9",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200554,
#     "localEstacao": "Faro (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200558,
#     "localEstacao": "\u00c9vora (C.Coordena\u00e7\u00e3o)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200559,
#     "localEstacao": "Viseu (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200560,
#     "localEstacao": "Viseu (C.Coordena\u00e7\u00e3o)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200562,
#     "localEstacao": "Beja",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200567,
#     "localEstacao": "Vila Real",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200568,
#     "localEstacao": "Penhas Douradas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200570,
#     "localEstacao": "Castelo Branco",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200571,
#     "localEstacao": "Portalegre",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200575,
#     "localEstacao": "Bragan\u00e7a",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200576,
#     "localEstacao": "Bragan\u00e7a (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200579,
#     "localEstacao": "Lisboa (G.Coutinho)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210513,
#     "localEstacao": "Ponta Delgada (Obs. Afonso Chaves)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210577,
#     "localEstacao": "Odemira, S. Teot\u00f3nio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210604,
#     "localEstacao": "V.N.Cerveira (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210605,
#     "localEstacao": "Mon\u00e7\u00e3o, Valinha",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210606,
#     "localEstacao": "Lamas de Mouro, P.Ribeiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210611,
#     "localEstacao": "Montalegre",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210612,
#     "localEstacao": "Vinhais",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210615,
#     "localEstacao": "Ponte de Lima (Escola agr\u00edcola)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210616,
#     "localEstacao": "Chaves (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210619,
#     "localEstacao": "Cabril",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210622,
#     "localEstacao": "Braga, Merelim",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210630,
#     "localEstacao": "Cabeceiras de Basto",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210632,
#     "localEstacao": "Mirandela",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210633,
#     "localEstacao": "Macedo de Cavaleiros, Bagueixe",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210635,
#     "localEstacao": "Miranda do Douro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210637,
#     "localEstacao": "Mogadouro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210643,
#     "localEstacao": "Pa\u00e7os Ferreira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210644,
#     "localEstacao": "Carraz\u00eada de Ansi\u00e3es",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210649,
#     "localEstacao": "S. Gens",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210654,
#     "localEstacao": "Moncorvo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210655,
#     "localEstacao": "Pinh\u00e3o, Santa B\u00e1rbara",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210657,
#     "localEstacao": "Luzim",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210663,
#     "localEstacao": "Moimenta da Beira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210666,
#     "localEstacao": "Trancoso, Bandarra",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210669,
#     "localEstacao": "Arouca",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210671,
#     "localEstacao": "Fig. de Castelo Rodrigo (Vila Torpim)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210683,
#     "localEstacao": "Guarda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210685,
#     "localEstacao": "Nelas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210687,
#     "localEstacao": "Covilh\u00e3 (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210690,
#     "localEstacao": "Aldeia Souto (Quinta Lageosa)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210697,
#     "localEstacao": "Lous\u00e3 (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210698,
#     "localEstacao": "Fund\u00e3o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210702,
#     "localEstacao": "Aveiro (Universidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210704,
#     "localEstacao": "Dunas de Mira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210705,
#     "localEstacao": "Anadia",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210707,
#     "localEstacao": "Coimbra, Bencanta",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210713,
#     "localEstacao": "Figueira da Foz, Vila Verde",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210716,
#     "localEstacao": "Ansi\u00e3o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210718,
#     "localEstacao": "Leiria (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210721,
#     "localEstacao": "S\u00e3o Pedro de Moel",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210724,
#     "localEstacao": "Tomar, Valdonas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210726,
#     "localEstacao": "Alcoba\u00e7a",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210729,
#     "localEstacao": "Rio Maior",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210734,
#     "localEstacao": "Santar\u00e9m, Fonte Boa",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210739,
#     "localEstacao": "Torres Vedras, Dois Portos",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210744,
#     "localEstacao": "Coruche (Est. de Regadio - I.N.I.A.)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210746,
#     "localEstacao": "Santa Cruz (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210750,
#     "localEstacao": "Cabo da Roca",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210762,
#     "localEstacao": "Lisboa, Tapada da Ajuda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210765,
#     "localEstacao": "Cabo Raso",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210766,
#     "localEstacao": "Barreiro, Lavradio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210767,
#     "localEstacao": "Peg\u00f5es",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210770,
#     "localEstacao": "Set\u00fabal (Est. de Fruticultura)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210776,
#     "localEstacao": "Alc\u00e1cer do Sal, Barrosinha",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210783,
#     "localEstacao": "Alvalade",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210788,
#     "localEstacao": "Zambujeira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210789,
#     "localEstacao": "Aljezur",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210790,
#     "localEstacao": "Fo\u00eda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210800,
#     "localEstacao": "Sabugal, Martim Rei",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210803,
#     "localEstacao": "Zebreira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210806,
#     "localEstacao": "Proen\u00e7a-a-Nova, P.Moitas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210812,
#     "localEstacao": "Alvega",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210824,
#     "localEstacao": "Avis, Benavila (Esc. Abreu Callado)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210826,
#     "localEstacao": "Mora",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210835,
#     "localEstacao": "Elvas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210837,
#     "localEstacao": "Estremoz",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210847,
#     "localEstacao": "Viana do Alentejo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210848,
#     "localEstacao": "Portel, Oriola",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210851,
#     "localEstacao": "Amareleja",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210863,
#     "localEstacao": "M\u00e9rtola, Vale Formoso",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210864,
#     "localEstacao": "Castro Verde, N.Corvo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210866,
#     "localEstacao": "Vila Real de S.Ant\u00f3nio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210867,
#     "localEstacao": "Castro Marim (RN Sapal)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210874,
#     "localEstacao": "Albufeira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210878,
#     "localEstacao": "Portim\u00e3o (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210881,
#     "localEstacao": "Olh\u00e3o, EPPO",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210883,
#     "localEstacao": "Tavira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210932,
#     "localEstacao": "S. Miguel, Nordeste",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210956,
#     "localEstacao": "Madeira, Porto Moniz",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210960,
#     "localEstacao": "Madeira, S. Jorge, Santana",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210965,
#     "localEstacao": "Madeira, Santana",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210970,
#     "localEstacao": "Madeira, Bica da Cana",
#     "precAcumuladaNormalizada": 1
#   },
#   {
#     "idEstacao": 1210972,
#     "localEstacao": "Pico Alto",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210973,
#     "localEstacao": "Madeira, Areeiro",
#     "precAcumuladaNormalizada": 1
#   },
#   {
#     "idEstacao": 1210976,
#     "localEstacao": "Monte ",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210977,
#     "localEstacao": "Madeira, Cancela, Funchal",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210978,
#     "localEstacao": "Madeira, Cani\u00e7al, S. Louren\u00e7o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210980,
#     "localEstacao": "Madeira, Lombo da Ter\u00e7a",
#     "precAcumuladaNormalizada": 1
#   },
#   {
#     "idEstacao": 1210984,
#     "localEstacao": "Madeira, Quinta Grande",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210986,
#     "localEstacao": "Madeira, Ponta do Sol",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210987,
#     "localEstacao": "Madeira, Prazeres",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210990,
#     "localEstacao": "Madeira, Calheta",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240546,
#     "localEstacao": "Serra do Pilar",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240566,
#     "localEstacao": "Vila Real (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240610,
#     "localEstacao": "Viana do Castelo (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240675,
#     "localEstacao": "Viseu (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240903,
#     "localEstacao": "Porto, Massarelos",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240971,
#     "localEstacao": "Funchal, Lido",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 5210758,
#     "localEstacao": "Alcochete / Campo Tiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212121,
#     "localEstacao": "Terras de Bouro/Barral (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212122,
#     "localEstacao": "Amares Caldelas (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212123,
#     "localEstacao": "Vila Verde (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212124,
#     "localEstacao": "Braga (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212125,
#     "localEstacao": "Barcelos (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212126,
#     "localEstacao": "Esposende (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213012,
#     "localEstacao": "Carregal do Sal(CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213013,
#     "localEstacao": "Castro Daire / M\u00e9zio (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213014,
#     "localEstacao": "Mangualde / Ch\u00e3s de Tavares  (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213017,
#     "localEstacao": "Penalva do Castelo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213020,
#     "localEstacao": "Sat\u00e3o (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213021,
#     "localEstacao": "Tondela, Caramulinho ",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213022,
#     "localEstacao": "Vila Nova do Paiva (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213023,
#     "localEstacao": "Vouzela (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213611,
#     "localEstacao": "Arganil / Aer\u00f3dromo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213612,
#     "localEstacao": "Cantanhede / Fonte Dom Pedro (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213613,
#     "localEstacao": "Coimbra / Mata de S\u00e3o Pedro (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213615,
#     "localEstacao": "Mealhada / Quinta do Vale (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213616,
#     "localEstacao": "Mort\u00e1gua / Aer\u00f3dromo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213617,
#     "localEstacao": "Penacova / Hombres (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213619,
#     "localEstacao": "Vila Nova de Poiares (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213620,
#     "localEstacao": "Oliveira do Hospital (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213621,
#     "localEstacao": "Soure (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 7240919,
#     "localEstacao": "Lisboa, Amoreiras (Lic. Franc\u00eas)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217160,
#     "localEstacao": "Santa Maria / Praia Formosa (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217165,
#     "localEstacao": "Santa Maria / Maia (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217217,
#     "localEstacao": "S\u00e3o Miguel / Santana (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217255,
#     "localEstacao": "S\u00e3o Miguel / Lagoa das Furnas (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217370,
#     "localEstacao": "Terceira / Ribeira das Nove (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217372,
#     "localEstacao": "Terceira / Serra do Cume (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217430,
#     "localEstacao": "Graciosa / Serra das Fontes (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217510,
#     "localEstacao": "S\u00e3o Jorge / Pico do Areeiro (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217625,
#     "localEstacao": "Pico / Cabe\u00e7o do Teicho (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217645,
#     "localEstacao": "Pico / Cabecinho (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200501,
#     "localEstacao": "Flores (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200502,
#     "localEstacao": "Corvo (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200504,
#     "localEstacao": "Pico (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200506,
#     "localEstacao": "Horta (Obs. Pr\u00edncipe Alberto M\u00f3naco)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200507,
#     "localEstacao": "Graciosa (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200510,
#     "localEstacao": "S\u00e3o Jorge",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200511,
#     "localEstacao": "Angra do Hero\u00edsmo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200512,
#     "localEstacao": "Ponta Delgada (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200515,
#     "localEstacao": "Santa Maria (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200521,
#     "localEstacao": "Santa Catarina (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200522,
#     "localEstacao": "Funchal",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200524,
#     "localEstacao": "Porto Santo (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200531,
#     "localEstacao": "Cabo Carvoeiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200533,
#     "localEstacao": "Sagres",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200535,
#     "localEstacao": "Lisboa (Geof\u00edsico)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200541,
#     "localEstacao": "Sines",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200545,
#     "localEstacao": "Pedras Rubras",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200548,
#     "localEstacao": "Coimbra (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200551,
#     "localEstacao": "Viana Castelo, Chaf\u00e9",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200554,
#     "localEstacao": "Faro (Aeroporto)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200558,
#     "localEstacao": "\u00c9vora (C.Coordena\u00e7\u00e3o)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200559,
#     "localEstacao": "Viseu (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200560,
#     "localEstacao": "Viseu (C.Coordena\u00e7\u00e3o)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200562,
#     "localEstacao": "Beja",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200567,
#     "localEstacao": "Vila Real",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200568,
#     "localEstacao": "Penhas Douradas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200570,
#     "localEstacao": "Castelo Branco",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200571,
#     "localEstacao": "Portalegre",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200575,
#     "localEstacao": "Bragan\u00e7a",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200576,
#     "localEstacao": "Bragan\u00e7a (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1200579,
#     "localEstacao": "Lisboa (G.Coutinho)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210513,
#     "localEstacao": "Ponta Delgada (Obs. Afonso Chaves)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210577,
#     "localEstacao": "Odemira, S. Teot\u00f3nio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210604,
#     "localEstacao": "V.N.Cerveira (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210605,
#     "localEstacao": "Mon\u00e7\u00e3o, Valinha",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210606,
#     "localEstacao": "Lamas de Mouro, P.Ribeiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210611,
#     "localEstacao": "Montalegre",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210612,
#     "localEstacao": "Vinhais",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210615,
#     "localEstacao": "Ponte de Lima (Escola agr\u00edcola)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210616,
#     "localEstacao": "Chaves (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210619,
#     "localEstacao": "Cabril",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210622,
#     "localEstacao": "Braga, Merelim",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210630,
#     "localEstacao": "Cabeceiras de Basto",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210632,
#     "localEstacao": "Mirandela",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210633,
#     "localEstacao": "Macedo de Cavaleiros, Bagueixe",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210635,
#     "localEstacao": "Miranda do Douro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210637,
#     "localEstacao": "Mogadouro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210643,
#     "localEstacao": "Pa\u00e7os Ferreira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210644,
#     "localEstacao": "Carraz\u00eada de Ansi\u00e3es",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210649,
#     "localEstacao": "S. Gens",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210654,
#     "localEstacao": "Moncorvo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210655,
#     "localEstacao": "Pinh\u00e3o, Santa B\u00e1rbara",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210657,
#     "localEstacao": "Luzim",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210663,
#     "localEstacao": "Moimenta da Beira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210666,
#     "localEstacao": "Trancoso, Bandarra",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210669,
#     "localEstacao": "Arouca",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210671,
#     "localEstacao": "Fig. de Castelo Rodrigo (Vila Torpim)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210683,
#     "localEstacao": "Guarda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210685,
#     "localEstacao": "Nelas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210687,
#     "localEstacao": "Covilh\u00e3 (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210690,
#     "localEstacao": "Aldeia Souto (Quinta Lageosa)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210697,
#     "localEstacao": "Lous\u00e3 (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210698,
#     "localEstacao": "Fund\u00e3o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210702,
#     "localEstacao": "Aveiro (Universidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210704,
#     "localEstacao": "Dunas de Mira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210705,
#     "localEstacao": "Anadia",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210707,
#     "localEstacao": "Coimbra, Bencanta",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210713,
#     "localEstacao": "Figueira da Foz, Vila Verde",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210716,
#     "localEstacao": "Ansi\u00e3o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210718,
#     "localEstacao": "Leiria (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210721,
#     "localEstacao": "S\u00e3o Pedro de Moel",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210724,
#     "localEstacao": "Tomar, Valdonas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210726,
#     "localEstacao": "Alcoba\u00e7a",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210729,
#     "localEstacao": "Rio Maior",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210734,
#     "localEstacao": "Santar\u00e9m, Fonte Boa",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210739,
#     "localEstacao": "Torres Vedras, Dois Portos",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210744,
#     "localEstacao": "Coruche (Est. de Regadio - I.N.I.A.)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210746,
#     "localEstacao": "Santa Cruz (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210750,
#     "localEstacao": "Cabo da Roca",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210762,
#     "localEstacao": "Lisboa, Tapada da Ajuda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210765,
#     "localEstacao": "Cabo Raso",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210766,
#     "localEstacao": "Barreiro, Lavradio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210767,
#     "localEstacao": "Peg\u00f5es",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210770,
#     "localEstacao": "Set\u00fabal (Est. de Fruticultura)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210776,
#     "localEstacao": "Alc\u00e1cer do Sal, Barrosinha",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210783,
#     "localEstacao": "Alvalade",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210788,
#     "localEstacao": "Zambujeira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210789,
#     "localEstacao": "Aljezur",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210790,
#     "localEstacao": "Fo\u00eda",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210800,
#     "localEstacao": "Sabugal, Martim Rei",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210803,
#     "localEstacao": "Zebreira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210806,
#     "localEstacao": "Proen\u00e7a-a-Nova, P.Moitas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210812,
#     "localEstacao": "Alvega",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210824,
#     "localEstacao": "Avis, Benavila (Esc. Abreu Callado)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210826,
#     "localEstacao": "Mora",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210835,
#     "localEstacao": "Elvas",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210837,
#     "localEstacao": "Estremoz",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210847,
#     "localEstacao": "Viana do Alentejo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210848,
#     "localEstacao": "Portel, Oriola",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210851,
#     "localEstacao": "Amareleja",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210863,
#     "localEstacao": "M\u00e9rtola, Vale Formoso",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210864,
#     "localEstacao": "Castro Verde, N.Corvo",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210866,
#     "localEstacao": "Vila Real de S.Ant\u00f3nio",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210867,
#     "localEstacao": "Castro Marim (RN Sapal)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210874,
#     "localEstacao": "Albufeira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210878,
#     "localEstacao": "Portim\u00e3o (Aer\u00f3dromo)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210881,
#     "localEstacao": "Olh\u00e3o, EPPO",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210883,
#     "localEstacao": "Tavira",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210932,
#     "localEstacao": "S. Miguel, Nordeste",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210960,
#     "localEstacao": "Madeira, S. Jorge, Santana",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210973,
#     "localEstacao": "Madeira, Areeiro",
#     "precAcumuladaNormalizada": 1
#   },
#   {
#     "idEstacao": 1210976,
#     "localEstacao": "Monte ",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210977,
#     "localEstacao": "Madeira, Cancela, Funchal",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210978,
#     "localEstacao": "Madeira, Cani\u00e7al, S. Louren\u00e7o",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210980,
#     "localEstacao": "Madeira, Lombo da Ter\u00e7a",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210986,
#     "localEstacao": "Madeira, Ponta do Sol",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210987,
#     "localEstacao": "Madeira, Prazeres",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1210990,
#     "localEstacao": "Madeira, Calheta",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240546,
#     "localEstacao": "Serra do Pilar",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240566,
#     "localEstacao": "Vila Real (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240610,
#     "localEstacao": "Viana do Castelo (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240675,
#     "localEstacao": "Viseu (Cidade)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 1240903,
#     "localEstacao": "Porto, Massarelos",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 5210758,
#     "localEstacao": "Alcochete / Campo Tiro",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212121,
#     "localEstacao": "Terras de Bouro/Barral (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212122,
#     "localEstacao": "Amares Caldelas (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212123,
#     "localEstacao": "Vila Verde (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212124,
#     "localEstacao": "Braga (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212125,
#     "localEstacao": "Barcelos (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6212126,
#     "localEstacao": "Esposende (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213012,
#     "localEstacao": "Carregal do Sal(CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213013,
#     "localEstacao": "Castro Daire / M\u00e9zio (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213014,
#     "localEstacao": "Mangualde / Ch\u00e3s de Tavares  (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213017,
#     "localEstacao": "Penalva do Castelo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213020,
#     "localEstacao": "Sat\u00e3o (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213021,
#     "localEstacao": "Tondela, Caramulinho ",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213022,
#     "localEstacao": "Vila Nova do Paiva (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213023,
#     "localEstacao": "Vouzela (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213611,
#     "localEstacao": "Arganil / Aer\u00f3dromo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213612,
#     "localEstacao": "Cantanhede / Fonte Dom Pedro (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213613,
#     "localEstacao": "Coimbra / Mata de S\u00e3o Pedro (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213615,
#     "localEstacao": "Mealhada / Quinta do Vale (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213616,
#     "localEstacao": "Mort\u00e1gua / Aer\u00f3dromo (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213617,
#     "localEstacao": "Penacova / Hombres (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213619,
#     "localEstacao": "Vila Nova de Poiares (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213620,
#     "localEstacao": "Oliveira do Hospital (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 6213621,
#     "localEstacao": "Soure (CIM)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 7240919,
#     "localEstacao": "Lisboa, Amoreiras (Lic. Franc\u00eas)",
#     "precAcumuladaNormalizada": 0
#   },
#   {
#     "idEstacao": 11217160,
#     "localEstacao": "Santa Maria / Praia Formosa (DRAAC)",
#     "precAcumuladaNormalizada": 0
#   }
# ]
