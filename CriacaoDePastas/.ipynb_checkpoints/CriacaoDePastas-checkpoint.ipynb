# %%
import os

for i in range(101):
    os.mkdir(str(i)) #---Cria as pastas do 0 ao 100
print("Pastas criadas!")

# %%
import requests
import json

DADOS_ULTIMAS_3_HORAS = "https://api.ipma.pt/open-data/observation/meteorology/stations/obs-surface.geojson" #por exemplo se forem 9PM tem os dados entre 5PM e 7PM de hora a hora para todas as estações
DADOS_ULTIMAS_24_HORAS = "https://api.ipma.pt/open-data/observation/meteorology/stations/observations.json" #tem os dados das ultimas 24 horas para algumas estações

class make_api_call:
    def get_data(self, api):
        response = requests.get(f"{api}")
        if response.status_code == 200:
            print("sucessfully fetched the data")
            return response.json()
        else:
            print(f"Hello there, there's a {response.status_code} error with your request")
            
#---Define a função que vai transformar o valor da precipatação para um valor de 0 a 100
#---https://www.ipma.pt/pt/oclima/extremos.clima/ Vou usar o valor máximo aqui como referencia

def normalize_precipitation_value(precipitation_value):
  return int(round((precipitation_value/240)*100,0)) #o valor normalizado ta a ser arredondado pq as pastas sao de valores inteiros

# %%
api_call_instance = make_api_call()
full_json_array = api_call_instance.get_data(DADOS_ULTIMAS_3_HORAS)
# Out:
# sucessfully fetched the data
# {'type': 'FeatureCollection',
#  'features': [{'geometry': {'type': 'Point',
#     'coordinates': [-31.1301, 39.4582]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 18.7,
#     'temperatura': 15.1,
#     'idEstacao': 1200501,
#     'pressao': 1022.5,
#     'humidade': 73.0,
#     'localEstacao': 'Flores (Aeroporto)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 5,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 5.2,
#     'descDirVento': 'S'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-31.1136, 39.6739]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 21.2,
#     'temperatura': 15.5,
#     'idEstacao': 1200502,
#     'pressao': 1022.4,
#     'humidade': 80.0,
#     'localEstacao': 'Corvo (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 5.9,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-28.4414, 38.5522]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 9.7,
#     'temperatura': 14.9,
#     'idEstacao': 1200504,
#     'pressao': 1024.6,
#     'humidade': 85.0,
#     'localEstacao': 'Pico (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.7,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-28.6322, 38.5408]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 27.4,
#     'temperatura': 15.2,
#     'idEstacao': 1200506,
#     'pressao': 1024.9,
#     'humidade': 92.0,
#     'localEstacao': 'Horta (Obs. Príncipe Alberto Mónaco)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 7.6,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-28.0285, 39.0904]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 15.5,
#     'temperatura': 14.8,
#     'idEstacao': 1200507,
#     'pressao': 1024.4,
#     'humidade': 93.0,
#     'localEstacao': 'Graciosa (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 6,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 4.3,
#     'descDirVento': 'SW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-28.17, 38.66]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.9,
#     'temperatura': 13.5,
#     'idEstacao': 1200510,
#     'pressao': 1024.7,
#     'humidade': 93.0,
#     'localEstacao': 'São Jorge',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.8,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-27.2166, 38.6659]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.2,
#     'temperatura': 14.0,
#     'idEstacao': 1200511,
#     'pressao': 1024.9,
#     'humidade': 88.0,
#     'localEstacao': 'Angra do Heroísmo',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.0,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-25.6953, 37.7441]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.9,
#     'temperatura': 14.6,
#     'idEstacao': 1200512,
#     'pressao': 1025.1,
#     'humidade': 92.0,
#     'localEstacao': 'Ponta Delgada (Aeroporto)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.2,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-25.1679, 36.9672]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.5,
#     'temperatura': 13.4,
#     'idEstacao': 1200515,
#     'pressao': 1025.5,
#     'humidade': 91.0,
#     'localEstacao': 'Santa Maria (Aeroporto)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.8,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-16.7761, 32.6969]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 16.9,
#     'temperatura': 16.7,
#     'idEstacao': 1200521,
#     'pressao': 1017.7,
#     'humidade': 63.0,
#     'localEstacao': 'Santa Catarina (Aeroporto)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 4.7,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-16.888, 32.6479]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.7,
#     'temperatura': 16.8,
#     'idEstacao': 1200522,
#     'pressao': 1017.5,
#     'humidade': 46.0,
#     'localEstacao': 'Funchal',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.3,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-16.3487, 33.074]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 22.7,
#     'temperatura': 15.6,
#     'idEstacao': 1200524,
#     'pressao': 1017.9,
#     'humidade': 81.0,
#     'localEstacao': 'Porto Santo (Aeroporto)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 0,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 6.3,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.4074, 39.38]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 17.3,
#     'temperatura': 14.4,
#     'idEstacao': 1200531,
#     'pressao': 1015.6,
#     'humidade': 92.0,
#     'localEstacao': 'Cabo Carvoeiro',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 4.8,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.9491, 37.0128]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.2,
#     'temperatura': 9.7,
#     'idEstacao': 1200533,
#     'pressao': 1014.1,
#     'humidade': 66.0,
#     'localEstacao': 'Sagres',
#     'precAcumulada': -99.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.0,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.1497, 38.7191]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.0,
#     'temperatura': 14.5,
#     'idEstacao': 1200535,
#     'pressao': 1015.1,
#     'humidade': 43.0,
#     'localEstacao': 'Lisboa (Geofísico)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.4,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.8383, 37.9545]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 10.8,
#     'temperatura': 10.4,
#     'idEstacao': 1200541,
#     'pressao': 1014.6,
#     'humidade': 54.0,
#     'localEstacao': 'Sines',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 3.0,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.6813, 41.2335]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.6,
#     'temperatura': 9.9,
#     'idEstacao': 1200545,
#     'pressao': 1016.5,
#     'humidade': 72.0,
#     'localEstacao': 'Pedras Rubras',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.1,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.4667, 40.1501]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.6,
#     'temperatura': 11.3,
#     'idEstacao': 1200548,
#     'pressao': 1016.1,
#     'humidade': 45.0,
#     'localEstacao': 'Coimbra (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.1,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.8046, 41.6489]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 10.1,
#     'temperatura': 8.9,
#     'idEstacao': 1200551,
#     'pressao': 1016.8,
#     'humidade': 70.0,
#     'localEstacao': 'Viana Castelo, Chafé',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.8,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.972, 37.0166]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 12.2,
#     'temperatura': 14.2,
#     'idEstacao': 1200554,
#     'pressao': 1013.9,
#     'humidade': 35.0,
#     'localEstacao': 'Faro (Aeroporto)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 3.4,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.8834, 38.5334]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.2,
#     'temperatura': 11.4,
#     'idEstacao': 1200558,
#     'pressao': 1015.1,
#     'humidade': 46.0,
#     'localEstacao': 'Évora (C.Coordenação)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.0,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.8875, 40.7264]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 9.4,
#     'temperatura': 10.6,
#     'idEstacao': 1200559,
#     'pressao': 1017.3,
#     'humidade': 36.0,
#     'localEstacao': 'Viseu (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.6,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.8959, 40.7149]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 21.6,
#     'temperatura': 12.6,
#     'idEstacao': 1200560,
#     'pressao': 1017.1,
#     'humidade': 31.0,
#     'localEstacao': 'Viseu (C.Coordenação)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 6.0,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.8673, 38.0249]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 8.3,
#     'temperatura': 13.2,
#     'idEstacao': 1200562,
#     'pressao': 1014.3,
#     'humidade': 34.0,
#     'localEstacao': 'Beja',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.3,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.7171, 41.2742]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.8,
#     'temperatura': 9.7,
#     'idEstacao': 1200567,
#     'pressao': 1018.9,
#     'humidade': 43.0,
#     'localEstacao': 'Vila Real',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.5,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.5587, 40.4114]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.1,
#     'temperatura': 7.9,
#     'idEstacao': 1200568,
#     'pressao': -99.0,
#     'humidade': 15.0,
#     'localEstacao': 'Penhas Douradas',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.7,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.4668, 39.8334]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 9.0,
#     'temperatura': 12.7,
#     'idEstacao': 1200570,
#     'pressao': 1016.3,
#     'humidade': 20.0,
#     'localEstacao': 'Castelo Branco',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.5,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.42, 39.2955]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 14.0,
#     'temperatura': 16.9,
#     'idEstacao': 1200571,
#     'pressao': 1014.8,
#     'humidade': 10.0,
#     'localEstacao': 'Portalegre',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 3.9,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-6.7428, 41.8039]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 7.7,
#     'idEstacao': 1200575,
#     'pressao': 1020.8,
#     'humidade': 33.0,
#     'localEstacao': 'Bragança',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-6.708, 41.8576]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 3.2,
#     'temperatura': 5.4,
#     'idEstacao': 1200576,
#     'pressao': 1021.7,
#     'humidade': 46.0,
#     'localEstacao': 'Bragança (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.9,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.1275, 38.7662]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.4,
#     'temperatura': 12.9,
#     'idEstacao': 1200579,
#     'pressao': 1015.1,
#     'humidade': 51.0,
#     'localEstacao': 'Lisboa (G.Coutinho)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.5,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-25.6623, 37.7464]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.8,
#     'temperatura': 14.9,
#     'idEstacao': 1210513,
#     'pressao': -99.0,
#     'humidade': 87.0,
#     'localEstacao': 'Ponta Delgada (Obs. Afonso Chaves)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 9,
#     'radiacao': 3.7,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.5,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.729, 37.5471]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.3,
#     'temperatura': 9.9,
#     'idEstacao': 1210577,
#     'pressao': -99.0,
#     'humidade': 63.0,
#     'localEstacao': 'Odemira, S. Teotónio',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.2,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.6668, 41.9667]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.0,
#     'temperatura': 5.4,
#     'idEstacao': 1210604,
#     'pressao': 1017.1,
#     'humidade': 100.0,
#     'localEstacao': 'V.N.Cerveira (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 0,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.1,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.3833, 42.0667]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.0,
#     'temperatura': 10.3,
#     'idEstacao': 1210605,
#     'pressao': -99.0,
#     'humidade': 60.0,
#     'localEstacao': 'Monção, Valinha',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.1,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.1833, 42.0333]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 17.6,
#     'temperatura': 12.1,
#     'idEstacao': 1210606,
#     'pressao': 1018.0,
#     'humidade': 28.0,
#     'localEstacao': 'Lamas de Mouro, P.Ribeiro',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 4.9,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.788, 41.8228]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.5,
#     'temperatura': 7.9,
#     'idEstacao': 1210611,
#     'pressao': -99.0,
#     'humidade': 37.0,
#     'localEstacao': 'Montalegre',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.8,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.0034, 41.8434]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.8,
#     'temperatura': 11.1,
#     'idEstacao': 1210612,
#     'pressao': -99.0,
#     'humidade': 28.0,
#     'localEstacao': 'Vinhais',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.6,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.5667, 41.7501]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.5,
#     'temperatura': 6.2,
#     'idEstacao': 1210615,
#     'pressao': -99.0,
#     'humidade': 89.0,
#     'localEstacao': 'Ponte de Lima (Escola agrícola)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.7,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.4654, 41.7252]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.5,
#     'temperatura': 2.1,
#     'idEstacao': 1210616,
#     'pressao': 1021.0,
#     'humidade': 92.0,
#     'localEstacao': 'Chaves (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.7,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.0167, 41.7167]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': -99.0,
#     'temperatura': 10.4,
#     'idEstacao': 1210619,
#     'pressao': -99.0,
#     'humidade': 35.0,
#     'localEstacao': 'Cabril',
#     'precAcumulada': 0.0,
#     'idDireccVento': 0,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': -99.0,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.45, 41.5668]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.0,
#     'temperatura': 5.1,
#     'idEstacao': 1210622,
#     'pressao': -99.0,
#     'humidade': 94.0,
#     'localEstacao': 'Braga, Merelim',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.4,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.9667, 41.5333]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 5.1,
#     'idEstacao': 1210630,
#     'pressao': -99.0,
#     'humidade': 91.0,
#     'localEstacao': 'Cabeceiras de Basto',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.1908, 41.5148]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 0.0,
#     'temperatura': 0.8,
#     'idEstacao': 1210632,
#     'pressao': -99.0,
#     'humidade': 92.0,
#     'localEstacao': 'Mirandela',
#     'precAcumulada': 0.0,
#     'idDireccVento': 9,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.0,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-6.7833, 41.5667]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 12.6,
#     'temperatura': 8.5,
#     'idEstacao': 1210633,
#     'pressao': -99.0,
#     'humidade': 36.0,
#     'localEstacao': 'Macedo de Cavaleiros, Bagueixe',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 3.5,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-6.2833, 41.5167]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.3,
#     'temperatura': 2.9,
#     'idEstacao': 1210635,
#     'pressao': -99.0,
#     'humidade': 62.0,
#     'localEstacao': 'Miranda do Douro',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.2,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-6.7333, 41.3333]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 23.4,
#     'temperatura': 7.5,
#     'idEstacao': 1210637,
#     'pressao': -99.0,
#     'humidade': 36.0,
#     'localEstacao': 'Mogadouro',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.3,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 6.5,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.3801, 41.2737]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.1,
#     'temperatura': 4.3,
#     'idEstacao': 1210643,
#     'pressao': -99.0,
#     'humidade': 96.0,
#     'localEstacao': 'Paços Ferreira',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.3,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.2833, 41.2333]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.9,
#     'temperatura': 7.4,
#     'idEstacao': 1210644,
#     'pressao': -99.0,
#     'humidade': 43.0,
#     'localEstacao': 'Carrazêda de Ansiães',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.8,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.6445, 41.1844]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.0,
#     'temperatura': 8.8,
#     'idEstacao': 1210649,
#     'pressao': -99.0,
#     'humidade': 76.0,
#     'localEstacao': 'S. Gens',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.1,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.0167, 41.1833]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 9.0,
#     'temperatura': 7.1,
#     'idEstacao': 1210654,
#     'pressao': 1019.9,
#     'humidade': 43.0,
#     'localEstacao': 'Moncorvo',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.5,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.549, 41.1728]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.8,
#     'temperatura': 6.0,
#     'idEstacao': 1210655,
#     'pressao': -99.0,
#     'humidade': 71.0,
#     'localEstacao': 'Pinhão, Santa Bárbara',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.5,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.249, 41.1459]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.4,
#     'temperatura': 6.3,
#     'idEstacao': 1210657,
#     'pressao': -99.0,
#     'humidade': 80.0,
#     'localEstacao': 'Luzim',
#     'precAcumulada': 0.0,
#     'idDireccVento': 5,
#     'radiacao': 0.1,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.4,
#     'descDirVento': 'S'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.6, 40.9833]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.8,
#     'temperatura': 6.8,
#     'idEstacao': 1210663,
#     'pressao': -99.0,
#     'humidade': 55.0,
#     'localEstacao': 'Moimenta da Beira',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.9,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.3667, 40.7833]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 14.0,
#     'temperatura': 9.7,
#     'idEstacao': 1210666,
#     'pressao': -99.0,
#     'humidade': 28.0,
#     'localEstacao': 'Trancoso, Bandarra',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 3.9,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.25, 40.9333]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.8,
#     'temperatura': 4.9,
#     'idEstacao': 1210669,
#     'pressao': -99.0,
#     'humidade': 92.0,
#     'localEstacao': 'Arouca',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.5,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-6.8833, 40.75]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 10.4,
#     'temperatura': 5.9,
#     'idEstacao': 1210671,
#     'pressao': -99.0,
#     'humidade': 39.0,
#     'localEstacao': 'Fig. de Castelo Rodrigo (Vila Torpim)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.9,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.2667, 40.5333]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 15.5,
#     'temperatura': 11.4,
#     'idEstacao': 1210683,
#     'pressao': -99.0,
#     'humidade': 14.0,
#     'localEstacao': 'Guarda',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 4.3,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.85, 40.5167]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 10.1,
#     'temperatura': 11.5,
#     'idEstacao': 1210685,
#     'pressao': -99.0,
#     'humidade': 29.0,
#     'localEstacao': 'Nelas',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.8,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.4823, 40.2643]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.8,
#     'temperatura': 7.2,
#     'idEstacao': 1210687,
#     'pressao': -99.0,
#     'humidade': 43.0,
#     'localEstacao': 'Covilhã (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.9,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.3893, 40.3543]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.4,
#     'temperatura': 6.2,
#     'idEstacao': 1210690,
#     'pressao': -99.0,
#     'humidade': 46.0,
#     'localEstacao': 'Aldeia Souto (Quinta Lageosa)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': 0.3,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.4,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.2441, 40.1439]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.3,
#     'temperatura': 7.6,
#     'idEstacao': 1210697,
#     'pressao': -99.0,
#     'humidade': 76.0,
#     'localEstacao': 'Lousã (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.2,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.6596, 40.6353]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.0,
#     'temperatura': 10.2,
#     'idEstacao': 1210702,
#     'pressao': 1016.5,
#     'humidade': 69.0,
#     'localEstacao': 'Aveiro (Universidade)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.1,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.7617, 40.446]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.4,
#     'temperatura': 3.4,
#     'idEstacao': 1210704,
#     'pressao': -99.0,
#     'humidade': 100.0,
#     'localEstacao': 'Dunas de Mira',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.4,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.44, 40.4389]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 0.0,
#     'temperatura': 5.5,
#     'idEstacao': 1210705,
#     'pressao': -99.0,
#     'humidade': 93.0,
#     'localEstacao': 'Anadia',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.0,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.4552, 40.2135]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 5.8,
#     'idEstacao': 1210707,
#     'pressao': -99.0,
#     'humidade': 100.0,
#     'localEstacao': 'Coimbra, Bencanta',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.8059, 40.1398]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.4,
#     'temperatura': 5.5,
#     'idEstacao': 1210713,
#     'pressao': -99.0,
#     'humidade': 91.0,
#     'localEstacao': 'Figueira da Foz, Vila Verde',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.5,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.4, 39.9]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 10.4,
#     'temperatura': 13.1,
#     'idEstacao': 1210716,
#     'pressao': -99.0,
#     'humidade': 26.0,
#     'localEstacao': 'Ansião',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.9,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.8182, 39.7806]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.8,
#     'temperatura': 4.7,
#     'idEstacao': 1210718,
#     'pressao': 1016.5,
#     'humidade': 93.0,
#     'localEstacao': 'Leiria (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.9,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.0306, 39.7636]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 11.9,
#     'temperatura': 5.0,
#     'idEstacao': 1210721,
#     'pressao': -99.0,
#     'humidade': 93.0,
#     'localEstacao': 'São Pedro de Moel',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 3.3,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.3667, 39.6]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.4,
#     'temperatura': 4.9,
#     'idEstacao': 1210724,
#     'pressao': -99.0,
#     'humidade': 87.0,
#     'localEstacao': 'Tomar, Valdonas',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.5,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.9667, 39.5167]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 4.4,
#     'idEstacao': 1210726,
#     'pressao': -99.0,
#     'humidade': 92.0,
#     'localEstacao': 'Alcobaça',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.9333, 39.35]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.7,
#     'temperatura': 5.0,
#     'idEstacao': 1210729,
#     'pressao': -99.0,
#     'humidade': 89.0,
#     'localEstacao': 'Rio Maior',
#     'precAcumulada': 0.0,
#     'idDireccVento': 9,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.3,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.7367, 39.2012]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.1,
#     'temperatura': 10.3,
#     'idEstacao': 1210734,
#     'pressao': 1014.7,
#     'humidade': 67.0,
#     'localEstacao': 'Santarém, Fonte Boa',
#     'precAcumulada': 0.0,
#     'idDireccVento': 9,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.7,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.179, 39.0439]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 3.2,
#     'temperatura': 9.3,
#     'idEstacao': 1210739,
#     'pressao': -99.0,
#     'humidade': 82.0,
#     'localEstacao': 'Torres Vedras, Dois Portos',
#     'precAcumulada': 0.0,
#     'idDireccVento': 5,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.9,
#     'descDirVento': 'S'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.5107, 38.941]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 4.0,
#     'idEstacao': 1210744,
#     'pressao': -99.0,
#     'humidade': 90.0,
#     'localEstacao': 'Coruche (Est. de Regadio - I.N.I.A.)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.379, 39.1259]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.0,
#     'temperatura': 8.8,
#     'idEstacao': 1210746,
#     'pressao': 1016.0,
#     'humidade': 95.0,
#     'localEstacao': 'Santa Cruz (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 1.3,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.1,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.4975, 38.7817]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 24.8,
#     'temperatura': 12.7,
#     'idEstacao': 1210750,
#     'pressao': -99.0,
#     'humidade': 89.0,
#     'localEstacao': 'Cabo da Roca',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 6.9,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.1828, 38.7096]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 3.2,
#     'temperatura': 9.5,
#     'idEstacao': 1210762,
#     'pressao': -99.0,
#     'humidade': 54.0,
#     'localEstacao': 'Lisboa, Tapada da Ajuda',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.9,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.4854, 38.709]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 8.3,
#     'temperatura': 14.5,
#     'idEstacao': 1210765,
#     'pressao': 1013.7,
#     'humidade': 67.0,
#     'localEstacao': 'Cabo Raso',
#     'precAcumulada': -99.0,
#     'idDireccVento': 1,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.3,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.0477, 38.6745]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 3.2,
#     'temperatura': 11.7,
#     'idEstacao': 1210766,
#     'pressao': -99.0,
#     'humidade': 71.0,
#     'localEstacao': 'Barreiro, Lavradio',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.9,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.635, 38.6508]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.0,
#     'temperatura': 7.9,
#     'idEstacao': 1210767,
#     'pressao': -99.0,
#     'humidade': 63.0,
#     'localEstacao': 'Pegões',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.1,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.8908, 38.5485]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.0,
#     'temperatura': 13.1,
#     'idEstacao': 1210770,
#     'pressao': -99.0,
#     'humidade': 47.0,
#     'localEstacao': 'Setúbal (Est. de Fruticultura)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.4,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.2128, 38.6171]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.7,
#     'temperatura': 6.9,
#     'idEstacao': 1210773,
#     'pressao': -99.0,
#     'humidade': 81.0,
#     'localEstacao': 'Almada, P.Rainha',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 0.1,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.3,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.4833, 38.3667]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 0.0,
#     'temperatura': 5.9,
#     'idEstacao': 1210776,
#     'pressao': -99.0,
#     'humidade': 73.0,
#     'localEstacao': 'Alcácer do Sal, Barrosinha',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.0,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.3945, 37.9468]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 0.0,
#     'temperatura': 3.7,
#     'idEstacao': 1210783,
#     'pressao': -99.0,
#     'humidade': 85.0,
#     'localEstacao': 'Alvalade',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.0,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.7429, 37.582]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.5,
#     'temperatura': 5.3,
#     'idEstacao': 1210788,
#     'pressao': -99.0,
#     'humidade': 94.0,
#     'localEstacao': 'Zambujeira',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.7,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.8, 37.3168]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 0.7,
#     'temperatura': 2.9,
#     'idEstacao': 1210789,
#     'pressao': -99.0,
#     'humidade': 96.0,
#     'localEstacao': 'Aljezur',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.2,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.5957, 37.3143]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 16.6,
#     'temperatura': -99.0,
#     'idEstacao': 1210790,
#     'pressao': -99.0,
#     'humidade': -99.0,
#     'localEstacao': 'Foía',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 4.6,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.0369, 40.3392]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 9.4,
#     'temperatura': 6.4,
#     'idEstacao': 1210800,
#     'pressao': -99.0,
#     'humidade': 33.0,
#     'localEstacao': 'Sabugal, Martim Rei',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.6,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.0167, 39.8667]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 11.1,
#     'idEstacao': 1210803,
#     'pressao': -99.0,
#     'humidade': 30.0,
#     'localEstacao': 'Zebreira',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.8667, 39.7333]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 8.3,
#     'temperatura': 14.2,
#     'idEstacao': 1210806,
#     'pressao': -99.0,
#     'humidade': 19.0,
#     'localEstacao': 'Proença-a-Nova, P.Moitas',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.3,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.05, 39.4667]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.5,
#     'temperatura': 1.5,
#     'idEstacao': 1210812,
#     'pressao': -99.0,
#     'humidade': 95.0,
#     'localEstacao': 'Alvega',
#     'precAcumulada': 0.0,
#     'idDireccVento': 5,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.7,
#     'descDirVento': 'S'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.8667, 39.1]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.7,
#     'temperatura': 6.7,
#     'idEstacao': 1210824,
#     'pressao': -99.0,
#     'humidade': -99.0,
#     'localEstacao': 'Avis, Benavila (Esc. Abreu Callado)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.3,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.1641, 38.9407]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.1,
#     'temperatura': 7.0,
#     'idEstacao': 1210826,
#     'pressao': -99.0,
#     'humidade': 76.0,
#     'localEstacao': 'Mora',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.3,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.1398, 38.8908]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.9,
#     'temperatura': 12.2,
#     'idEstacao': 1210835,
#     'pressao': -99.0,
#     'humidade': 37.0,
#     'localEstacao': 'Elvas',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.8,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.5167, 38.8667]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.5,
#     'temperatura': 8.5,
#     'idEstacao': 1210837,
#     'pressao': -99.0,
#     'humidade': 50.0,
#     'localEstacao': 'Estremoz',
#     'precAcumulada': 0.0,
#     'idDireccVento': 5,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.7,
#     'descDirVento': 'S'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.4729, 38.4849]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.1,
#     'temperatura': 11.0,
#     'idEstacao': 1210840,
#     'pressao': -99.0,
#     'humidade': 36.0,
#     'localEstacao': 'Reguengos, S.Pedro do Corval',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.7,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.0455, 38.3319]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.6,
#     'temperatura': 9.4,
#     'idEstacao': 1210847,
#     'pressao': -99.0,
#     'humidade': 46.0,
#     'localEstacao': 'Viana do Alentejo',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.1,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.8667, 38.3167]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.9,
#     'temperatura': 5.3,
#     'idEstacao': 1210848,
#     'pressao': -99.0,
#     'humidade': 75.0,
#     'localEstacao': 'Portel, Oriola',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.8,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.2261, 38.2007]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.8,
#     'temperatura': 9.1,
#     'idEstacao': 1210851,
#     'pressao': 1014.5,
#     'humidade': 51.0,
#     'localEstacao': 'Amareleja',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.9,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.55, 37.75]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.5,
#     'temperatura': 9.3,
#     'idEstacao': 1210863,
#     'pressao': -99.0,
#     'humidade': 72.0,
#     'localEstacao': 'Mértola, Vale Formoso',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.7,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.9721, 37.5766]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.4,
#     'temperatura': 6.9,
#     'idEstacao': 1210864,
#     'pressao': -99.0,
#     'humidade': 62.0,
#     'localEstacao': 'Castro Verde, N.Corvo',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.5,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.4163, 37.1871]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': -99.0,
#     'temperatura': 10.3,
#     'idEstacao': 1210866,
#     'pressao': -99.0,
#     'humidade': 67.0,
#     'localEstacao': 'Vila Real de S.António',
#     'precAcumulada': 0.0,
#     'idDireccVento': 0,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': -99.0,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.45, 37.2167]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 12.6,
#     'temperatura': 9.2,
#     'idEstacao': 1210867,
#     'pressao': -99.0,
#     'humidade': 81.0,
#     'localEstacao': 'Castro Marim (RN Sapal)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 3.5,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.5814, 37.1492]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.5,
#     'temperatura': 5.2,
#     'idEstacao': 1210878,
#     'pressao': 1014.2,
#     'humidade': 95.0,
#     'localEstacao': 'Portimão (Aeródromo)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.7,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.821, 37.033]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.9,
#     'temperatura': 13.0,
#     'idEstacao': 1210881,
#     'pressao': 1013.9,
#     'humidade': 37.0,
#     'localEstacao': 'Olhão, EPPO',
#     'precAcumulada': 0.0,
#     'idDireccVento': 0,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.2,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.6205, 37.1217]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 6.8,
#     'temperatura': 8.2,
#     'idEstacao': 1210883,
#     'pressao': 1014.1,
#     'humidade': 72.0,
#     'localEstacao': 'Tavira',
#     'precAcumulada': 0.0,
#     'idDireccVento': 9,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 1.9,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-25.1501, 37.8326]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.9,
#     'temperatura': 13.6,
#     'idEstacao': 1210932,
#     'pressao': -99.0,
#     'humidade': 93.0,
#     'localEstacao': 'S. Miguel, Nordeste',
#     'precAcumulada': 0.0,
#     'idDireccVento': 6,
#     'radiacao': -99.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 0.8,
#     'descDirVento': 'SW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-16.9062, 32.8345]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 9.7,
#     'temperatura': 13.8,
#     'idEstacao': 1210960,
#     'pressao': 1019.0,
#     'humidade': 97.0,
#     'localEstacao': 'Madeira, S. Jorge, Santana',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': 0.0,
#     'time': '2023-04-06T06:00:00',
#     'intensidadeVento': 2.7,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-16.8864, 32.8082]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': -99.0,
#     'temperatura': 10.4,
# ...
#     'intensidadeVento': 8.1,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-17.202, 32.831]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 34.6,
#     'temperatura': 8.7,
#     'idEstacao': 1210980,
#     'pressao': -99.0,
#     'humidade': 100.0,
#     'localEstacao': 'Madeira, Lombo da Terça',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 122.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 9.6,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-17.1042, 32.6815]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.4,
#     'temperatura': 18.2,
#     'idEstacao': 1210986,
#     'pressao': 1017.4,
#     'humidade': 36.0,
#     'localEstacao': 'Madeira, Ponta do Sol',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 229.2,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.4,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-17.2016, 32.7572]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 8.6,
#     'temperatura': 12.7,
#     'idEstacao': 1210987,
#     'pressao': -99.0,
#     'humidade': 46.0,
#     'localEstacao': 'Madeira, Prazeres',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': 341.6,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 2.4,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-17.2632, 32.8138]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 12.2,
#     'temperatura': 13.8,
#     'idEstacao': 1210990,
#     'pressao': 1018.1,
#     'humidade': 79.0,
#     'localEstacao': 'Madeira, Calheta',
#     'precAcumulada': 0.0,
#     'idDireccVento': 6,
#     'radiacao': 115.2,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 3.4,
#     'descDirVento': 'SW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.6025, 41.1385]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 14.0,
#     'temperatura': 10.0,
#     'idEstacao': 1240546,
#     'pressao': 1016.7,
#     'humidade': 99.0,
#     'localEstacao': 'Serra do Pilar',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 744.5,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 3.9,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.7405, 41.309]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 3.6,
#     'temperatura': 10.8,
#     'idEstacao': 1240566,
#     'pressao': -99.0,
#     'humidade': 58.0,
#     'localEstacao': 'Vila Real (Cidade)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 1.0,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.8292, 41.695]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': -99.0,
#     'temperatura': 12.2,
#     'idEstacao': 1240610,
#     'pressao': -99.0,
#     'humidade': 56.0,
#     'localEstacao': 'Viana do Castelo (Cidade)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 0,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': -99.0,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.904, 40.6627]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': -99.0,
#     'temperatura': 12.6,
#     'idEstacao': 1240675,
#     'pressao': -99.0,
#     'humidade': 43.0,
#     'localEstacao': 'Viseu (Cidade)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 0,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': -99.0,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.626, 41.1526]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': -99.0,
#     'temperatura': 12.4,
#     'idEstacao': 1240903,
#     'pressao': -99.0,
#     'humidade': 60.0,
#     'localEstacao': 'Porto, Massarelos',
#     'precAcumulada': 0.0,
#     'idDireccVento': 0,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': -99.0,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.7825, 38.7627]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 8.6,
#     'temperatura': 10.2,
#     'idEstacao': 5210758,
#     'pressao': -99.0,
#     'humidade': 72.0,
#     'localEstacao': 'Alcochete / Campo Tiro',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 2.4,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.3181, 41.7023]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.8,
#     'temperatura': 13.9,
#     'idEstacao': 6212121,
#     'pressao': 1016.0,
#     'humidade': 38.0,
#     'localEstacao': 'Terras de Bouro/Barral (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 701.4,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.5,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.3798, 41.668]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 8.9,
#     'idEstacao': 6212122,
#     'pressao': 1017.6,
#     'humidade': 71.0,
#     'localEstacao': 'Amares Caldelas (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 786.6,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.434, 41.6469]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.4,
#     'temperatura': 8.9,
#     'idEstacao': 6212123,
#     'pressao': 1018.5,
#     'humidade': 83.0,
#     'localEstacao': 'Vila Verde (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': 793.8,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.4,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.4251, 41.5357]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 4.3,
#     'temperatura': 13.2,
#     'idEstacao': 6212124,
#     'pressao': 1017.9,
#     'humidade': 53.0,
#     'localEstacao': 'Braga (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 8,
#     'radiacao': 814.2,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 1.2,
#     'descDirVento': 'NW'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.6271, 41.5294]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 9.3,
#     'idEstacao': 6212125,
#     'pressao': 1018.2,
#     'humidade': 80.0,
#     'localEstacao': 'Barcelos (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 9,
#     'radiacao': 727.2,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.7798, 41.5265]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': -99.0,
#     'temperatura': 9.4,
#     'idEstacao': 6212126,
#     'pressao': 1017.1,
#     'humidade': 83.0,
#     'localEstacao': 'Esposende (CIM)',
#     'precAcumulada': -99.0,
#     'idDireccVento': 0,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': -99.0,
#     'descDirVento': '---'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.9263, 40.4672]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 7.6,
#     'temperatura': 11.6,
#     'idEstacao': 6213012,
#     'pressao': -99.0,
#     'humidade': -99.0,
#     'localEstacao': 'Carregal do Sal(CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 2.1,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.8832, 40.9809]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 14.4,
#     'temperatura': 10.7,
#     'idEstacao': 6213013,
#     'pressao': -99.0,
#     'humidade': 46.0,
#     'localEstacao': 'Castro Daire / Mézio (CIM)',
#     'precAcumulada': -99.0,
#     'idDireccVento': 9,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 4.0,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.6084, 40.611]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 13.3,
#     'temperatura': 13.8,
#     'idEstacao': 6213014,
#     'pressao': -99.0,
#     'humidade': 19.0,
#     'localEstacao': 'Mangualde / Chãs de Tavares  (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 3.7,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.6966, 40.6571]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 17.3,
#     'temperatura': 11.8,
#     'idEstacao': 6213017,
#     'pressao': -99.0,
#     'humidade': 36.0,
#     'localEstacao': 'Penalva do Castelo (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 4.8,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.7202, 40.7607]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 11.9,
#     'temperatura': 11.5,
#     'idEstacao': 6213020,
#     'pressao': -99.0,
#     'humidade': 35.0,
#     'localEstacao': 'Satão (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 3.3,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.2083, 40.5458]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 22.3,
#     'temperatura': 13.4,
#     'idEstacao': 6213021,
#     'pressao': -99.0,
#     'humidade': 12.0,
#     'localEstacao': 'Tondela, Caramulinho ',
#     'precAcumulada': 0.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 6.2,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.7272, 40.8559]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 13.7,
#     'temperatura': 12.8,
#     'idEstacao': 6213022,
#     'pressao': -99.0,
#     'humidade': 33.0,
#     'localEstacao': 'Vila Nova do Paiva (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 3.8,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.0511, 40.6441]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 24.8,
#     'temperatura': 13.7,
#     'idEstacao': 6213023,
#     'pressao': -99.0,
#     'humidade': 23.0,
#     'localEstacao': 'Vouzela (CIM)',
#     'precAcumulada': -99.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 6.9,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.9744, 40.2746]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.8,
#     'temperatura': 6.4,
#     'idEstacao': 6213611,
#     'pressao': -99.0,
#     'humidade': 82.0,
#     'localEstacao': 'Arganil / Aeródromo (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 1,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 1.6,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.5776, 40.3419]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 7.8,
#     'idEstacao': 6213612,
#     'pressao': -99.0,
#     'humidade': 89.0,
#     'localEstacao': 'Cantanhede / Fonte Dom Pedro (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.3749, 40.3308]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 12.2,
#     'temperatura': 14.1,
#     'idEstacao': 6213613,
#     'pressao': -99.0,
#     'humidade': 40.0,
#     'localEstacao': 'Coimbra / Mata de São Pedro (CIM)',
#     'precAcumulada': -99.0,
#     'idDireccVento': 3,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 3.4,
#     'descDirVento': 'E'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.4388, 40.3733]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.2,
#     'temperatura': 7.7,
#     'idEstacao': 6213615,
#     'pressao': -99.0,
#     'humidade': 89.0,
#     'localEstacao': 'Mealhada / Quinta do Vale (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 4,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.6,
#     'descDirVento': 'SE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.2321, 40.4262]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.1,
#     'temperatura': -99.0,
#     'idEstacao': 6213616,
#     'pressao': -99.0,
#     'humidade': -99.0,
#     'localEstacao': 'Mortágua / Aeródromo (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.3,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.1987, 40.2809]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 1.4,
#     'temperatura': 4.9,
#     'idEstacao': 6213617,
#     'pressao': -99.0,
#     'humidade': 94.0,
#     'localEstacao': 'Penacova / Hombres (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 5,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.4,
#     'descDirVento': 'S'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.242, 40.2114]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 5.8,
#     'temperatura': 7.3,
#     'idEstacao': 6213619,
#     'pressao': -99.0,
#     'humidade': 85.0,
#     'localEstacao': 'Vila Nova de Poiares (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 7,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 1.6,
#     'descDirVento': 'W'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-7.868, 40.4133]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 2.5,
#     'temperatura': 7.7,
#     'idEstacao': 6213620,
#     'pressao': -99.0,
#     'humidade': 62.0,
#     'localEstacao': 'Oliveira do Hospital (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.7,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-8.5049, 40.0293]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 28.4,
#     'temperatura': 13.5,
#     'idEstacao': 6213621,
#     'pressao': -99.0,
#     'humidade': 29.0,
#     'localEstacao': 'Soure (CIM)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 7.9,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.2939, 38.724]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 9.7,
#     'temperatura': 15.4,
#     'idEstacao': 6215360,
#     'pressao': 1015.1,
#     'humidade': 52.0,
#     'localEstacao': 'Oeiras / Vila Fria',
#     'precAcumulada': 0.0,
#     'idDireccVento': 9,
#     'radiacao': 690.2,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 2.7,
#     'descDirVento': 'N'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-9.1649, 38.7239]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': 3.2,
#     'temperatura': 14.4,
#     'idEstacao': 7240919,
#     'pressao': 1015.9,
#     'humidade': 58.0,
#     'localEstacao': 'Lisboa, Amoreiras (Lic. Francês)',
#     'precAcumulada': 0.0,
#     'idDireccVento': 2,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': 0.9,
#     'descDirVento': 'NE'}},
#   {'geometry': {'type': 'Point', 'coordinates': [-25.0917, 36.9542]},
#    'type': 'Feature',
#    'properties': {'intensidadeVentoKM': -99.0,
#     'temperatura': -99.0,
#     'idEstacao': 11217160,
#     'pressao': -99.0,
#     'humidade': 81.0,
#     'localEstacao': 'Santa Maria / Praia Formosa (DRAAC)',
#     'precAcumulada': -99.0,
#     'idDireccVento': 0,
#     'radiacao': -99.0,
#     'time': '2023-04-06T08:00:00',
#     'intensidadeVento': -99.0,
#     'descDirVento': '---'}}]}

# %%
# Extract specific attributes from each feature in the GeoJSON and store them in a list
selected_attributes = []

for feature in full_json_array['features']:
    # Extract only the 'name' and 'population' attributes from each feature
    idEstacao = feature['properties']['idEstacao']
    localEstacao = feature['properties']['localEstacao']
    precAcumulada = feature['properties']['precAcumulada']
    horario = feature['properties']['time']
    # Create a new dictionary with the selected attributes and append it to the list
    selected_attributes.append({'idEstacao': idEstacao, 'horario': horario, 'localEstacao': localEstacao, 'precAcumuladaNormalizada' : normalize_precipitation_value(max(0, precAcumulada))})

# Print the list of selected attributes
# print(json.dumps(selected_attributes, indent=2))

# Para ver uma lista de um único atributo
# horario_array = [item["horario"] for item in selected_attributes]
# print(json.dumps(horario_array, indent=2))

# %%
 horario_array = [item["localEstacao"] for item in selected_attributes]
print(json.dumps(horario_array, indent=2))
# Out:
# [
#   "Flores (Aeroporto)",
#   "Corvo (Aer\u00f3dromo)",
#   "Pico (Aer\u00f3dromo)",
#   "Horta (Obs. Pr\u00edncipe Alberto M\u00f3naco)",
#   "Graciosa (Aer\u00f3dromo)",
#   "S\u00e3o Jorge",
#   "Angra do Hero\u00edsmo",
#   "Ponta Delgada (Aeroporto)",
#   "Santa Maria (Aeroporto)",
#   "Santa Catarina (Aeroporto)",
#   "Funchal",
#   "Porto Santo (Aeroporto)",
#   "Cabo Carvoeiro",
#   "Sagres",
#   "Lisboa (Geof\u00edsico)",
#   "Sines",
#   "Pedras Rubras",
#   "Coimbra (Aer\u00f3dromo)",
#   "Viana Castelo, Chaf\u00e9",
#   "Faro (Aeroporto)",
#   "\u00c9vora (C.Coordena\u00e7\u00e3o)",
#   "Viseu (Aer\u00f3dromo)",
#   "Viseu (C.Coordena\u00e7\u00e3o)",
#   "Beja",
#   "Vila Real",
#   "Penhas Douradas",
#   "Castelo Branco",
#   "Portalegre",
#   "Bragan\u00e7a",
#   "Bragan\u00e7a (Aer\u00f3dromo)",
#   "Lisboa (G.Coutinho)",
#   "Ponta Delgada (Obs. Afonso Chaves)",
#   "Odemira, S. Teot\u00f3nio",
#   "V.N.Cerveira (Aer\u00f3dromo)",
#   "Mon\u00e7\u00e3o, Valinha",
#   "Lamas de Mouro, P.Ribeiro",
#   "Montalegre",
#   "Vinhais",
#   "Ponte de Lima (Escola agr\u00edcola)",
#   "Chaves (Aer\u00f3dromo)",
#   "Cabril",
#   "Braga, Merelim",
#   "Cabeceiras de Basto",
#   "Mirandela",
#   "Macedo de Cavaleiros, Bagueixe",
#   "Miranda do Douro",
#   "Mogadouro",
#   "Pa\u00e7os Ferreira",
#   "Carraz\u00eada de Ansi\u00e3es",
#   "S. Gens",
#   "Moncorvo",
#   "Pinh\u00e3o, Santa B\u00e1rbara",
#   "Luzim",
#   "Moimenta da Beira",
#   "Trancoso, Bandarra",
#   "Arouca",
#   "Fig. de Castelo Rodrigo (Vila Torpim)",
#   "Guarda",
#   "Nelas",
#   "Covilh\u00e3 (Aer\u00f3dromo)",
#   "Aldeia Souto (Quinta Lageosa)",
#   "Lous\u00e3 (Aer\u00f3dromo)",
#   "Aveiro (Universidade)",
#   "Dunas de Mira",
#   "Anadia",
#   "Coimbra, Bencanta",
#   "Figueira da Foz, Vila Verde",
#   "Ansi\u00e3o",
#   "Leiria (Aer\u00f3dromo)",
#   "S\u00e3o Pedro de Moel",
#   "Tomar, Valdonas",
#   "Alcoba\u00e7a",
#   "Rio Maior",
#   "Santar\u00e9m, Fonte Boa",
#   "Torres Vedras, Dois Portos",
#   "Coruche (Est. de Regadio - I.N.I.A.)",
#   "Santa Cruz (Aer\u00f3dromo)",
#   "Cabo da Roca",
#   "Lisboa, Tapada da Ajuda",
#   "Cabo Raso",
#   "Barreiro, Lavradio",
#   "Peg\u00f5es",
#   "Set\u00fabal (Est. de Fruticultura)",
#   "Almada, P.Rainha",
#   "Alc\u00e1cer do Sal, Barrosinha",
#   "Alvalade",
#   "Zambujeira",
#   "Aljezur",
#   "Fo\u00eda",
#   "Sabugal, Martim Rei",
#   "Zebreira",
#   "Proen\u00e7a-a-Nova, P.Moitas",
#   "Alvega",
#   "Avis, Benavila (Esc. Abreu Callado)",
#   "Mora",
#   "Elvas",
#   "Estremoz",
#   "Reguengos, S.Pedro do Corval",
#   "Viana do Alentejo",
#   "Portel, Oriola",
#   "Amareleja",
#   "M\u00e9rtola, Vale Formoso",
#   "Castro Verde, N.Corvo",
#   "Vila Real de S.Ant\u00f3nio",
#   "Castro Marim (RN Sapal)",
#   "Portim\u00e3o (Aer\u00f3dromo)",
#   "Olh\u00e3o, EPPO",
#   "Tavira",
#   "S. Miguel, Nordeste",
#   "Madeira, S. Jorge, Santana",
#   "Madeira, Santana",
#   "Madeira, S\u00e3o Vicente",
#   "Madeira, Bica da Cana",
#   "Pico Alto",
#   "Madeira, Areeiro",
#   "Madeira, Pico do Areeiro",
#   "Madeira, Santo da Serra",
#   "Monte ",
#   "Madeira, Cancela, Funchal",
#   "Madeira, Cani\u00e7al, S. Louren\u00e7o",
#   "Madeira, Lombo da Ter\u00e7a",
#   "Madeira, Quinta Grande",
#   "Madeira, Ponta do Sol",
#   "Madeira, Prazeres",
#   "Madeira, Calheta",
#   "Serra do Pilar",
#   "Vila Real (Cidade)",
#   "Viana do Castelo (Cidade)",
#   "Viseu (Cidade)",
#   "Porto, Massarelos",
#   "Funchal, Lido",
#   "Alcochete / Campo Tiro",
#   "Terras de Bouro/Barral (CIM)",
#   "Amares Caldelas (CIM)",
#   "Vila Verde (CIM)",
#   "Braga (CIM)",
#   "Barcelos (CIM)",
#   "Esposende (CIM)",
#   "Carregal do Sal(CIM)",
#   "Castro Daire / M\u00e9zio (CIM)",
#   "Mangualde / Ch\u00e3s de Tavares  (CIM)",
#   "Penalva do Castelo (CIM)",
#   "Sat\u00e3o (CIM)",
#   "Tondela, Caramulinho ",
#   "Vila Nova do Paiva (CIM)",
#   "Vouzela (CIM)",
#   "Arganil / Aer\u00f3dromo (CIM)",
#   "Cantanhede / Fonte Dom Pedro (CIM)",
#   "Coimbra / Mata de S\u00e3o Pedro (CIM)",
#   "Mealhada / Quinta do Vale (CIM)",
#   "Mort\u00e1gua / Aer\u00f3dromo (CIM)",
#   "Penacova / Hombres (CIM)",
#   "Vila Nova de Poiares (CIM)",
#   "Oliveira do Hospital (CIM)",
#   "Soure (CIM)",
#   "Ma\u00e7\u00e3o/Cardigos (CIM)",
#   "Oeiras / Vila Fria",
#   "Lisboa, Amoreiras (Lic. Franc\u00eas)",
#   "Santa Maria / Praia Formosa (DRAAC)",
#   "Santa Maria / Maia (DRAAC)",
#   "S\u00e3o Miguel / Santana (DRAAC)",
#   "S\u00e3o Miguel / Sete Cidades (DRAAC)",
#   "S\u00e3o Miguel / Lagoa das Furnas (DRAAC)",
#   "Terceira / Ribeira das Nove (DRAAC)",
#   "Terceira / Serra do Cume (DRAAC)",
#   "Graciosa / Serra das Fontes (DRAAC)",
#   "S\u00e3o Jorge / Pico do Areeiro (DRAAC)",
#   "Pico / Cabe\u00e7o do Teicho (DRAAC)",
#   "Pico / Cabecinho (DRAAC)",
#   "Flores (Aeroporto)",
#   "Corvo (Aer\u00f3dromo)",
#   "Pico (Aer\u00f3dromo)",
#   "Horta (Obs. Pr\u00edncipe Alberto M\u00f3naco)",
#   "Graciosa (Aer\u00f3dromo)",
#   "S\u00e3o Jorge",
#   "Angra do Hero\u00edsmo",
#   "Ponta Delgada (Aeroporto)",
#   "Santa Maria (Aeroporto)",
#   "Santa Catarina (Aeroporto)",
#   "Funchal",
#   "Porto Santo (Aeroporto)",
#   "Cabo Carvoeiro",
#   "Sagres",
#   "Lisboa (Geof\u00edsico)",
#   "Sines",
#   "Pedras Rubras",
#   "Coimbra (Aer\u00f3dromo)",
#   "Viana Castelo, Chaf\u00e9",
#   "Faro (Aeroporto)",
#   "\u00c9vora (C.Coordena\u00e7\u00e3o)",
#   "Viseu (Aer\u00f3dromo)",
#   "Viseu (C.Coordena\u00e7\u00e3o)",
#   "Beja",
#   "Vila Real",
#   "Penhas Douradas",
#   "Castelo Branco",
#   "Portalegre",
#   "Bragan\u00e7a",
#   "Bragan\u00e7a (Aer\u00f3dromo)",
#   "Lisboa (G.Coutinho)",
#   "Ponta Delgada (Obs. Afonso Chaves)",
#   "Odemira, S. Teot\u00f3nio",
#   "V.N.Cerveira (Aer\u00f3dromo)",
#   "Mon\u00e7\u00e3o, Valinha",
#   "Lamas de Mouro, P.Ribeiro",
#   "Montalegre",
#   "Vinhais",
#   "Ponte de Lima (Escola agr\u00edcola)",
#   "Chaves (Aer\u00f3dromo)",
#   "Cabril",
#   "Braga, Merelim",
#   "Cabeceiras de Basto",
#   "Mirandela",
#   "Macedo de Cavaleiros, Bagueixe",
#   "Miranda do Douro",
#   "Mogadouro",
#   "Pa\u00e7os Ferreira",
#   "Carraz\u00eada de Ansi\u00e3es",
#   "S. Gens",
#   "Moncorvo",
#   "Pinh\u00e3o, Santa B\u00e1rbara",
#   "Luzim",
#   "Moimenta da Beira",
#   "Trancoso, Bandarra",
#   "Arouca",
#   "Fig. de Castelo Rodrigo (Vila Torpim)",
#   "Guarda",
#   "Nelas",
#   "Covilh\u00e3 (Aer\u00f3dromo)",
#   "Aldeia Souto (Quinta Lageosa)",
#   "Lous\u00e3 (Aer\u00f3dromo)",
#   "Aveiro (Universidade)",
#   "Dunas de Mira",
#   "Anadia",
#   "Coimbra, Bencanta",
#   "Figueira da Foz, Vila Verde",
#   "Ansi\u00e3o",
#   "Leiria (Aer\u00f3dromo)",
#   "S\u00e3o Pedro de Moel",
#   "Tomar, Valdonas",
#   "Alcoba\u00e7a",
#   "Rio Maior",
#   "Santar\u00e9m, Fonte Boa",
#   "Torres Vedras, Dois Portos",
#   "Coruche (Est. de Regadio - I.N.I.A.)",
#   "Santa Cruz (Aer\u00f3dromo)",
#   "Cabo da Roca",
#   "Lisboa, Tapada da Ajuda",
#   "Cabo Raso",
#   "Barreiro, Lavradio",
#   "Peg\u00f5es",
#   "Set\u00fabal (Est. de Fruticultura)",
#   "Almada, P.Rainha",
#   "Alc\u00e1cer do Sal, Barrosinha",
#   "Alvalade",
#   "Zambujeira",
#   "Aljezur",
#   "Fo\u00eda",
#   "Sabugal, Martim Rei",
#   "Zebreira",
#   "Proen\u00e7a-a-Nova, P.Moitas",
#   "Alvega",
#   "Avis, Benavila (Esc. Abreu Callado)",
#   "Mora",
#   "Elvas",
#   "Estremoz",
#   "Reguengos, S.Pedro do Corval",
#   "Viana do Alentejo",
#   "Portel, Oriola",
#   "Amareleja",
#   "M\u00e9rtola, Vale Formoso",
#   "Castro Verde, N.Corvo",
#   "Vila Real de S.Ant\u00f3nio",
#   "Castro Marim (RN Sapal)",
#   "Portim\u00e3o (Aer\u00f3dromo)",
#   "Olh\u00e3o, EPPO",
#   "Tavira",
#   "S. Miguel, Nordeste",
#   "Madeira, S. Jorge, Santana",
#   "Madeira, Santana",
#   "Madeira, S\u00e3o Vicente",
#   "Madeira, Bica da Cana",
#   "Pico Alto",
#   "Madeira, Areeiro",
#   "Madeira, Santo da Serra",
#   "Monte ",
#   "Madeira, Cancela, Funchal",
#   "Madeira, Cani\u00e7al, S. Louren\u00e7o",
#   "Madeira, Lombo da Ter\u00e7a",
#   "Madeira, Quinta Grande",
#   "Madeira, Ponta do Sol",
#   "Madeira, Prazeres",
#   "Madeira, Calheta",
#   "Serra do Pilar",
#   "Vila Real (Cidade)",
#   "Viana do Castelo (Cidade)",
#   "Viseu (Cidade)",
#   "Porto, Massarelos",
#   "Funchal, Lido",
#   "Alcochete / Campo Tiro",
#   "Terras de Bouro/Barral (CIM)",
#   "Amares Caldelas (CIM)",
#   "Vila Verde (CIM)",
#   "Braga (CIM)",
#   "Barcelos (CIM)",
#   "Esposende (CIM)",
#   "Carregal do Sal(CIM)",
#   "Castro Daire / M\u00e9zio (CIM)",
#   "Mangualde / Ch\u00e3s de Tavares  (CIM)",
#   "Penalva do Castelo (CIM)",
#   "Sat\u00e3o (CIM)",
#   "Tondela, Caramulinho ",
#   "Vila Nova do Paiva (CIM)",
#   "Vouzela (CIM)",
#   "Arganil / Aer\u00f3dromo (CIM)",
#   "Cantanhede / Fonte Dom Pedro (CIM)",
#   "Coimbra / Mata de S\u00e3o Pedro (CIM)",
#   "Mealhada / Quinta do Vale (CIM)",
#   "Mort\u00e1gua / Aer\u00f3dromo (CIM)",
#   "Penacova / Hombres (CIM)",
#   "Vila Nova de Poiares (CIM)",
#   "Oliveira do Hospital (CIM)",
#   "Soure (CIM)",
#   "Oeiras / Vila Fria",
#   "Lisboa, Amoreiras (Lic. Franc\u00eas)",
#   "Santa Maria / Praia Formosa (DRAAC)",
#   "Santa Maria / Maia (DRAAC)",
#   "S\u00e3o Miguel / Santana (DRAAC)",
#   "S\u00e3o Miguel / Lagoa das Furnas (DRAAC)",
#   "Terceira / Ribeira das Nove (DRAAC)",
#   "Terceira / Serra do Cume (DRAAC)",
#   "Graciosa / Serra das Fontes (DRAAC)",
#   "S\u00e3o Jorge / Pico do Areeiro (DRAAC)",
#   "Pico / Cabe\u00e7o do Teicho (DRAAC)",
#   "Pico / Cabecinho (DRAAC)",
#   "Flores (Aeroporto)",
#   "Corvo (Aer\u00f3dromo)",
#   "Pico (Aer\u00f3dromo)",
#   "Horta (Obs. Pr\u00edncipe Alberto M\u00f3naco)",
#   "Graciosa (Aer\u00f3dromo)",
#   "S\u00e3o Jorge",
#   "Angra do Hero\u00edsmo",
#   "Ponta Delgada (Aeroporto)",
#   "Santa Maria (Aeroporto)",
#   "Santa Catarina (Aeroporto)",
#   "Funchal",
#   "Porto Santo (Aeroporto)",
#   "Cabo Carvoeiro",
#   "Sagres",
#   "Lisboa (Geof\u00edsico)",
#   "Sines",
#   "Pedras Rubras",
#   "Coimbra (Aer\u00f3dromo)",
#   "Viana Castelo, Chaf\u00e9",
#   "Faro (Aeroporto)",
#   "\u00c9vora (C.Coordena\u00e7\u00e3o)",
#   "Viseu (Aer\u00f3dromo)",
#   "Viseu (C.Coordena\u00e7\u00e3o)",
#   "Beja",
#   "Vila Real",
#   "Penhas Douradas",
#   "Castelo Branco",
#   "Portalegre",
#   "Bragan\u00e7a",
#   "Bragan\u00e7a (Aer\u00f3dromo)",
#   "Lisboa (G.Coutinho)",
#   "Ponta Delgada (Obs. Afonso Chaves)",
#   "Odemira, S. Teot\u00f3nio",
#   "V.N.Cerveira (Aer\u00f3dromo)",
#   "Mon\u00e7\u00e3o, Valinha",
#   "Lamas de Mouro, P.Ribeiro",
#   "Montalegre",
#   "Vinhais",
#   "Ponte de Lima (Escola agr\u00edcola)",
#   "Chaves (Aer\u00f3dromo)",
#   "Cabril",
#   "Braga, Merelim",
#   "Cabeceiras de Basto",
#   "Mirandela",
#   "Macedo de Cavaleiros, Bagueixe",
#   "Miranda do Douro",
#   "Mogadouro",
#   "Pa\u00e7os Ferreira",
#   "Carraz\u00eada de Ansi\u00e3es",
#   "S. Gens",
#   "Moncorvo",
#   "Pinh\u00e3o, Santa B\u00e1rbara",
#   "Luzim",
#   "Moimenta da Beira",
#   "Trancoso, Bandarra",
#   "Arouca",
#   "Fig. de Castelo Rodrigo (Vila Torpim)",
#   "Guarda",
#   "Nelas",
#   "Covilh\u00e3 (Aer\u00f3dromo)",
#   "Aldeia Souto (Quinta Lageosa)",
#   "Lous\u00e3 (Aer\u00f3dromo)",
#   "Aveiro (Universidade)",
#   "Dunas de Mira",
#   "Anadia",
#   "Coimbra, Bencanta",
#   "Figueira da Foz, Vila Verde",
#   "Ansi\u00e3o",
#   "Leiria (Aer\u00f3dromo)",
#   "S\u00e3o Pedro de Moel",
#   "Tomar, Valdonas",
#   "Alcoba\u00e7a",
#   "Rio Maior",
#   "Santar\u00e9m, Fonte Boa",
#   "Torres Vedras, Dois Portos",
#   "Coruche (Est. de Regadio - I.N.I.A.)",
#   "Santa Cruz (Aer\u00f3dromo)",
#   "Cabo da Roca",
#   "Lisboa, Tapada da Ajuda",
#   "Cabo Raso",
#   "Barreiro, Lavradio",
#   "Peg\u00f5es",
#   "Set\u00fabal (Est. de Fruticultura)",
#   "Almada, P.Rainha",
#   "Alc\u00e1cer do Sal, Barrosinha",
#   "Alvalade",
#   "Zambujeira",
#   "Aljezur",
#   "Fo\u00eda",
#   "Sabugal, Martim Rei",
#   "Zebreira",
#   "Proen\u00e7a-a-Nova, P.Moitas",
#   "Alvega",
#   "Avis, Benavila (Esc. Abreu Callado)",
#   "Mora",
#   "Elvas",
#   "Estremoz",
#   "Reguengos, S.Pedro do Corval",
#   "Viana do Alentejo",
#   "Portel, Oriola",
#   "Amareleja",
#   "M\u00e9rtola, Vale Formoso",
#   "Castro Verde, N.Corvo",
#   "Vila Real de S.Ant\u00f3nio",
#   "Castro Marim (RN Sapal)",
#   "Portim\u00e3o (Aer\u00f3dromo)",
#   "Olh\u00e3o, EPPO",
#   "Tavira",
#   "S. Miguel, Nordeste",
#   "Madeira, S. Jorge, Santana",
#   "Madeira, Areeiro",
#   "Monte ",
#   "Madeira, Cancela, Funchal",
#   "Madeira, Cani\u00e7al, S. Louren\u00e7o",
#   "Madeira, Lombo da Ter\u00e7a",
#   "Madeira, Ponta do Sol",
#   "Madeira, Prazeres",
#   "Madeira, Calheta",
#   "Serra do Pilar",
#   "Vila Real (Cidade)",
#   "Viana do Castelo (Cidade)",
#   "Viseu (Cidade)",
#   "Porto, Massarelos",
#   "Alcochete / Campo Tiro",
#   "Terras de Bouro/Barral (CIM)",
#   "Amares Caldelas (CIM)",
#   "Vila Verde (CIM)",
#   "Braga (CIM)",
#   "Barcelos (CIM)",
#   "Esposende (CIM)",
#   "Carregal do Sal(CIM)",
#   "Castro Daire / M\u00e9zio (CIM)",
#   "Mangualde / Ch\u00e3s de Tavares  (CIM)",
#   "Penalva do Castelo (CIM)",
#   "Sat\u00e3o (CIM)",
#   "Tondela, Caramulinho ",
#   "Vila Nova do Paiva (CIM)",
#   "Vouzela (CIM)",
#   "Arganil / Aer\u00f3dromo (CIM)",
#   "Cantanhede / Fonte Dom Pedro (CIM)",
#   "Coimbra / Mata de S\u00e3o Pedro (CIM)",
#   "Mealhada / Quinta do Vale (CIM)",
#   "Mort\u00e1gua / Aer\u00f3dromo (CIM)",
#   "Penacova / Hombres (CIM)",
#   "Vila Nova de Poiares (CIM)",
#   "Oliveira do Hospital (CIM)",
#   "Soure (CIM)",
#   "Oeiras / Vila Fria",
#   "Lisboa, Amoreiras (Lic. Franc\u00eas)",
#   "Santa Maria / Praia Formosa (DRAAC)"
# ]
