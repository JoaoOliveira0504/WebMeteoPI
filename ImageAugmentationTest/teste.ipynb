# %%
import os

def list_folders_without_dataset():
    folders = []
    folder_path = os.getcwd()
    for name in os.listdir(folder_path):
        if os.path.isdir(os.path.join(folder_path, name)):
            if name.endswith("dataset"):
                # and name != "dataset"
                #folder_name = name.replace("dataset", "")
                folders.append(name)
    return folders

all_datasets=list_folders_without_dataset()

images = []

for unique_dataset in all_datasets:
    image_path=unique_dataset+'/images/1200554/2023-04-07/2023-04-07T2100.png'
    image = Image.open(image_path)
    images.append(image)

# %%
import ipyplot 



labels = all_datasets
ipyplot.plot_images(images,labels=labels,img_width=200)
image.close()
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fEYS3d9rxMJLYn7usdUpWJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fEYS3d9rxMJLYn7usdUpWJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fEYS3d9rxMJLYn7usdUpWJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fEYS3d9rxMJLYn7usdUpWJ:checked ~ #ipyplot-html-viewer-textarea-fEYS3d9rxMJLYn7usdUpWJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fEYS3d9rxMJLYn7usdUpWJ:checked + #ipyplot-html-viewer-label-fEYS3d9rxMJLYn7usdUpWJ:after {
# ...
