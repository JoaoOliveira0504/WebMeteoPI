# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images = tf.keras.utils.normalize(train_images, axis=1)
test_images = tf.keras.utils.normalize(test_images, axis=1)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)          36928
#
# =================================================================
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.7455 - accuracy: 0.3578 - val_loss: 1.4487 - val_accuracy: 0.4711
# Epoch 2/10
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.3611 - accuracy: 0.5162 - val_loss: 1.3022 - val_accuracy: 0.5365
# Epoch 3/10
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.2101 - accuracy: 0.5734 - val_loss: 1.1794 - val_accuracy: 0.5829
# Epoch 4/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.1161 - accuracy: 0.6083 - val_loss: 1.0935 - val_accuracy: 0.6128
# Epoch 5/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.0359 - accuracy: 0.6364 - val_loss: 1.0680 - val_accuracy: 0.6287
# Epoch 6/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.9774 - accuracy: 0.6561 - val_loss: 1.0441 - val_accuracy: 0.6345
# Epoch 7/10
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.9302 - accuracy: 0.6753 - val_loss: 0.9852 - val_accuracy: 0.6561
# Epoch 8/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8898 - accuracy: 0.6883 - val_loss: 0.9778 - val_accuracy: 0.6592
# Epoch 9/10
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.8513 - accuracy: 0.7021 - val_loss: 0.9834 - val_accuracy: 0.6581
# Epoch 10/10
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.8136 - accuracy: 0.7150 - val_loss: 0.9347 - val_accuracy: 0.6803

# %%
predictions = model.predict([test_images])
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 2s - loss: 0.9347 - accuracy: 0.6803 - 2s/epoch - 5ms/step

# %%
import numpy as np

index = 962

print("Predicted output: {} \nReal output: {}".format(class_names[np.argmax(predictions[index])],class_names[test_labels[index][0]]))
plt.imshow(test_images[index])
# Out:
# Predicted output: truck
# Real output: automobile
